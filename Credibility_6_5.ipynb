# %% [markdown]
# <a href="https://colab.research.google.com/github/Konstantinosil/Chortareas-Linardatos-A-Macro-Augmented-Jump-Diffusion-Shadow-Rate-Model/blob/main/Credibility_6_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import annotations

import importlib
import logging
import random
import subprocess
import sys
import warnings
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, Optional, Sequence, Tuple, Union

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from scipy.stats import norm

try:
    from IPython.display import display
    from IPython import get_ipython
except Exception:
    get_ipython = None

    def display(obj):
        print(obj)


def ensure_runtime_dependencies() -> None:
    missing = []
    for mod, pkg in [("arch", "arch"), ("openpyxl", "openpyxl"), ("statsmodels", "statsmodels")]:
        if importlib.util.find_spec(mod) is None:
            missing.append(pkg)

    if missing:
        subprocess.check_call(
            [sys.executable, "-m", "pip", "install", "-q", *missing]
        )


ensure_runtime_dependencies()
from arch import arch_model


def _activate_inline_backend() -> None:
    ip = get_ipython() if callable(get_ipython) else None
    if ip is not None:
        try:
            ip.run_line_magic("matplotlib", "inline")
        except Exception:
            pass


_activate_inline_backend()

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings(
    "ignore",
    message="No frequency information was provided, so inferred frequency",
)
warnings.filterwarnings("ignore", category=RuntimeWarning)

logging.basicConfig(level=logging.INFO, format="[%(levelname)s] %(message)s")


@dataclass(frozen=True)
class JournalConfig:
    ROOT_LOCAL: str = "."
    DATA_FILE: str = "Dataset for Credibility.xlsx"

    REPORTED_START: str = "2008-01-01"
    END: str = "2022-01-31"
    AP_PRESAMPLE_START: str = "2000-01-01"

    PI_STAR: float = 2.0
    ELB_EPS: float = 0.10
    ELB_THRESHOLDS: Optional[Dict[str, float]] = None

    RF_WINDOW_CAND: Tuple[int, ...] = (36, 48, 60, 72, 84)
    AP_SCALE_P_LO: int = 1
    AP_SCALE_P_HI: int = 99

    HAC_LAGS_BASE: int = 6
    WILD_BOOT_B: int = 399
    SEED: int = 123

    AR_MAX: int = 2
    MIN_T: int = 24
    FALLBACK_ROLL: int = 12
    ANCHOR_END: str = "2010-12-01"
    SHADOW_SCALE_P_LO: int = 5
    SHADOW_SCALE_P_HI: int = 95

    SHADOW_START: str = "2008-01-01"
    SHADOW_END: str = "2022-01-01"
    SHADOW_SEED: int = 42
    LEGACY_SHADOW_FORCE_AR0: bool = True
    LEGACY_SR_LAG_AFTER_DROP: bool = True

    HAMILTON_K: int = 12
    SR_H: int = 12
    SR_LAG: int = 12
    MIN_ABS_DPI: float = 0.10
    WINSOR_PCTS: Tuple[float, float] = (0.01, 0.99)

    PLOTS: bool = True
    SAVE_FIGURES: bool = False
    WRITE_RESULTS_TO_FILES: bool = False
    RESULTS_DIR: str = "credibility_results_single_workbook"

    def __post_init__(self):
        if self.ELB_THRESHOLDS is None:
            object.__setattr__(
                self,
                "ELB_THRESHOLDS",
                {"ECB": 0.10, "BoE": 0.25, "Fed": 0.25},
            )


CFG = JournalConfig()

BANK_CODE_TO_NAME = {"EU": "ECB", "UK": "BoE", "US": "Fed"}
BANK_NAME_TO_CODE = {v: k for k, v in BANK_CODE_TO_NAME.items()}
BANK_ORDER = ["Fed", "ECB", "BoE"]
ECON_ORDER = ["US", "EU", "UK"]


def set_seeds(seed: int) -> None:
    np.random.seed(seed)
    random.seed(seed)


def resolve_input_file(filename: str, root_local: Optional[str] = None) -> Path:
    candidates = []
    if root_local:
        candidates.append(Path(root_local) / filename)

    candidates.extend(
        [
            Path.cwd() / filename,
            Path("/content") / filename,
            Path("/mnt/data") / filename,
            Path(filename),
        ]
    )

    seen = set()
    unique = []
    for p in candidates:
        key = str(p.resolve()) if p.exists() else str(p)
        if key not in seen:
            seen.add(key)
            unique.append(p)

    for p in unique:
        if p.exists():
            return p

    searched = "\n".join(str(x) for x in unique)
    raise FileNotFoundError(f"Could not find '{filename}'. Searched:\n{searched}")


def show_heading(title: str) -> None:
    bar = "=" * max(44, len(title))
    print(f"\n{bar}\n{title}\n{bar}")


def show_table(title: str, obj, max_rows: int = 200) -> None:
    show_heading(title)
    if obj is None:
        print("(none)")
        return
    if isinstance(obj, pd.Series):
        obj = obj.to_frame()
    if not hasattr(obj, "__len__") or len(obj) == 0:
        print("(empty)")
        return
    try:
        display(obj if len(obj) <= max_rows else obj.head(max_rows))
        if len(obj) > max_rows:
            print(f"Displayed first {max_rows} rows out of {len(obj)}.")
    except Exception:
        print(obj if len(obj) <= max_rows else obj.head(max_rows))


def month_end(ts) -> pd.Timestamp:
    return (
        pd.Timestamp(ts).to_period("M").to_timestamp(how="start")
        + pd.offsets.MonthEnd(0)
    ).normalize()


def save_fig(fig: plt.Figure, save_path: Optional[Path] = None, save_flag: bool = False):
    if save_flag and save_path is not None:
        save_path.parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(save_path, bbox_inches="tight")
    plt.show()
    plt.close(fig)


def winsorize_df(df: pd.DataFrame, cols: Sequence[str], p: float = 0.01) -> pd.DataFrame:
    z = df.copy()
    for c in cols:
        if c in z.columns and z[c].notna().any():
            lo, hi = z[c].quantile([p, 1 - p])
            z[c] = z[c].clip(lo, hi)
    return z


def winsorize(s: pd.Series, p: Tuple[float, float] = (0.01, 0.99)) -> pd.Series:
    z = pd.Series(s).copy()
    if z.dropna().empty:
        return z
    lo, hi = z.quantile(p[0]), z.quantile(p[1])
    return z.clip(lo, hi)


def params_as_series(res) -> pd.Series:
    return pd.Series(res.params, index=res.model.exog_names).astype(float)


def bse_as_series(res) -> pd.Series:
    return pd.Series(res.bse, index=res.model.exog_names).astype(float)


def pvalues_as_series(res) -> pd.Series:
    return pd.Series(res.pvalues, index=res.model.exog_names).astype(float)


def safe_get_triplet(res, var: str) -> Tuple[float, float, float]:
    return (
        float(params_as_series(res).get(var, np.nan)),
        float(bse_as_series(res).get(var, np.nan)),
        float(pvalues_as_series(res).get(var, np.nan)),
    )


def merge_no_overlap(
    left: pd.DataFrame,
    right: pd.DataFrame,
    on: Sequence[str],
    suffix: str = "_r",
    how: str = "left",
    validate: Optional[str] = None,
) -> pd.DataFrame:
    on = list(on)
    overlap = (set(left.columns) & set(right.columns)) - set(on)
    r = right.rename(columns={c: f"{c}{suffix}" for c in overlap})
    return left.merge(r, on=on, how=how, validate=validate)


def scale_series_to_0_100(
    s: pd.Series,
    p_lo: int = 1,
    p_hi: int = 99,
) -> Tuple[pd.Series, Dict[str, float]]:
    x = pd.to_numeric(pd.Series(s), errors="coerce")
    base = x.dropna()
    if base.empty:
        out = pd.Series(np.nan, index=x.index, dtype=float)
        return out, {"q_lo": np.nan, "q_hi": np.nan}

    q_lo = float(np.nanpercentile(base.values, p_lo))
    q_hi = float(np.nanpercentile(base.values, p_hi))
    width = max(1e-8, q_hi - q_lo)
    scaled = ((x - q_lo) / width * 100.0).clip(0, 100)
    return scaled.astype(float), {"q_lo": q_lo, "q_hi": q_hi}


def scale_wide_to_0_100(
    rawcred: pd.DataFrame,
    anchor_end: str,
    p_lo: int = 5,
    p_hi: int = 95,
) -> Tuple[pd.DataFrame, Dict[str, float]]:
    anchor_end_me = month_end(anchor_end)
    z = rawcred.copy()
    z.index = pd.to_datetime(z.index).to_period("M").to_timestamp("M")
    base = z.loc[z.index <= anchor_end_me].stack().dropna()
    if base.empty:
        raise ValueError("Anchor window empty. Check ANCHOR_END.")

    q_lo = float(np.nanpercentile(base.values, p_lo))
    q_hi = float(np.nanpercentile(base.values, p_hi))
    width = max(1e-8, q_hi - q_lo)
    scaled = ((z - q_lo) / width * 100.0).clip(0, 100)
    stats = {"q_lo": q_lo, "q_hi": q_hi, "anchor_end": str(anchor_end_me.date())}
    return scaled, stats


def parse_unified_sheet(name: str) -> Tuple[Optional[str], Optional[str]]:
    s = str(name).strip()
    parts = s.split()
    if len(parts) < 2:
        return None, None

    econ = parts[-1].upper()
    head = " ".join(parts[:-1]).lower()

    key = {
        "shadow rates": "SR",
        "policy rates": "POLICY",
        "inflation": "INF",
    }

    for k, v in key.items():
        if k in head:
            return v, econ

    if head.startswith("rgdp"):
        return "GDP", econ

    return None, None


def read_raw_sheet(path: Union[str, Path], sheet_name: str) -> pd.DataFrame:
    d = pd.read_excel(str(path), sheet_name=sheet_name)
    if d.shape[1] < 2:
        raise ValueError(f"Sheet '{sheet_name}' must have at least two columns.")

    d = d.iloc[:, :2].copy()
    d.columns = ["date", "value"]
    d["date"] = pd.to_datetime(d["date"], errors="coerce")

    raw = d["value"]
    num = pd.to_numeric(raw, errors="coerce")
    if num.notna().mean() < 0.5:
        num = (
            raw.astype(str)
            .str.replace("%", "", regex=False)
            .str.replace("\u2212", "-", regex=False)
            .str.replace(" ", "", regex=False)
            .str.replace(",", ".", regex=False)
        )
        num = pd.to_numeric(num, errors="coerce")

    d["value"] = num
    d = d.dropna(subset=["date"]).sort_values("date").reset_index(drop=True)
    return d


def load_unified_raw(path: Union[str, Path]) -> Tuple[Dict[Tuple[str, str], pd.DataFrame], pd.Series]:
    xls = pd.ExcelFile(str(path))

    raw: Dict[Tuple[str, str], pd.DataFrame] = {}
    t5y5y_daily = None

    for sh in xls.sheet_names:
        if sh.strip().lower() == "5y5y":
            fwd = pd.read_excel(str(path), sheet_name=sh)
            cols = {str(c).lower(): c for c in fwd.columns}

            date_col = cols.get("observation_date", fwd.columns[0])
            val_col = cols.get("t5yifr", fwd.columns[1])

            fwd = fwd[[date_col, val_col]].copy()
            fwd.columns = ["date", "t5y5y"]
            fwd["date"] = pd.to_datetime(fwd["date"], errors="coerce")
            fwd["t5y5y"] = pd.to_numeric(fwd["t5y5y"], errors="coerce")
            fwd = fwd.dropna(subset=["date", "t5y5y"]).sort_values("date")
            t5y5y_daily = fwd.set_index("date")["t5y5y"].rename("t5y5y")
            continue

        var, econ = parse_unified_sheet(sh)
        if var is None:
            continue
        if econ not in BANK_CODE_TO_NAME:
            continue

        raw[(econ, var)] = read_raw_sheet(path, sh)

    required = [(econ, var) for econ in ["EU", "UK", "US"] for var in ["SR", "POLICY", "INF", "GDP"]]
    missing = [k for k in required if k not in raw]
    if missing:
        raise KeyError(f"Missing required sheets/series: {missing}")

    if t5y5y_daily is None:
        raise KeyError("Missing required '5y5y' sheet with observation_date/T5YIFR.")

    return raw, t5y5y_daily


def freq_audit(xls_path: Union[str, Path]) -> pd.DataFrame:
    xls = pd.ExcelFile(str(xls_path))
    rows = []

    for sh in xls.sheet_names:
        d = pd.read_excel(xls, sheet_name=sh)
        if d.shape[1] < 2:
            rows.append({"sheet": sh, "n": len(d), "infer_freq": None, "start": pd.NaT, "end": pd.NaT})
            continue

        date_col = d.columns[0]
        val_col = d.columns[1]
        dd = pd.to_datetime(d[date_col], errors="coerce").dropna().sort_values()
        vv = pd.to_numeric(d[val_col], errors="coerce")

        try:
            freq = pd.infer_freq(dd[:20]) if len(dd) >= 10 else None
        except Exception:
            freq = None

        rows.append(
            {
                "sheet": sh,
                "n_rows": int(len(d)),
                "n_dates": int(dd.notna().sum()),
                "n_values": int(vv.notna().sum()),
                "infer_freq": freq,
                "start": dd.min(),
                "end": dd.max(),
                "date_col": str(date_col),
                "value_col": str(val_col),
            }
        )

    return pd.DataFrame(rows)


def to_monthly_eom(s: pd.Series, interpolate_quarterly: bool = True) -> pd.Series:
    z = pd.Series(s).copy()
    if not isinstance(z.index, pd.DatetimeIndex):
        z.index = pd.to_datetime(z.index, errors="coerce")
    z = z[~pd.isna(z.index)]
    z = pd.to_numeric(z, errors="coerce").sort_index()

    if z.index.has_duplicates:
        z = z.groupby(level=0).last()

    inferred = ""
    if len(z.dropna()) >= 3:
        try:
            inferred = (pd.infer_freq(z.dropna().index[:20]) or "").upper()
        except Exception:
            inferred = ""

    if inferred.startswith(("D", "B")):
        out = z.resample("ME").last()
        if out.index.has_duplicates:
            out = out.groupby(level=0).last()
        return out

    if inferred.startswith("Q"):
        q = z.copy()
        q.index = q.index.to_period("Q").to_timestamp("Q")
        q = q[~q.index.duplicated(keep="last")].sort_index()
        if not interpolate_quarterly:
            return q.resample("ME").last()

        monthly_idx = pd.date_range(
            q.index.min().to_period("M").to_timestamp("M"),
            q.index.max().to_period("M").to_timestamp("M"),
            freq="ME",
        )
        q_month = q.reindex(monthly_idx)
        q_month.loc[q.index] = q.values
        return q_month.interpolate(method="linear", limit_direction="both")

    z.index = z.index.to_period("M").to_timestamp("M")
    z = z.groupby(level=0).last().sort_index()
    return z.asfreq("ME")


def infer_yoy_from_INF(series: pd.Series) -> pd.Series:
    s = pd.to_numeric(series, errors="coerce")
    med = s.median()
    return s.pct_change(12, fill_method=None) * 100.0 if (np.isfinite(med) and med > 30) else s


def inflation_yoy_log_from_cpi(cpi: pd.Series) -> pd.Series:
    s = pd.to_numeric(pd.Series(cpi), errors="coerce")
    s = s.replace([np.inf, -np.inf], np.nan).dropna()
    l = np.log(s.clip(lower=1e-8))
    return 100.0 * (l - l.shift(12))


def hamilton_output_gap(log_gdp: pd.Series, k: int = 12) -> pd.Series:
    y = pd.to_numeric(log_gdp, errors="coerce").replace([np.inf, -np.inf], np.nan)
    y = y.sort_index()

    Xlags = pd.concat([y.shift(i) for i in range(1, k + 1)], axis=1)
    Xlags.columns = [f"lag{i}" for i in range(1, k + 1)]

    resid = pd.Series(index=y.index, dtype=float)

    for t in range(k + 8, len(y)):
        X_t = sm.add_constant(Xlags.iloc[:t].dropna(), has_constant="add")
        idx = X_t.index
        y_t = y.loc[idx]

        if len(y_t) >= k + 5:
            beta = sm.OLS(y_t, X_t).fit().params
            row = sm.add_constant(Xlags.iloc[t:t + 1], has_constant="add").iloc[0]
            y_hat = float((row * beta.reindex(row.index).fillna(0)).sum())
            resid.iloc[t] = y.iloc[t] - y_hat

    return resid * 100.0


def qe_flag(bank: str, year: Union[int, float]) -> int:
    if pd.isna(year):
        return 0

    y = int(year)

    if bank == "ECB":
        return int((2015 <= y <= 2018) or (2020 <= y <= 2021))
    if bank == "BoE":
        return int((2009 <= y <= 2012) or (2020 <= y <= 2021))
    if bank == "Fed":
        return int((2009 <= y <= 2014) or (2020 <= y <= 2021))

    return 0


def build_common_macro_panel(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    cfg: JournalConfig,
    elb_mode: str = "data_driven",
) -> pd.DataFrame:
    master_me = pd.date_range(month_end(cfg.AP_PRESAMPLE_START), month_end(cfg.END), freq="ME")

    rows = []
    for econ in ["EU", "UK", "US"]:
        bank = BANK_CODE_TO_NAME[econ]

        pol = raw[(econ, "POLICY")]
        inf = raw[(econ, "INF")]
        gdp = raw[(econ, "GDP")]

        m_pol = to_monthly_eom(pol.set_index("date")["value"]).reindex(master_me)
        inf_level = to_monthly_eom(inf.set_index("date")["value"], interpolate_quarterly=True).reindex(master_me)
        infl_yoy = infer_yoy_from_INF(inf_level)
        pi_log_yoy = inflation_yoy_log_from_cpi(inf_level)
        m_gdp = to_monthly_eom(gdp.set_index("date")["value"], interpolate_quarterly=True).reindex(master_me)

        tmp = pd.concat([m_pol, inf_level, infl_yoy, pi_log_yoy, m_gdp], axis=1)
        tmp.columns = ["policy_rate", "inf_level", "infl_yoy", "PI_log", "gdp"]
        tmp["bank"] = bank
        tmp["econ"] = econ
        tmp = tmp.reset_index().rename(columns={"index": "date"})
        rows.append(tmp)

    mon = pd.concat(rows, ignore_index=True).sort_values(["bank", "date"]).reset_index(drop=True)

    outs = []
    for bank, g in mon.groupby("bank", sort=False):
        gg = g.copy()
        gg["gdp"] = pd.to_numeric(gg["gdp"], errors="coerce").ffill().bfill()
        gg["log_gdp"] = np.log(gg["gdp"].clip(lower=1e-8))
        gg["output_gap"] = hamilton_output_gap(gg.set_index("date")["log_gdp"], k=cfg.HAMILTON_K).reindex(gg["date"]).values
        outs.append(gg)

    mon = pd.concat(outs, ignore_index=True).sort_values(["bank", "date"]).reset_index(drop=True)

    mon["inflation_gap"] = pd.to_numeric(mon["infl_yoy"], errors="coerce") - cfg.PI_STAR
    mon["year"] = mon["date"].dt.year
    mon["month"] = mon["date"].dt.month
    mon["ym"] = mon["date"].dt.to_period("M")

    mon["crisis10"] = mon["year"].between(2010, 2012).astype(int)
    mon["pandem"] = mon["year"].between(2020, 2021).astype(int)
    mon["QE_FG"] = mon.apply(lambda r: qe_flag(r["bank"], r["year"]), axis=1).astype(int)

    if elb_mode == "data_driven":
        def _elb_transform(s: pd.Series) -> pd.Series:
            x = pd.to_numeric(s, errors="coerce")
            roll_min = x.rolling(24, min_periods=24).min()
            return (x <= (roll_min + cfg.ELB_EPS)).astype(int)

        mon["ELB"] = (
            mon.groupby("bank", group_keys=False)["policy_rate"]
            .transform(_elb_transform)
            .astype(int)
        )
    else:
        mon["ELB"] = mon.apply(
            lambda r: int(r["policy_rate"] <= cfg.ELB_THRESHOLDS.get(str(r["bank"]), 0.25)),
            axis=1,
        ).astype(int)

    mon["policy_rate_lead3"] = mon.groupby("bank")["policy_rate"].shift(-3)
    mon["di"] = mon.groupby("bank")["policy_rate"].diff()
    mon["abs_deltai_3m"] = (mon["policy_rate_lead3"] - mon["policy_rate"]).abs()
    mon["abs_deltai_3m_lag"] = mon.groupby("bank")["abs_deltai_3m"].shift(1)

    mon["abs_pi_gap"] = mon["inflation_gap"].abs()
    mon["abs_y_gap"] = mon["output_gap"].abs()
    den = mon["abs_pi_gap"] + mon["abs_y_gap"]
    mon["pi_share"] = np.where(den > 0, mon["abs_pi_gap"] / den, np.nan)

    return mon


def build_shadow_rate_wide(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    cfg: JournalConfig,
) -> pd.DataFrame:
    idx = pd.date_range(month_end(cfg.REPORTED_START), month_end(cfg.END), freq="ME")
    out = {}

    for econ in ["US", "EU", "UK"]:
        sr = raw[(econ, "SR")]
        out[econ] = to_monthly_eom(sr.set_index("date")["value"]).reindex(idx)

    return pd.DataFrame(out).sort_index()


def t5y5y_monthly_eom(t5y5y_daily: pd.Series) -> pd.Series:
    s = pd.Series(t5y5y_daily).copy()
    if not isinstance(s.index, pd.DatetimeIndex):
        s.index = pd.to_datetime(s.index, errors="coerce")
    s = pd.to_numeric(s, errors="coerce")
    s = s.dropna().sort_index()
    return s.resample("ME").last().rename("t5y5y")


def macro_backbone_audit(panel: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for bank, g in panel.groupby("bank"):
        for c in [
            "policy_rate",
            "inf_level",
            "infl_yoy",
            "PI_log",
            "gdp",
            "output_gap",
            "inflation_gap",
            "ELB",
            "pi_share",
        ]:
            s = g[c] if c in g.columns else pd.Series(dtype=float)
            rows.append(
                {
                    "bank": bank,
                    "series": c,
                    "nonmissing": int(s.notna().sum()),
                    "start": g.loc[s.notna(), "date"].min() if s.notna().any() else pd.NaT,
                    "end": g.loc[s.notna(), "date"].max() if s.notna().any() else pd.NaT,
                    "min": float(pd.to_numeric(s, errors="coerce").min()) if s.notna().any() else np.nan,
                    "max": float(pd.to_numeric(s, errors="coerce").max()) if s.notna().any() else np.nan,
                }
            )
    return pd.DataFrame(rows)


def estimate_reaction_function_realtime(mon: pd.DataFrame, window: int = 60) -> pd.DataFrame:
    Z = ["inflation_gap", "output_gap", "ELB", "QE_FG", "crisis10", "pandem", "di_lag"]
    out = []

    for bank, g in mon.sort_values(["bank", "date"]).groupby("bank"):
        z = g.copy()
        z["di_lag"] = z["di"].shift(1)
        z = z.dropna(subset=["di"] + Z)
        if z.empty:
            continue

        names = ["const"] + Z
        di_hat = []

        for i in range(len(z)):
            lo = max(0, i - window)
            sub = z.iloc[lo:i]

            if len(sub) < max(24, len(Z) + 5):
                di_hat.append(np.nan)
                continue

            X = pd.DataFrame({"const": 1.0}, index=sub.index)
            for c in Z:
                X[c] = pd.to_numeric(sub[c], errors="coerce").astype(float)

            res = sm.OLS(pd.to_numeric(sub["di"], errors="coerce").astype(float), X).fit()

            x_now = pd.Series({"const": 1.0}, dtype=float)
            for c in Z:
                x_now[c] = float(z.iloc[i][c])

            di_hat.append(float((x_now[names] * res.params.reindex(names).fillna(0)).sum()))

        z["di_hat_rt"] = di_hat
        z["di_surpr_rt"] = z["di"] - z["di_hat_rt"]
        out.append(z[["date", "bank", "di_hat_rt", "di_surpr_rt"]])

    if not out:
        return pd.DataFrame(columns=["date", "bank", "di_hat_rt", "di_surpr_rt"])

    return pd.concat(out, ignore_index=True)


def build_surprise_h_rt(mon: pd.DataFrame, h: int = 3) -> pd.DataFrame:
    if h != 3:
        raise ValueError("Original First Credibility Metric is centered AP(3). Use h=3.")

    z = mon.sort_values(["bank", "date"]).copy()

    u_lag1 = z.groupby("bank")["di_surpr_rt"].shift(1)
    u_now = z.groupby("bank")["di_surpr_rt"].shift(0)
    u_lead1 = z.groupby("bank")["di_surpr_rt"].shift(-1)

    z["cum_surpr_3_rt"] = pd.concat([u_lag1, u_now, u_lead1], axis=1).sum(axis=1, min_count=3)
    z["abs_surprise_rel_3_rt"] = z["cum_surpr_3_rt"].abs()
    return z


def rf_params_rt(mon: pd.DataFrame, window: int = 60) -> pd.DataFrame:
    Z = ["inflation_gap", "output_gap", "ELB", "QE_FG", "crisis10", "pandem", "di_lag"]
    out = []

    for bank, g in mon.sort_values(["bank", "date"]).groupby("bank"):
        z = g.copy()
        z["di_lag"] = z["di"].shift(1)
        z = z.dropna(subset=["di"] + Z)

        phi_pi, phi_y = [], []
        for i in range(len(z)):
            lo = max(0, i - window)
            sub = z.iloc[lo:i]
            if len(sub) < max(24, len(Z) + 5):
                phi_pi.append(np.nan)
                phi_y.append(np.nan)
                continue

            X = pd.DataFrame({"const": 1.0}, index=sub.index)
            for c in Z:
                X[c] = pd.to_numeric(sub[c], errors="coerce").astype(float)

            params = sm.OLS(pd.to_numeric(sub["di"], errors="coerce").astype(float), X).fit().params
            phi_pi.append(float(params.get("inflation_gap", np.nan)))
            phi_y.append(float(params.get("output_gap", np.nan)))

        tmp = z[["date"]].copy()
        tmp["bank"] = bank
        tmp["phi_pi_rt"] = phi_pi
        tmp["phi_y_rt"] = phi_y
        den = np.abs(tmp["phi_pi_rt"]) + np.abs(tmp["phi_y_rt"])
        tmp["omega_t_rt"] = np.where(den > 0, np.abs(tmp["phi_pi_rt"]) / den, np.nan)
        out.append(tmp)

    return pd.concat(out, ignore_index=True) if out else pd.DataFrame()


def cv_select_rf_window_rt(mon: pd.DataFrame, cand: Sequence[int]) -> pd.DataFrame:
    rows = []
    for w in cand:
        rf = estimate_reaction_function_realtime(mon, window=w)
        z = mon.merge(rf, on=["bank", "date"], how="left")
        mse = np.nanmean(z["di_surpr_rt"] ** 2)
        rows.append(
            {
                "window": int(w),
                "mse": float(mse) if np.isfinite(mse) else np.inf,
                "n_surprise": int(z["di_surpr_rt"].notna().sum()),
            }
        )

    return pd.DataFrame(rows).sort_values(["mse", "n_surprise"], ascending=[True, False]).reset_index(drop=True)


def plot_ap3_credibility_score(z_reported: pd.DataFrame, cfg: JournalConfig) -> None:
    if not cfg.PLOTS:
        return

    show_heading("Figure 1A. First Credibility Score")
    fig, axes = plt.subplots(3, 1, figsize=(11, 9), sharex=True)

    for ax, bank in zip(axes, BANK_ORDER):
        g = z_reported[z_reported["bank"] == bank].dropna(subset=["cred_ap3_score"]).copy()
        if g.empty:
            ax.set_visible(False)
            continue
        ax.plot(g["date"], g["cred_ap3_score"])
        ax.set_title(f"First Credibility Metric — {bank}")
        ax.set_ylabel("Credibility")
        ax.set_xlim(month_end(cfg.REPORTED_START), month_end(cfg.END))
        ax.set_ylim(0, 100)
        ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.4)

    axes[-1].set_xlabel("Date")
    fig.tight_layout()
    save_fig(
        fig,
        Path(cfg.RESULTS_DIR) / "figure_first_credibility_score.png",
        cfg.SAVE_FIGURES,
    )


def build_ap3_measure(common_panel: pd.DataFrame, cfg: JournalConfig) -> Dict[str, object]:
    backbone = common_panel.copy()

    cv_table = cv_select_rf_window_rt(backbone, cfg.RF_WINDOW_CAND)
    best_w = int(cv_table.iloc[0]["window"])

    rf = estimate_reaction_function_realtime(backbone, window=best_w)
    mon = merge_no_overlap(backbone, rf, on=["bank", "date"], suffix="_rf", validate="one_to_one")

    if "di_surpr_rt_rf" in mon.columns:
        mon["di_surpr_rt"] = mon["di_surpr_rt_rf"]
    if "di_hat_rt_rf" in mon.columns:
        mon["di_hat_rt"] = mon["di_hat_rt_rf"]

    mon = build_surprise_h_rt(mon, h=3)
    mon["AP3_raw_lowcred"] = mon["abs_surprise_rel_3_rt"]
    mon["lowcred_ap3"] = mon["AP3_raw_lowcred"]

    phidf = rf_params_rt(mon, window=best_w)
    if not phidf.empty:
        mon = mon.merge(phidf, on=["bank", "date"], how="left", validate="one_to_one")

    mon_reported = mon.loc[mon["date"] >= month_end(cfg.REPORTED_START)].copy()

    mon_reported["AP3_lowcred_scaled"], ap3_scale_stats = scale_series_to_0_100(
        mon_reported["AP3_raw_lowcred"],
        p_lo=cfg.AP_SCALE_P_LO,
        p_hi=cfg.AP_SCALE_P_HI,
    )
    mon_reported["cred_ap3_score"] = 100.0 - mon_reported["AP3_lowcred_scaled"]

    mon = mon.merge(
        mon_reported[["date", "bank", "AP3_lowcred_scaled", "cred_ap3_score"]],
        on=["date", "bank"],
        how="left",
        validate="one_to_one",
    )

    plot_ap3_credibility_score(mon_reported, cfg)

    return {
        "panel_full": mon,
        "panel_reported": mon_reported,
        "rf_window_cv": cv_table,
        "best_rf_window": best_w,
        "scale_stats": ap3_scale_stats,
    }


def ensure_me(s: pd.Series) -> pd.Series:
    z = pd.Series(s).copy()
    if not isinstance(z.index, pd.DatetimeIndex):
        z.index = pd.to_datetime(z.index, errors="coerce")
    z = z[~pd.isna(z.index)]
    z.index = z.index.to_period("M").to_timestamp("M")
    z = pd.to_numeric(z, errors="coerce").sort_index()
    if z.index.has_duplicates:
        z = z.groupby(level=0).last()
    return z.asfreq("ME")


def select_ar(y: pd.Series, max_p: int = 2) -> int:
    z = ensure_me(pd.Series(y).dropna())
    best, lag, success = np.inf, 0, 0

    for p in range(max_p + 1):
        try:
            fit = smt.ARIMA(z, order=(p, 0, 0)).fit(method="innovations_mle")
            success += 1
            if fit.aic < best:
                best, lag = float(fit.aic), int(p)
        except Exception:
            continue

    if success == 0:
        logging.warning("AR lag selection failed for all p; using p=0 fallback.")

    return lag


def _fallback_vol(y: pd.Series, roll: int) -> pd.Series:
    z = ensure_me(pd.Series(y).astype(float))
    return z.rolling(roll).std(ddof=0)


def fit_egarch_t_level(
    y: pd.Series,
    lags_ar: int,
    min_T: int,
    fallback_roll: int,
):
    z = ensure_me(pd.Series(y).astype(float).dropna())

    if len(z) < min_T:
        return None, _fallback_vol(z, fallback_roll)

    mu, sd = z.mean(), z.std(ddof=0)
    if (not np.isfinite(sd)) or sd == 0:
        return None, _fallback_vol(z, fallback_roll)

    y_std = (z - mu) / sd

    try:
        am = arch_model(
            y_std,
            mean="AR",
            lags=lags_ar,
            vol="EGARCH",
            p=1,
            o=0,
            q=1,
            dist="t",
            rescale=True,
        )
        res = am.fit(disp="off", show_warning=False, options={"maxiter": 2500})
        sig = pd.Series(res.conditional_volatility, index=z.index).replace([np.inf, -np.inf], np.nan)

        if sig.isna().mean() > 0.20:
            return None, _fallback_vol(z, fallback_roll)

        return res, sig * sd

    except Exception as e:
        logging.warning(f"EGARCH failed: {e}; fallback rolling std.")
        return None, _fallback_vol(z, fallback_roll)


def fit_gjr_garch_t_level(
    y: pd.Series,
    lags_ar: int,
    min_T: int,
    fallback_roll: int,
):
    z = ensure_me(pd.Series(y).astype(float).dropna())

    if len(z) < min_T:
        return None, _fallback_vol(z, fallback_roll)

    mu, sd = z.mean(), z.std(ddof=0)
    if (not np.isfinite(sd)) or sd == 0:
        return None, _fallback_vol(z, fallback_roll)

    y_std = (z - mu) / sd

    try:
        am = arch_model(
            y_std,
            mean="AR",
            lags=lags_ar,
            vol="GARCH",
            p=1,
            o=1,
            q=1,
            dist="t",
            rescale=True,
        )
        res = am.fit(disp="off", show_warning=False, options={"maxiter": 2500})
        sig = pd.Series(res.conditional_volatility, index=z.index).replace([np.inf, -np.inf], np.nan)

        if sig.isna().mean() > 0.20:
            return None, _fallback_vol(z, fallback_roll)

        return res, sig * sd

    except Exception as e:
        logging.warning(f"GJR-GARCH failed: {e}; fallback rolling std.")
        return None, _fallback_vol(z, fallback_roll)


def plot_shadow_vol_and_cred(
    sigma_df: pd.DataFrame,
    cred_df: pd.DataFrame,
    cfg: JournalConfig,
    econ_subset: Optional[Sequence[str]] = None,
) -> None:
    if not cfg.PLOTS:
        return

    label_map = {"US": "Fed", "EU": "ECB", "UK": "BoE"}
    if econ_subset is None:
        econ_subset = ["US", "EU", "UK"]
    econ_subset = [e.upper() for e in econ_subset]

    t0 = month_end(cfg.REPORTED_START)
    t1 = month_end(cfg.END)

    fig, axes = plt.subplots(len(econ_subset), 1, figsize=(11, 9), sharex=True)
    if len(econ_subset) == 1:
        axes = [axes]

    for ax, econ in zip(axes, econ_subset):
        s = sigma_df[econ].dropna()
        s = s.loc[s.index >= t0]
        if s.empty:
            ax.set_visible(False)
            continue

        ax.plot(s.index, s.values)
        ax.set_title(f"EGARCH-t shadow-rate volatility — {label_map.get(econ, econ)}")
        ax.set_ylabel("Volatility")
        ax.set_xlim(t0, t1)
        ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.4)

    axes[-1].set_xlabel("Date")
    fig.tight_layout()
    save_fig(
        fig,
        Path(cfg.RESULTS_DIR) / "figure_shadow_volatility.png",
        cfg.SAVE_FIGURES,
    )

    fig, axes = plt.subplots(len(econ_subset), 1, figsize=(11, 9), sharex=True)
    if len(econ_subset) == 1:
        axes = [axes]

    for ax, econ in zip(axes, econ_subset):
        s = cred_df[econ].dropna()
        s = s.loc[s.index >= t0]
        if s.empty:
            ax.set_visible(False)
            continue

        ax.plot(s.index, s.values)
        ax.set_title(f"Second Credibility Score — {label_map.get(econ, econ)}")
        ax.set_ylabel("Credibility")
        ax.set_ylim(0, 100)
        ax.set_xlim(t0, t1)
        ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.4)

    axes[-1].set_xlabel("Date")
    fig.tight_layout()
    save_fig(
        fig,
        Path(cfg.RESULTS_DIR) / "figure_second_credibility_score.png",
        cfg.SAVE_FIGURES,
    )


def run_shadow_rate_measure(
    shadow_wide: pd.DataFrame,
    cfg: JournalConfig,
) -> Dict[str, object]:
    show_heading("WU & XIA SHADOW-RATE PIPELINE — SINGLE WORKBOOK")

    ar_lags: Dict[str, int] = {}
    sigma_eg: Dict[str, pd.Series] = {}
    eg_meta: Dict[str, Dict[str, object]] = {}

    for e in ["US", "EU", "UK"]:
        sr = ensure_me(shadow_wide[e]).dropna()
        p = select_ar(sr, cfg.AR_MAX)
        ar_lags[e] = int(p)

        res, sig = fit_egarch_t_level(
            sr,
            lags_ar=p,
            min_T=cfg.MIN_T,
            fallback_roll=cfg.FALLBACK_ROLL,
        )
        sigma_eg[e] = sig
        eg_meta[e] = {"ar_lags": int(p), "egarch_ok": bool(res is not None)}

    sigma_eg_df = pd.DataFrame(sigma_eg).sort_index()
    cred_eg_raw = (-np.log(sigma_eg_df.clip(lower=1e-10))).rename_axis("date")
    cred_eg_sc, anchor_stats = scale_wide_to_0_100(
        cred_eg_raw,
        cfg.ANCHOR_END,
        cfg.SHADOW_SCALE_P_LO,
        cfg.SHADOW_SCALE_P_HI,
    )

    print("\n=== EGARCH meta (baseline SR-level) ===")
    print(pd.DataFrame(eg_meta).T)

    print("\n=== Anchor stats (pooled scaling) ===")
    print(anchor_stats)

    sigma_gjr: Dict[str, pd.Series] = {}
    gjr_meta: Dict[str, Dict[str, object]] = {}

    for e in ["US", "EU", "UK"]:
        sr = ensure_me(shadow_wide[e]).dropna()
        p = ar_lags.get(e, select_ar(sr, cfg.AR_MAX))

        res, sig = fit_gjr_garch_t_level(
            sr,
            lags_ar=p,
            min_T=cfg.MIN_T,
            fallback_roll=cfg.FALLBACK_ROLL,
        )
        sigma_gjr[e] = sig
        gjr_meta[e] = {"ar_lags": int(p), "gjr_ok": bool(res is not None)}

    sigma_gjr_df = pd.DataFrame(sigma_gjr).sort_index()
    cred_gjr_raw = (-np.log(sigma_gjr_df.clip(lower=1e-10))).rename_axis("date")
    cred_gjr_sc, _ = scale_wide_to_0_100(
        cred_gjr_raw,
        cfg.ANCHOR_END,
        cfg.SHADOW_SCALE_P_LO,
        cfg.SHADOW_SCALE_P_HI,
    )

    rows = []
    for e in ["US", "EU", "UK"]:
        tmp = pd.concat(
            [cred_eg_sc[e].rename("egarch"), cred_gjr_sc[e].rename("gjr")],
            axis=1,
        ).dropna()
        rows.append(
            [
                e,
                float(tmp["egarch"].corr(tmp["gjr"])) if len(tmp) > 5 else np.nan,
                int(len(tmp)),
            ]
        )

    pooled = pd.concat(
        [cred_eg_sc.stack().rename("egarch"), cred_gjr_sc.stack().rename("gjr")],
        axis=1,
    ).dropna()

    print("\n=== Robustness: baseline EGARCH credibility vs GJR-GARCH credibility ===")
    print(pd.DataFrame(rows, columns=["econ", "corr(egarch,gjr)", "T_common"]).to_string(index=False))
    print(f"Pooled corr(egarch,gjr) = {float(pooled['egarch'].corr(pooled['gjr'])):.3f} (N={len(pooled)})")
    print("\n=== GJR meta ===")
    print(pd.DataFrame(gjr_meta).T)

    plot_shadow_vol_and_cred(sigma_eg_df, cred_eg_sc, cfg)

    return {
        "sigma_eg": sigma_eg_df,
        "cred_eg_raw": cred_eg_raw,
        "cred_eg_sc": cred_eg_sc,
        "eg_meta": pd.DataFrame(eg_meta).T,
        "anchor_stats": anchor_stats,
        "sigma_gjr": sigma_gjr_df,
        "cred_gjr_raw": cred_gjr_raw,
        "cred_gjr_sc": cred_gjr_sc,
        "gjr_meta": pd.DataFrame(gjr_meta).T,
        "gjr_corr_by_econ": pd.DataFrame(rows, columns=["econ", "corr(egarch,gjr)", "T_common"]),
        "gjr_corr_pooled": float(pooled["egarch"].corr(pooled["gjr"])) if len(pooled) > 0 else np.nan,
    }


def sacrifice_ratio(
    pi: pd.Series,
    gap: pd.Series,
    H: int,
    min_abs_dpi: float,
    winsor_pcts: Tuple[float, float],
) -> pd.Series:
    pi = ensure_me(pi).astype(float).sort_index()
    gap = ensure_me(gap).astype(float).sort_index()

    cost_pm = gap.clip(upper=0).abs().rolling(H, min_periods=H).sum()
    cost_py = cost_pm / 12.0
    dpi = pi - pi.shift(H)
    sr = (cost_py / dpi.abs()).where(dpi < -min_abs_dpi)

    return winsorize(sr, winsor_pcts).rename("SR")


def run_sr_reg_hac_only(
    sr_panel_full: pd.DataFrame,
    cred_col: str,
    H: int,
    L: int,
    analysis_start: Optional[str] = None,
):
    df = sr_panel_full.copy().sort_values(["econ", "date"])

    df[f"cred_lag{L}"] = df.groupby("econ")[cred_col].shift(L)

    if analysis_start is not None:
        df = df[df["date"] >= pd.Timestamp(analysis_start)].copy()

    use = df[["SR", f"cred_lag{L}", "econ"]].dropna().copy()

    D = pd.get_dummies(use["econ"], prefix="ent", drop_first=True, dtype=int)
    X = pd.concat([use[[f"cred_lag{L}"]], D], axis=1)
    X = sm.add_constant(X, has_constant="add")
    y = use["SR"]

    res_hac = sm.OLS(y, X).fit(cov_type="HAC", cov_kwds={"maxlags": H})
    return res_hac, int(res_hac.nobs), use


def coef_line(res, var: str) -> Tuple[float, float, float]:
    b = float(res.params.get(var, np.nan))
    se = float(res.bse.get(var, np.nan))
    p = float(res.pvalues.get(var, np.nan))
    return b, se, p


def run_sacrifice_ratio_validation(
    common_panel: pd.DataFrame,
    cred_eg_raw: pd.DataFrame,
    cfg: JournalConfig,
) -> Dict[str, object]:
    sr_rows = []

    for econ in ["US", "EU", "UK"]:
        bank = BANK_CODE_TO_NAME[econ]
        sub = common_panel[common_panel["bank"] == bank].sort_values("date").copy()
        sub_idx = sub.set_index("date")

        srH = sacrifice_ratio(
            pi=sub_idx["PI_log"],
            gap=sub_idx["output_gap"],
            H=cfg.SR_H,
            min_abs_dpi=cfg.MIN_ABS_DPI,
            winsor_pcts=cfg.WINSOR_PCTS,
        )

        tmp = pd.DataFrame({"date": srH.index, "econ": econ, "SR": srH.values})
        sr_rows.append(tmp)

    sr_panel = pd.concat(sr_rows, axis=0).sort_values(["econ", "date"]).reset_index(drop=True)

    cred_long = cred_eg_raw.copy()
    cred_long.index = pd.to_datetime(cred_long.index).to_period("M").to_timestamp("M")
    cred_long = cred_long.stack().rename("cred_eg_raw").reset_index()
    cred_long.columns = ["date", "econ", "cred_eg_raw"]

    sr_panel_full = (
        sr_panel.merge(cred_long, on=["date", "econ"], how="left", validate="one_to_one")
        .sort_values(["econ", "date"])
        .reset_index(drop=True)
    )

    H = cfg.SR_H
    L = cfg.SR_LAG
    xname = f"cred_lag{L}"

    res_hac_eg, N_eg, use = run_sr_reg_hac_only(
        sr_panel_full,
        cred_col="cred_eg_raw",
        H=H,
        L=L,
        analysis_start=cfg.REPORTED_START,
    )

    print("\n==================== SACRIFICE RATIO REGRESSION (WX only) ====================")
    print(f"Model: SR_H{H} ~ const + cred(t-{L}) + country dummies (pooled)")
    print("Notes: SR uses overlapping windows; HAC(maxlags=H) is conservative under persistence.")
    print("Credibility lag is computed on the full monthly panel before SR missing windows are dropped.\n")

    b, se, p = coef_line(res_hac_eg, xname)
    print(f"[Baseline cred = EGARCH] HAC: b={b:.4f}, se={se:.4f}, p={p:.4f} | N={N_eg} | maxlags={H}")

    print("\n--- EGARCH credibility regression table (HAC) ---")
    print(res_hac_eg.summary().tables[1])

    return {
        "sr_panel_full": sr_panel_full,
        "sr_reg_use": use,
        "res_hac_eg": res_hac_eg,
        "N_eg": N_eg,
    }


def fe_ols(
    y: str,
    X: Sequence[str],
    data: pd.DataFrame,
    bank_fe: bool = True,
    year_fe: bool = False,
    month_fe: bool = False,
    bank_year_fe: bool = False,
    hac_lags: Optional[int] = None,
):
    if bank_year_fe:
        bank_fe = False

    z = data.copy()
    X_df = pd.DataFrame(index=z.index)
    X_df["const"] = 1.0

    for name in X:
        X_df[name] = pd.to_numeric(z[name], errors="coerce")

    if bank_fe and "bank" in z.columns:
        d = pd.get_dummies(z["bank"], prefix="", prefix_sep="", drop_first=True).astype(float)
        X_df = pd.concat([X_df, d], axis=1)

    if bank_year_fe and ("bank" in z.columns) and ("year" in z.columns):
        by = z["bank"].astype(str) + "_" + z["year"].astype(str)
        d = pd.get_dummies(by, prefix="by", drop_first=True).astype(float)
        X_df = pd.concat([X_df, d], axis=1)
    else:
        if year_fe and "year" in z.columns:
            d = pd.get_dummies(z["year"], prefix="y", drop_first=True).astype(float)
            X_df = pd.concat([X_df, d], axis=1)

    if month_fe and "month" in z.columns:
        d = pd.get_dummies(z["month"], prefix="m", drop_first=True).astype(float)
        X_df = pd.concat([X_df, d], axis=1)

    X_df = X_df.apply(pd.to_numeric, errors="coerce").replace([np.inf, -np.inf], np.nan)
    X_df = X_df.loc[:, X_df.notna().any(axis=0)]

    yv = pd.to_numeric(z[y], errors="coerce").replace([np.inf, -np.inf], np.nan)
    mask = yv.notna() & X_df.notna().all(axis=1)
    X_df = X_df.loc[mask].astype(float)
    yv = yv.loc[mask].astype(float)

    if X_df.empty or yv.empty:
        raise ValueError("Empty design after NA drop.")

    res = sm.OLS(yv, X_df).fit(
        cov_type="HAC",
        cov_kwds={"maxlags": hac_lags or CFG.HAC_LAGS_BASE},
    )
    res._index = X_df.index.copy()
    return res


def _cov_as_df(res) -> pd.DataFrame:
    cov = res.cov_params()
    if isinstance(cov, pd.DataFrame):
        return cov
    names = res.model.exog_names
    return pd.DataFrame(np.asarray(cov, dtype=float), index=names, columns=names)


def twoway_cluster_se(
    res_ols,
    groups1: Union[pd.Series, np.ndarray],
    groups2: Union[pd.Series, np.ndarray],
) -> Dict[str, pd.Series]:
    g1 = pd.Series(groups1).astype(str).loc[res_ols._index]
    g2 = pd.Series(groups2).astype(str).loc[res_ols._index]
    g12 = g1 + "×" + g2

    r1 = res_ols.get_robustcov_results(cov_type="cluster", groups=g1)
    r2 = res_ols.get_robustcov_results(cov_type="cluster", groups=g2)
    r12 = res_ols.get_robustcov_results(cov_type="cluster", groups=g12)

    names = res_ols.model.exog_names
    k = len(names)

    def fix(A):
        A = np.asarray(A, dtype=float)
        if A.shape != (k, k):
            A = np.resize(A, (k, k))
        return A

    C1 = fix(r1.cov_params())
    C2 = fix(r2.cov_params())
    C12 = fix(r12.cov_params())

    cov_tw = pd.DataFrame(C1 + C2 - C12, index=names, columns=names)
    se = pd.Series(np.sqrt(np.maximum(np.diag(cov_tw), 0.0)), index=names, name="se")
    params = params_as_series(res_ols)
    tstat = params / se.replace(0.0, np.nan)
    pval = pd.Series(2 * (1 - norm.cdf(np.abs(tstat.values))), index=names, name="p")

    return {"se": se, "t": tstat, "p": pval}


def wild_cluster_bootstrap_pvalue(
    X: np.ndarray,
    y: np.ndarray,
    res,
    groups: Union[pd.Series, np.ndarray],
    param_name: str,
    B: int = 399,
    seed: int = 123,
) -> float:
    rng = np.random.default_rng(seed)

    X = np.asarray(X, dtype=float)
    y = np.asarray(y, dtype=float).reshape(-1)

    groups = pd.Series(groups).astype(str).reset_index(drop=True)
    uniq = groups.unique()

    names = list(res.model.exog_names)
    if param_name not in names:
        return np.nan
    idx = names.index(param_name)

    params = np.asarray(res.params, dtype=float).copy()
    bse = np.asarray(res.bse, dtype=float)

    if idx >= len(params) or idx >= len(bse):
        return np.nan
    if not np.isfinite(bse[idx]) or bse[idx] == 0:
        return np.nan

    t_obs = float(params[idx] / bse[idx])

    b0 = params.copy()
    b0[idx] = 0.0
    yhat0 = X @ b0
    resid_restricted = y - yhat0

    count = 0
    for _ in range(B):
        gsign = pd.Series({g: (1.0 if rng.random() < 0.5 else -1.0) for g in uniq})
        mult = groups.map(gsign).to_numpy(dtype=float)
        y_star = yhat0 + resid_restricted * mult

        try:
            res_b = sm.OLS(y_star, X).fit()
            rb = np.asarray(res_b.bse, dtype=float)
            rp = np.asarray(res_b.params, dtype=float)
            if idx < len(rp) and idx < len(rb):
                if rb[idx] != 0 and np.isfinite(rb[idx]):
                    t_b = float(rp[idx] / rb[idx])
                    if np.isfinite(t_b) and abs(t_b) >= abs(t_obs):
                        count += 1
        except Exception:
            continue

    return (count + 1) / (B + 1)


def safe_wild_boot(res, df_used: pd.DataFrame, param_name: str, cluster_col: str = "ym") -> float:
    try:
        Xmat = pd.DataFrame(res.model.exog, columns=res.model.exog_names).values
        yvec = pd.Series(res.model.endog).values
        groups = df_used.loc[res._index, cluster_col].astype(str)
        return float(
            wild_cluster_bootstrap_pvalue(
                Xmat,
                yvec,
                res,
                groups,
                param_name,
                B=CFG.WILD_BOOT_B,
                seed=CFG.SEED,
            )
        )
    except Exception:
        return np.nan


def report_with_twocluster(
    name: str,
    res,
    df_used: pd.DataFrame,
    key_params: Sequence[str],
    cluster1: str = "bank",
    cluster2: str = "ym",
    wild_for: Optional[Union[str, Sequence[str]]] = None,
) -> None:
    print(f"\n[{name}] two-way cluster results")
    tw = twoway_cluster_se(
        res,
        df_used.loc[res._index, cluster1],
        df_used.loc[res._index, cluster2].astype(str),
    )

    for p in key_params:
        t_tw = float(tw["t"].get(p, np.nan))
        p_tw = float(tw["p"].get(p, np.nan))
        print(f"{p:<25} t_tw={t_tw:8.3f}  p_tw={p_tw:0.3f}")

    if wild_for is None:
        wild_list = []
    elif isinstance(wild_for, str):
        wild_list = [wild_for]
    else:
        wild_list = list(wild_for)

    for wf in wild_list:
        p_boot = safe_wild_boot(res, df_used, wf, cluster_col=cluster2)
        print(f"[wild-cluster by {cluster2}] {wf}: p_boot={p_boot:0.3f}")


def make_reg_table(res, var_order: Sequence[str], spec_name: str) -> pd.DataFrame:
    ci = res.conf_int()
    rows = []

    for v in var_order:
        rows.append(
            {
                "spec": spec_name,
                "variable": v,
                "coef": float(params_as_series(res).get(v, np.nan)),
                "se_hac": float(bse_as_series(res).get(v, np.nan)),
                "t_hac": float(pd.Series(res.tvalues, index=res.model.exog_names).get(v, np.nan)),
                "p_hac": float(pvalues_as_series(res).get(v, np.nan)),
                "ci_low": float(ci.loc[v, 0]) if v in ci.index else np.nan,
                "ci_high": float(ci.loc[v, 1]) if v in ci.index else np.nan,
            }
        )

    return pd.DataFrame(rows)


def make_inference_table(
    res,
    df_used: pd.DataFrame,
    spec_name: str,
    params: Sequence[str],
    boot_params: Optional[Sequence[str]] = None,
) -> pd.DataFrame:
    tw = twoway_cluster_se(
        res,
        df_used.loc[res._index, "bank"],
        df_used.loc[res._index, "ym"].astype(str),
    )

    rows = []
    for p in params:
        rows.append(
            {
                "spec": spec_name,
                "param": p,
                "coef": float(params_as_series(res).get(p, np.nan)),
                "se_hac": float(bse_as_series(res).get(p, np.nan)),
                "p_hac": float(pvalues_as_series(res).get(p, np.nan)),
                "se_tw": float(tw["se"].get(p, np.nan)),
                "p_tw": float(tw["p"].get(p, np.nan)),
                "p_boot": float(safe_wild_boot(res, df_used, p)) if (boot_params and p in boot_params) else np.nan,
            }
        )

    return pd.DataFrame(rows)


def combined_effect_table(
    res,
    df_used: pd.DataFrame,
    base_var: str,
    interaction_var: str,
    spec_name: str,
) -> pd.DataFrame:
    b = params_as_series(res)
    cov = _cov_as_df(res)

    if base_var not in cov.index or interaction_var not in cov.columns:
        return pd.DataFrame()

    base = float(b.get(base_var, np.nan))
    inter = float(b.get(interaction_var, np.nan))

    v_base = float(cov.loc[base_var, base_var])
    v_inter = float(cov.loc[interaction_var, interaction_var])
    c_bi = float(cov.loc[base_var, interaction_var])

    beta_non = base
    se_non = np.sqrt(max(v_base, 0.0))
    t_non = beta_non / se_non if se_non > 0 else np.nan
    p_non = 2 * (1 - norm.cdf(abs(t_non))) if np.isfinite(t_non) else np.nan

    beta_elb = base + inter
    var_elb = v_base + v_inter + 2 * c_bi
    se_elb = np.sqrt(max(var_elb, 0.0))
    t_elb = beta_elb / se_elb if se_elb > 0 else np.nan
    p_elb = 2 * (1 - norm.cdf(abs(t_elb))) if np.isfinite(t_elb) else np.nan

    beta_diff = inter
    se_diff = np.sqrt(max(v_inter, 0.0))
    t_diff = beta_diff / se_diff if se_diff > 0 else np.nan
    p_diff = 2 * (1 - norm.cdf(abs(t_diff))) if np.isfinite(t_diff) else np.nan

    return pd.DataFrame(
        [
            {
                "spec": spec_name,
                "effect": f"{base_var} in non-ELB",
                "coef": beta_non,
                "se_hac": se_non,
                "p_hac": p_non,
                "p_boot": np.nan,
            },
            {
                "spec": spec_name,
                "effect": f"{base_var} in ELB",
                "coef": beta_elb,
                "se_hac": se_elb,
                "p_hac": p_elb,
                "p_boot": np.nan,
            },
            {
                "spec": spec_name,
                "effect": "ELB minus non-ELB",
                "coef": beta_diff,
                "se_hac": se_diff,
                "p_hac": p_diff,
                "p_boot": safe_wild_boot(res, df_used, interaction_var),
            },
        ]
    )


def prepare_lowcred_regression_panel(
    panel: pd.DataFrame,
    y_col: str,
    reported_start: str,
) -> pd.DataFrame:
    z = panel.copy()
    z = z.loc[z["date"] >= month_end(reported_start)].copy()

    z["p_share_F"] = z["pi_share"]
    z["p_share_F_x_ELB"] = z["p_share_F"] * z["ELB"]

    z["abs_infl_gap"] = z["inflation_gap"].abs()
    z["miss_streak_24m"] = z.groupby("bank")["abs_infl_gap"].transform(
        lambda s: s.rolling(24, min_periods=6).mean()
    )
    z["abs_infl_gap_x_ELB"] = z["abs_infl_gap"] * z["ELB"]
    z["miss_streak_24m_x_ELB"] = z["miss_streak_24m"] * z["ELB"]

    z["abs_deltai_3_lag"] = z["abs_deltai_3m_lag"]

    z["year"] = z["date"].dt.year
    z["month"] = z["date"].dt.month
    z["ym"] = z["date"].dt.to_period("M")

    if y_col not in z.columns:
        raise KeyError(f"{y_col} not found in regression panel.")

    return z


def build_shadow_determinants_panel(
    common_panel: pd.DataFrame,
    cred_eg_raw: pd.DataFrame,
    cfg: JournalConfig,
) -> pd.DataFrame:
    cred_long = cred_eg_raw.copy()
    cred_long.index = pd.to_datetime(cred_long.index).to_period("M").to_timestamp("M")
    cred_long = cred_long.stack().rename("cred_eg_raw").reset_index()
    cred_long.columns = ["date", "econ", "cred_eg_raw"]
    cred_long["bank"] = cred_long["econ"].map(BANK_CODE_TO_NAME)

    z = common_panel.merge(
        cred_long[["date", "bank", "cred_eg_raw"]],
        on=["date", "bank"],
        how="left",
        validate="one_to_one",
    ).sort_values(["bank", "date"])

    z["neg_cred_eg_raw"] = -pd.to_numeric(z["cred_eg_raw"], errors="coerce")

    return prepare_lowcred_regression_panel(
        z,
        y_col="neg_cred_eg_raw",
        reported_start=cfg.REPORTED_START,
    )


def run_workhorse_determinants(
    panel: pd.DataFrame,
    yname: str,
    label_prefix: str,
    heading: str,
    cfg: JournalConfig,
) -> Dict[str, pd.DataFrame]:
    hac_lags = max(cfg.HAC_LAGS_BASE, 2)
    coef_tables = []
    inf_tables = []
    combo_tables = []

    print("\n" + "=" * 100)
    print(heading)
    print("=" * 100)
    print(f"LHS: {yname}")
    print("Interpretation: larger LHS = lower credibility.\n")

    print("-" * 78)
    print("Outcome-based p-share: pooled + ELB interaction")
    print("-" * 78)

    reg_Outcome_based_p_share = panel.copy()
    reg_Outcome_based_p_share = winsorize_df(
        reg_Outcome_based_p_share,
        [c for c in [yname, "p_share_F"] if c in reg_Outcome_based_p_share.columns],
        p=0.01,
    )
    reg_Outcome_based_p_share = reg_Outcome_based_p_share.dropna(
        subset=[yname, "p_share_F", "abs_deltai_3_lag", "ELB", "QE_FG", "crisis10", "pandem"]
    ).copy()

    X_Outcome_based_p_share_pool = ["p_share_F", "ELB", "QE_FG", "crisis10", "pandem", "abs_deltai_3_lag"]
    res_Outcome_based_p_share_pool = fe_ols(
        yname,
        X_Outcome_based_p_share_pool,
        reg_Outcome_based_p_share,
        bank_fe=False,
        bank_year_fe=True,
        month_fe=True,
        hac_lags=hac_lags,
    )

    print("\n[Outcome-based p-share: NO interaction]")
    print(res_Outcome_based_p_share_pool.summary().tables[1])
    report_with_twocluster(
        f"{label_prefix} Outcome-based p-share pooled",
        res_Outcome_based_p_share_pool,
        reg_Outcome_based_p_share,
        ["p_share_F", "ELB"],
        cluster1="bank",
        cluster2="ym",
        wild_for="p_share_F",
    )

    coef_tables.append(make_reg_table(
        res_Outcome_based_p_share_pool,
        X_Outcome_based_p_share_pool,
        f"{label_prefix}_Outcome_based_p-share_pooled",
    ))
    inf_tables.append(make_inference_table(
        res_Outcome_based_p_share_pool,
        reg_Outcome_based_p_share,
        f"{label_prefix}_Outcome_based_p-share_pooled",
        ["p_share_F", "ELB"],
        ["p_share_F"],
    ))

    X_Outcome_based_p_share_reg = ["p_share_F", "ELB", "p_share_F_x_ELB", "QE_FG", "crisis10", "pandem", "abs_deltai_3_lag"]
    res_Outcome_based_p_share_reg = fe_ols(
        yname,
        X_Outcome_based_p_share_reg,
        reg_Outcome_based_p_share,
        bank_fe=False,
        bank_year_fe=True,
        month_fe=True,
        hac_lags=hac_lags,
    )

    print("\n[Outcome-based p-share with ELB interaction]")
    print(res_Outcome_based_p_share_reg.summary().tables[1])
    report_with_twocluster(
        f"{label_prefix} Outcome-based p-share",
        res_Outcome_based_p_share_reg,
        reg_Outcome_based_p_share,
        ["p_share_F", "p_share_F_x_ELB", "ELB"],
        cluster1="bank",
        cluster2="ym",
        wild_for=["p_share_F", "p_share_F_x_ELB"],
    )

    coef_tables.append(make_reg_table(
        res_Outcome_based_p_share_reg,
        X_Outcome_based_p_share_reg,
        f"{label_prefix}_Outcome-based_p-share_regime",
    ))
    inf_tables.append(make_inference_table(
        res_Outcome_based_p_share_reg,
        reg_Outcome_based_p_share,
        f"{label_prefix}_Outcome_based_p-share_regime",
        ["p_share_F", "p_share_F_x_ELB", "ELB"],
        ["p_share_F", "p_share_F_x_ELB"],
    ))
    combo_tables.append(combined_effect_table(
        res_Outcome_based_p_share_reg,
        reg_Outcome_based_p_share,
        "p_share_F",
        "p_share_F_x_ELB",
        f"{label_prefix}_Outcome-based_p-share_regime",
    ))

    print("\n" + "-" * 78)
    print("Inflation performance: pooled + ELB interactions")
    print("-" * 78)

    reg_Inflation_performance = panel.copy()
    reg_Inflation_performance = winsorize_df(
        reg_Inflation_performance,
        [c for c in [yname, "abs_infl_gap", "miss_streak_24m"] if c in reg_Inflation_performance.columns],
        p=0.01,
    )
    reg_Inflation_performance = reg_Inflation_performance.dropna(
        subset=[yname, "abs_infl_gap", "miss_streak_24m", "output_gap", "ELB", "QE_FG", "crisis10", "pandem"]
    ).copy()

    X_Inflation_performance_pool = ["abs_infl_gap", "miss_streak_24m", "output_gap", "ELB", "QE_FG", "crisis10", "pandem"]
    res_Inflation_performance_pool = fe_ols(
        yname,
        X_Inflation_performance_pool,
        reg_Inflation_performance,
        bank_fe=False,
        bank_year_fe=True,
        month_fe=True,
        hac_lags=hac_lags,
    )

    print("\n[Inflation performance pooled: levels-only]")
    print(res_Inflation_performance_pool.summary().tables[1])
    report_with_twocluster(
        f"{label_prefix} Inflation performance pooled",
        res_Inflation_performance_pool,
        reg_Inflation_performance,
        ["abs_infl_gap", "miss_streak_24m"],
        cluster1="bank",
        cluster2="ym",
        wild_for=["abs_infl_gap", "miss_streak_24m"],
    )

    coef_tables.append(make_reg_table(
        res_Inflation_performance_pool,
        X_Inflation_performance_pool,
        f"{label_prefix}_Inflation_performance_pooled",
    ))
    inf_tables.append(make_inference_table(
        res_Inflation_performance_pool,
        reg_Inflation_performance,
        f"{label_prefix}_Inflation_performance_pooled",
        ["abs_infl_gap", "miss_streak_24m"],
        ["abs_infl_gap", "miss_streak_24m"],
    ))

    X_Inflation_performance_reg = [
        "abs_infl_gap",
        "abs_infl_gap_x_ELB",
        "miss_streak_24m",
        "miss_streak_24m_x_ELB",
        "output_gap",
        "ELB",
        "QE_FG",
        "crisis10",
        "pandem",
    ]
    res_Inflation_performance_reg = fe_ols(
        yname,
        X_Inflation_performance_reg,
        reg_Inflation_performance,
        bank_fe=False,
        bank_year_fe=True,
        month_fe=True,
        hac_lags=hac_lags,
    )

    print("\n[Inflation performance with ELB interactions]")
    print(res_Inflation_performance_reg.summary().tables[1])
    report_with_twocluster(
        f"{label_prefix} Inflation performance",
        res_Inflation_performance_reg,
        reg_Inflation_performance,
        ["abs_infl_gap", "abs_infl_gap_x_ELB", "miss_streak_24m", "miss_streak_24m_x_ELB"],
        cluster1="bank",
        cluster2="ym",
        wild_for=["abs_infl_gap", "abs_infl_gap_x_ELB", "miss_streak_24m", "miss_streak_24m_x_ELB"],
    )

    coef_tables.append(make_reg_table(
        res_Inflation_performance_reg,
        X_Inflation_performance_reg,
        f"{label_prefix}_Inflation_performance_regime",
    ))
    inf_tables.append(make_inference_table(
        res_Inflation_performance_reg,
        reg_Inflation_performance,
        f"{label_prefix}_Inflation_performance_regime",
        ["abs_infl_gap", "abs_infl_gap_x_ELB", "miss_streak_24m", "miss_streak_24m_x_ELB"],
        ["abs_infl_gap", "abs_infl_gap_x_ELB", "miss_streak_24m", "miss_streak_24m_x_ELB"],
    ))

    combo_tables.append(combined_effect_table(
        res_Inflation_performance_reg,
        reg_Inflation_performance,
        "abs_infl_gap",
        "abs_infl_gap_x_ELB",
        f"{label_prefix}_Inflation_performance_regime",
    ))
    combo_tables.append(combined_effect_table(
        res_Inflation_performance_reg,
        reg_Inflation_performance,
        "miss_streak_24m",
        "miss_streak_24m_x_ELB",
        f"{label_prefix}_Inflation_performance_regime",
    ))

    print("\n" + "=" * 100)
    print(f"SUMMARY — {label_prefix} DETERMINANTS")
    print("=" * 100)

    b0, se0, p0 = safe_get_triplet(res_Outcome_based_p_share_pool, "p_share_F")
    print(f"Outcome-based p-share pooled: β(p_share_F)={b0:.4f} se={se0:.4f} p={p0:.3f}")

    b0, se0, p0 = safe_get_triplet(res_Outcome_based_p_share_reg, "p_share_F")
    b1, se1, p1 = safe_get_triplet(res_Outcome_based_p_share_reg, "p_share_F_x_ELB")
    print(f"Outcome-based p-share: β(p_share_F | ELB=0)={b0:.4f} se={se0:.4f} p={p0:.3f} | Δβ at ELB={b1:.4f} se={se1:.4f} p={p1:.3f}")

    b0, se0, p0 = safe_get_triplet(res_Inflation_performance_pool, "abs_infl_gap")
    b1, se1, p1 = safe_get_triplet(res_Inflation_performance_pool, "miss_streak_24m")
    print(f"Inflation performance pooled: β(|π-π*|)={b0:.4f} se={se0:.4f} p={p0:.3f} | β(streak)={b1:.4f} se={se1:.4f} p={p1:.3f}")

    b0, se0, p0 = safe_get_triplet(res_Inflation_performance_reg, "abs_infl_gap")
    b1, se1, p1 = safe_get_triplet(res_Inflation_performance_reg, "abs_infl_gap_x_ELB")
    print(f"Inflation performance: β(|π-π*| | ELB=0)={b0:.4f} se={se0:.4f} p={p0:.3f} | Δβ at ELB={b1:.4f} se={se1:.4f} p={p1:.3f}")

    b0, se0, p0 = safe_get_triplet(res_Inflation_performance_reg, "miss_streak_24m")
    b1, se1, p1 = safe_get_triplet(res_Inflation_performance_reg, "miss_streak_24m_x_ELB")
    print(f"Inflation performance: β(streak | ELB=0)={b0:.4f} se={se0:.4f} p={p0:.3f} | Δβ at ELB={b1:.4f} se={se1:.4f} p={p1:.3f}")

    out = {
        "coefficients": pd.concat(coef_tables, ignore_index=True) if coef_tables else pd.DataFrame(),
        "inference": pd.concat(inf_tables, ignore_index=True) if inf_tables else pd.DataFrame(),
        "combined_effects": (
            pd.concat([x for x in combo_tables if x is not None and not x.empty], ignore_index=True)
            if any((x is not None and not x.empty) for x in combo_tables)
            else pd.DataFrame()
        ),
        "regression_samples": {
            "Outcome_based_p_share": reg_Outcome_based_p_share,
            "Inflation_performance": reg_Inflation_performance,
        },
        "models": {
            "Outcome_based_p_share_pool": res_Outcome_based_p_share_pool,
            "Outcome_based_p_share_regime": res_Outcome_based_p_share_reg,
            "Inflation_performance_pool": res_Inflation_performance_pool,
            "Inflation_performance_regime": res_Inflation_performance_reg,
        },
    }

    return out


def run_us_t5y5y_validation(
    panel: pd.DataFrame,
    yvar: str,
    label: str,
    t5y5y_daily: pd.Series,
    cfg: JournalConfig,
    val_start: str = "2012-01-31",
    val_end: Optional[str] = None,
) -> Dict[str, pd.DataFrame]:
    """
    US 5y5y validation for the AP(3) reaction-function measure.

    Validation object:
        downside_anch_gap_t = max(pi* - 5y5y_t, 0)
    """
    if val_end is None:
        val_end = cfg.END

    t5y5y = t5y5y_monthly_eom(t5y5y_daily)

    fed = panel[panel["bank"] == "Fed"].copy()
    fed = fed.dropna(subset=["date", yvar]).sort_values("date")
    fed = fed.merge(t5y5y.reset_index(), on="date", how="left", validate="one_to_one")

    fed = fed[
        (fed["date"] >= month_end(val_start))
        & (fed["date"] <= month_end(val_end))
    ].copy()

    fed["abs_anch_dev"] = (fed["t5y5y"] - cfg.PI_STAR).abs()
    fed["downside_anch_gap"] = (cfg.PI_STAR - fed["t5y5y"]).clip(lower=0)

    joint = fed.dropna(
        subset=[yvar, "t5y5y", "abs_anch_dev", "downside_anch_gap"]
    ).copy()
    joint = joint.sort_values("date").reset_index(drop=True)

    correlations = pd.DataFrame(
        [
            {
                "label": label,
                "sample_start": joint["date"].min(),
                "sample_end": joint["date"].max(),
                "N": int(len(joint)),
                "corr_y_t5y5y_pearson": float(joint[yvar].corr(joint["t5y5y"], method="pearson")),
                "corr_y_t5y5y_spearman": float(joint[yvar].corr(joint["t5y5y"], method="spearman")),
                "corr_y_absdev_pearson": float(joint[yvar].corr(joint["abs_anch_dev"], method="pearson")),
                "corr_y_absdev_spearman": float(joint[yvar].corr(joint["abs_anch_dev"], method="spearman")),
                "corr_y_downside_gap_pearson": float(joint[yvar].corr(joint["downside_anch_gap"], method="pearson")),
                "corr_y_downside_gap_spearman": float(joint[yvar].corr(joint["downside_anch_gap"], method="spearman")),
            }
        ]
    )

    reg = joint.copy()
    reg["year"] = reg["date"].dt.year
    reg["month"] = reg["date"].dt.month

    def run_downside_reg(spec_name: str, year_fe: bool, month_fe: bool) -> Dict[str, object]:
        X = pd.DataFrame(
            {
                "const": 1.0,
                "downside_anch_gap": reg["downside_anch_gap"].astype(float),
            },
            index=reg.index,
        )

        if year_fe:
            X = pd.concat(
                [X, pd.get_dummies(reg["year"], prefix="y", drop_first=True).astype(float)],
                axis=1,
            )

        if month_fe:
            X = pd.concat(
                [X, pd.get_dummies(reg["month"], prefix="m", drop_first=True).astype(float)],
                axis=1,
            )

        y = reg[yvar].astype(float)

        res = sm.OLS(y, X).fit(
            cov_type="HAC",
            cov_kwds={"maxlags": cfg.HAC_LAGS_BASE},
        )

        ci = res.conf_int()

        return {
            "spec": spec_name,
            "variable": "downside_anch_gap",
            "coef": float(res.params.get("downside_anch_gap", np.nan)),
            "se_hac": float(res.bse.get("downside_anch_gap", np.nan)),
            "t_hac": float(res.tvalues.get("downside_anch_gap", np.nan)),
            "p_hac": float(res.pvalues.get("downside_anch_gap", np.nan)),
            "ci_low": float(ci.loc["downside_anch_gap", 0]) if "downside_anch_gap" in ci.index else np.nan,
            "ci_high": float(ci.loc["downside_anch_gap", 1]) if "downside_anch_gap" in ci.index else np.nan,
            "N": int(res.nobs),
            "sample_start": reg["date"].min(),
            "sample_end": reg["date"].max(),
            "year_FE": year_fe,
            "month_FE": month_fe,
        }

    regression = pd.DataFrame(
        [
            run_downside_reg("no_FE", year_fe=False, month_fe=False),
            run_downside_reg("month_FE", year_fe=False, month_fe=True),
            run_downside_reg("year_month_FE", year_fe=True, month_fe=True),
        ]
    )

    baseline_row = regression.loc[regression["spec"] == "year_month_FE"].iloc[0]

    summary = pd.DataFrame(
        [
            {
                "label": label,
                "validation_object": "downside_anch_gap = max(2 - 5y5y, 0)",
                "baseline_spec": "year_month_FE",
                "higher_is_worse": True,
                "beta_downside_anch_gap": float(baseline_row["coef"]),
                "se_hac": float(baseline_row["se_hac"]),
                "p_hac": float(baseline_row["p_hac"]),
                "n_joint": int(baseline_row["N"]),
                "sample_start": baseline_row["sample_start"],
                "sample_end": baseline_row["sample_end"],
            }
        ]
    )

    return {
        "correlations": correlations,
        "regression": regression,
        "summary": summary,
        "validation_data": joint,
    }


def maybe_write_results(results: Dict[str, object], cfg: JournalConfig) -> None:
    if not cfg.WRITE_RESULTS_TO_FILES:
        return

    outdir = Path(cfg.RESULTS_DIR)
    outdir.mkdir(parents=True, exist_ok=True)

    tables = {
        "workbook_audit": results.get("workbook_audit"),
        "macro_backbone_audit": results.get("macro_backbone_audit"),
        "ap3_rf_window_cv": results["ap3"].get("rf_window_cv"),
        "us_5y5y_correlations": results["us_val_ap3"].get("correlations"),
        "us_5y5y_regression": results["us_val_ap3"].get("regression"),
        "us_5y5y_summary": results["us_val_ap3"].get("summary"),
        "ap3_det_coefficients": results["det_ap3"].get("coefficients"),
        "ap3_det_inference": results["det_ap3"].get("inference"),
        "ap3_det_combined_effects": results["det_ap3"].get("combined_effects"),
        "shadow_det_coefficients": results["det_shadow"].get("coefficients"),
        "shadow_det_inference": results["det_shadow"].get("inference"),
        "shadow_det_combined_effects": results["det_shadow"].get("combined_effects"),
        "egarch_meta": results["shadow"].get("eg_meta"),
        "gjr_meta": results["shadow"].get("gjr_meta"),
        "gjr_corr_by_econ": results["shadow"].get("gjr_corr_by_econ"),
    }

    for name, df in tables.items():
        if isinstance(df, pd.DataFrame):
            df.to_csv(outdir / f"{name}.csv", index=False)


def run_all(cfg: JournalConfig = CFG) -> Dict[str, object]:
    global CFG
    CFG = cfg
    set_seeds(cfg.SEED)

    data_path = resolve_input_file(cfg.DATA_FILE, cfg.ROOT_LOCAL)

    show_heading("Single-workbook data audit")
    audit = freq_audit(data_path)
    print(audit.to_string(index=False))

    raw, t5y5y_daily = load_unified_raw(data_path)

    common_panel = build_common_macro_panel(raw, cfg=cfg, elb_mode="data_driven")
    show_table("Common macro backbone audit", macro_backbone_audit(common_panel))

    shadow_wide = build_shadow_rate_wide(raw, cfg=cfg)

    ap3_bundle = build_ap3_measure(common_panel, cfg)
    ap3_panel_for_det = prepare_lowcred_regression_panel(
        ap3_bundle["panel_reported"],
        y_col="AP3_raw_lowcred",
        reported_start=cfg.REPORTED_START,
    )

    det_ap3 = run_workhorse_determinants(
        ap3_panel_for_det,
        yname="AP3_raw_lowcred",
        label_prefix="AP3_RAW",
        heading="AP(3) DETERMINANTS — RAW LOW-CREDIBILITY",
        cfg=cfg,
    )

    us_val_ap3 = run_us_t5y5y_validation(
        ap3_bundle["panel_reported"].rename(columns={"AP3_raw_lowcred": "AP3_RAW"}),
        yvar="AP3_RAW",
        label="AP(3) raw low-credibility",
        t5y5y_daily=t5y5y_daily,
        cfg=cfg,
    )

    shadow_bundle = run_shadow_rate_measure(shadow_wide, cfg)

    sr_validation = run_sacrifice_ratio_validation(
        common_panel=common_panel,
        cred_eg_raw=shadow_bundle["cred_eg_raw"],
        cfg=cfg,
    )

    shadow_panel_for_det = build_shadow_determinants_panel(
        common_panel=common_panel,
        cred_eg_raw=shadow_bundle["cred_eg_raw"],
        cfg=cfg,
    )

    det_shadow = run_workhorse_determinants(
        shadow_panel_for_det,
        yname="neg_cred_eg_raw",
        label_prefix="SHADOW_RAW",
        heading="SHADOW-RATE CREDIBILITY DETERMINANTS — NEGATIVE RAW EGARCH CREDIBILITY",
        cfg=cfg,
    )

    results = {
        "data_path": data_path,
        "workbook_audit": audit,
        "raw": raw,
        "t5y5y_daily": t5y5y_daily,
        "common_panel": common_panel,
        "macro_backbone_audit": macro_backbone_audit(common_panel),
        "shadow_wide": shadow_wide,
        "ap3": ap3_bundle,
        "det_ap3": det_ap3,
        "us_val_ap3": us_val_ap3,
        "shadow": shadow_bundle,
        "sacrifice_ratio": sr_validation,
        "shadow_det_panel": shadow_panel_for_det,
        "det_shadow": det_shadow,
    }

    maybe_write_results(results, cfg)

    return results


def present_results(results: Dict[str, object]) -> None:
    print(f"\nData workbook: {results['data_path']}")
    print(f"Best AP(3) rolling RF window: {results['ap3']['best_rf_window']}")

    show_table("AP(3) rolling-window CV", results["ap3"]["rf_window_cv"])
    show_table("AP(3) scale stats", pd.DataFrame([results["ap3"]["scale_stats"]]))

    show_table("US 5y5y validation: correlations", results["us_val_ap3"]["correlations"])
    show_table("US 5y5y validation: downside-gap regressions", results["us_val_ap3"]["regression"])
    show_table("US 5y5y validation: baseline summary", results["us_val_ap3"]["summary"])

    show_table("Shadow EGARCH meta", results["shadow"]["eg_meta"])
    show_table("Shadow anchor stats", pd.DataFrame([results["shadow"]["anchor_stats"]]))
    show_table("Shadow EGARCH vs GJR robustness", results["shadow"]["gjr_corr_by_econ"])

    sr_res = results["sacrifice_ratio"]["res_hac_eg"]
    xname = f"cred_lag{CFG.SR_LAG}"
    b, se, p = coef_line(sr_res, xname)
    show_table(
        "Sacrifice-ratio validation summary",
        pd.DataFrame(
            [
                {
                    "model": f"SR_H{CFG.SR_H} ~ {xname} + country dummies",
                    "coef": b,
                    "se_hac": se,
                    "p_hac": p,
                    "N": int(sr_res.nobs),
                    "HAC_lags": CFG.SR_H,
                }
            ]
        ),
    )

    show_table("AP3 determinant coefficients", results["det_ap3"]["coefficients"])
    show_table("Shadow determinant coefficients", results["det_shadow"]["coefficients"])


def _month_start(ts) -> pd.Timestamp:
    return pd.Timestamp(ts).to_period("M").to_timestamp(how="start")


def to_monthly_ms_legacy(s: pd.Series) -> pd.Series:
    """
    Original WX `to_monthly` behavior:
    - daily/business: resample to month-start using last observation in month;
    - quarterly: QS interpolation then MS ffill;
    - monthly: move dates to month-start.
    """
    z = pd.Series(s).copy()
    if not isinstance(z.index, pd.DatetimeIndex):
        z.index = pd.to_datetime(z.index, errors="coerce")
    z = z[~pd.isna(z.index)]
    z = pd.to_numeric(z, errors="coerce").sort_index()

    if z.index.has_duplicates:
        z = z.groupby(level=0).mean()

    try:
        f = (pd.infer_freq(z.dropna().index[:5]) or "").upper()
    except Exception:
        f = ""

    if f.startswith(("D", "B")):
        z = z.resample("MS").last()
    elif f.startswith("Q"):
        z = z.resample("QS").last().interpolate("linear").resample("MS").ffill()
    else:
        if not z.index.is_month_start.all():
            z.index = z.index.to_period("M").to_timestamp(how="start")
        z = z.asfreq("MS")

    return z


def ensure_me(s: pd.Series) -> pd.Series:
    """
    Legacy name kept for compatibility with the single-workbook file.
    For the WX/shadow block, this now intentionally returns month-start data,
    matching the original `ensure_ms` helper.
    """
    z = pd.Series(s).copy()
    if not isinstance(z.index, pd.DatetimeIndex):
        z.index = pd.to_datetime(z.index, errors="coerce")
    z = z[~pd.isna(z.index)]
    z.index = z.index.to_period("M").to_timestamp(how="start")
    z = pd.to_numeric(z, errors="coerce").sort_index()
    if z.index.has_duplicates:
        z = z.groupby(level=0).mean()
    return z.asfreq("MS")


def scale_wide_to_0_100(
    rawcred: pd.DataFrame,
    anchor_end: str,
    p_lo: int = 5,
    p_hi: int = 95,
) -> Tuple[pd.DataFrame, Dict[str, float]]:
    """
    Original WX scaling convention:
    pooled percentiles over the month-start anchor window ending at ANCHOR_END.
    """
    anchor_end_ts = pd.Timestamp(anchor_end)
    z = rawcred.copy()
    z.index = pd.to_datetime(z.index).to_period("M").to_timestamp(how="start")

    base = z.loc[z.index <= anchor_end_ts].stack().dropna()
    if base.empty:
        raise ValueError("Anchor window empty. Check ANCHOR_END.")

    q_lo = float(np.nanpercentile(base.values, p_lo))
    q_hi = float(np.nanpercentile(base.values, p_hi))
    width = max(1e-8, q_hi - q_lo)
    scaled = ((z - q_lo) / width * 100.0).clip(0, 100)
    stats = {"q_lo": q_lo, "q_hi": q_hi, "anchor_end": str(anchor_end_ts.date())}
    return scaled, stats


def build_shadow_rate_wide(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    cfg: JournalConfig,
) -> pd.DataFrame:
    """
    Original WX shadow-rate panel convention: month-start, 2008-01 to 2022-01.
    """
    idx = pd.date_range(_month_start(cfg.SHADOW_START), _month_start(cfg.SHADOW_END), freq="MS")
    out = {}

    for econ in ["US", "EU", "UK"]:
        sr = raw[(econ, "SR")]
        out[econ] = to_monthly_ms_legacy(sr.set_index("date")["value"]).reindex(idx)

    return pd.DataFrame(out).sort_index()


def select_ar(y: pd.Series, max_p: int = 2) -> int:
    """
    Legacy 1:1 shadow-rate AR selection.

    The original code attempted AIC selection using:
        ARIMA(...).fit(method='innovations_mle', disp=0)
    In current statsmodels, `disp` is invalid, all fits are silently skipped,
    and the function returns the initialized fallback lag p=0.

    To reproduce the original *effective* methodology exactly and transparently,
    this override returns p=0 by default. Setting CFG.LEGACY_SHADOW_FORCE_AR0=False
    allows repaired AIC selection, but that is NOT the legacy baseline.
    """
    if getattr(CFG, "LEGACY_SHADOW_FORCE_AR0", True):
        return 0

    z = ensure_me(pd.Series(y).dropna())
    best, lag, success = np.inf, 0, 0

    for p in range(max_p + 1):
        try:
            fit = smt.ARIMA(z, order=(p, 0, 0)).fit(method="innovations_mle")
            success += 1
            if fit.aic < best:
                best, lag = float(fit.aic), int(p)
        except Exception:
            pass

    if success == 0:
        logging.warning("Repaired AIC selection failed for all p; using p=0 fallback.")

    return int(lag)


def inflation_yoy_from_cpi_legacy(cpi: pd.Series) -> pd.Series:
    """
    Original WX sacrifice-ratio inflation convention: log YoY CPI inflation.
    """
    cpi = ensure_me(pd.Series(cpi).astype(float)).dropna()
    l = np.log(cpi.replace([np.inf, -np.inf], np.nan)).dropna()
    return 100.0 * (l - l.shift(12))


def legacy_load_panel_from_raw(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    econ_list: Sequence[str],
    start: str,
    end: str,
) -> pd.DataFrame:
    """
    Original WX `load_panel`, but using the already-loaded unified workbook raw sheets.
    """
    panel_raw = {}

    for econ in econ_list:
        for var in ["SR", "INF", "GDP"]:
            d = raw[(econ, var)]
            s = to_monthly_ms_legacy(d.set_index("date")["value"])
            panel_raw[(econ, var)] = s.loc[str(start):str(end)]

    panel = (
        pd.concat(panel_raw, axis=1)
        .swaplevel(0, 1, axis=1)
        .sort_index(axis=1)
        .stack(level=1)
        .rename_axis(["date", "econ"])
        .sort_index()
    )

    if panel.index.duplicated().any():
        panel = panel.groupby(level=["date", "econ"]).mean()

    return panel


def prep_shadow_panel_legacy(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    cfg: JournalConfig,
) -> pd.DataFrame:
    """
    Original WX `prep_panel`, but from the unified workbook.
    """
    panel = legacy_load_panel_from_raw(
        raw,
        econ_list=["US", "EU", "UK"],
        start=cfg.SHADOW_START,
        end=cfg.SHADOW_END,
    )

    needed = {"SR", "INF", "GDP"}
    missing = needed - set(panel.columns)
    if missing:
        raise KeyError(f"Missing variables in legacy WX panel: {missing}")

    print("=== Legacy WX data coverage (non-missing counts) ===")
    for v in ["SR", "INF", "GDP"]:
        cnt = panel[v].groupby("econ").apply(lambda s: int(s.notna().sum()))
        print(v, dict(cnt))

    inf_wide = panel["INF"].unstack("econ").sort_index()
    inf_wide = inf_wide.loc[~inf_wide.index.duplicated(keep="last")]
    pi_wide = inf_wide.apply(inflation_yoy_from_cpi_legacy, axis=0)
    pi_long = pi_wide.stack().rename("PI").groupby(level=["date", "econ"]).mean()

    panel = (
        panel.reset_index()
        .merge(pi_long.to_frame("PI").reset_index(), on=["date", "econ"], how="left")
        .set_index(["date", "econ"])
        .sort_index()
    )

    if panel.index.duplicated().any():
        panel = panel.groupby(level=["date", "econ"]).mean()

    return panel


def hamilton_output_gap_series_legacy(log_gdp: pd.Series, k: int = 12) -> pd.Series:
    """
    Original WX Hamilton helper with month-start index.
    """
    y = pd.Series(log_gdp).copy()
    if not isinstance(y.index, pd.DatetimeIndex):
        y.index = pd.to_datetime(y.index, errors="coerce")
    y = pd.to_numeric(y, errors="coerce")
    y = y[~pd.isna(y.index)].sort_index()

    if y.index.has_duplicates:
        y = y.groupby(level=0).last()

    Xlags = pd.concat([y.shift(i) for i in range(1, k + 1)], axis=1)
    Xlags.columns = [f"lag{i}" for i in range(1, k + 1)]

    resid = pd.Series(index=y.index, dtype=float)
    for t in range(k + 8, len(y)):
        X_t = sm.add_constant(Xlags.iloc[:t].dropna(), has_constant="add")
        idx = X_t.index
        y_t = y.loc[idx]
        if len(y_t) >= k + 5:
            beta = sm.OLS(y_t, X_t).fit().params
            row = sm.add_constant(Xlags.iloc[t:t + 1], has_constant="add").iloc[0]
            y_hat = float((row * beta.reindex(row.index).fillna(0)).sum())
            resid.iloc[t] = y.iloc[t] - y_hat

    return (resid * 100.0).rename("gap")


def hamilton_gap_from_gdp_legacy(gdp: pd.Series, k: int = 12) -> pd.Series:
    s = pd.Series(gdp).copy()
    if not isinstance(s.index, pd.DatetimeIndex):
        s.index = pd.to_datetime(s.index, errors="coerce")
    s = pd.to_numeric(s, errors="coerce").replace([np.inf, -np.inf], np.nan)
    s = s[~pd.isna(s.index)].sort_index()

    if s.index.has_duplicates:
        s = s.groupby(level=0).last()

    s = s.ffill().bfill().clip(lower=1e-8)
    loglvl = np.log(s)
    return hamilton_output_gap_series_legacy(loglvl, k=k)


def sacrifice_ratio_legacy(
    pi: pd.Series,
    gap: pd.Series,
    H: int,
    min_abs_dpi: float,
    winsor_pcts: Tuple[float, float],
) -> pd.Series:
    """
    Original WX sacrifice-ratio construction.
    """
    pi = ensure_me(pi).astype(float).sort_index()
    gap = ensure_me(gap).astype(float).sort_index()
    cost_pm = gap.clip(upper=0).abs().rolling(H, min_periods=H).sum()
    cost_py = cost_pm / 12.0
    dpi = pi - pi.shift(H)
    sr = (cost_py / dpi.abs()).where(dpi < -min_abs_dpi)
    return winsorize(sr, winsor_pcts).rename("SR")


def run_sacrifice_ratio_validation_legacy(
    shadow_wx_panel: pd.DataFrame,
    cred_eg_raw: pd.DataFrame,
    cfg: JournalConfig,
) -> Dict[str, object]:
    """
    Original WX sacrifice-ratio validation.

    By default this reproduces the original legacy lag timing:
        SR rows are reduced to non-missing windows first, then cred_lag12 is computed
        over that reduced panel in run_sr_reg_hac_only.
    This is intentionally 1:1 with the old code.
    """
    sr_rows = []

    for e in ["US", "EU", "UK"]:
        sub = shadow_wx_panel.xs(e, level="econ").sort_index()
        gap = hamilton_gap_from_gdp_legacy(sub["GDP"], k=cfg.HAMILTON_K)
        pi = sub["PI"]
        srH = sacrifice_ratio_legacy(
            pi,
            gap,
            H=cfg.SR_H,
            min_abs_dpi=cfg.MIN_ABS_DPI,
            winsor_pcts=cfg.WINSOR_PCTS,
        )
        sr_rows.append(pd.DataFrame({"date": srH.index, "econ": e, "SR": srH.values}))

    sr_df = pd.concat(sr_rows, axis=0)

    if getattr(cfg, "LEGACY_SR_LAG_AFTER_DROP", True):
        sr_df = sr_df.dropna(subset=["SR"])

    sr_df = sr_df.sort_values(["econ", "date"]).reset_index(drop=True)

    cred_long = cred_eg_raw.stack().rename("cred_eg_raw")
    cred_long.index.names = ["date", "econ"]

    sr_df = (
        sr_df.merge(cred_long.reset_index(), on=["date", "econ"], how="left")
        .dropna(subset=["cred_eg_raw"])
        .sort_values(["econ", "date"])
        .reset_index(drop=True)
    )

    H = cfg.SR_H
    L = cfg.SR_LAG
    xname = f"cred_lag{L}"

    res_hac_eg, N_eg, use = run_sr_reg_hac_only(
        sr_df,
        cred_col="cred_eg_raw",
        H=H,
        L=L,
        analysis_start=cfg.SHADOW_START,
    )

    print("\n==================== SACRIFICE RATIO REGRESSION (WX only, LEGACY 1:1) ====================")
    print(f"Model: SR_H{H} ~ const + cred(t-{L}) + country dummies (pooled)")
    print("Notes: SR uses overlapping windows; HAC(maxlags=H) is conservative under persistence.")
    if getattr(cfg, "LEGACY_SR_LAG_AFTER_DROP", True):
        print("Legacy timing: SR non-missing windows are selected before cred_lag is computed.\n")
    else:
        print("Corrected timing: cred_lag is computed on the full monthly panel before SR windows are dropped.\n")

    b, se, p = coef_line(res_hac_eg, xname)
    print(f"[Baseline cred = EGARCH] HAC: b={b:.4f}, se={se:.4f}, p={p:.4f} | N={N_eg} | maxlags={H}")

    print("\n--- EGARCH credibility regression table (HAC) ---")
    print(res_hac_eg.summary().tables[1])

    return {
        "sr_df": sr_df,
        "sr_reg_use": use,
        "res_hac_eg": res_hac_eg,
        "N_eg": N_eg,
    }


@dataclass
class PanelCompatConfigLegacy:
    START: str
    END: str
    PI_STAR: float = 2.0
    ELB_EPS: float = 0.10
    ELB_THRESHOLDS: Optional[Dict[str, float]] = None

    def __post_init__(self):
        if self.ELB_THRESHOLDS is None:
            self.ELB_THRESHOLDS = {"ECB": 0.10, "BoE": 0.25, "Fed": 0.25}


def to_monthly_panel_legacy_from_raw(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    cfg_panel: PanelCompatConfigLegacy,
    elb_mode: str = "data_driven",
) -> pd.DataFrame:
    """
    Original shadow-determinants compatibility panel:
    month-end panel over 2008-01 to 2022-01.
    """
    master_me = pd.date_range(month_end(cfg_panel.START), month_end(cfg_panel.END), freq="ME")

    rows = []
    for econ in ["EU", "UK", "US"]:
        bank = BANK_CODE_TO_NAME[econ]

        pol = raw[(econ, "POLICY")]
        inf = raw[(econ, "INF")]
        gdp = raw[(econ, "GDP")]

        m_pol = to_monthly_eom(pol.set_index("date")["value"]).reindex(master_me)
        inf_level_eom = to_monthly_eom(inf.set_index("date")["value"], interpolate_quarterly=True).reindex(master_me)
        m_infl_yoy = infer_yoy_from_INF(inf_level_eom)
        m_gdp = to_monthly_eom(gdp.set_index("date")["value"], interpolate_quarterly=True).reindex(master_me)

        tmp = pd.concat([m_pol, m_infl_yoy, m_gdp], axis=1)
        tmp.columns = ["policy_rate", "infl_yoy", "gdp"]
        tmp["bank"] = bank
        tmp["econ"] = econ
        tmp = tmp.reset_index().rename(columns={"index": "date"})
        rows.append(tmp)

    mon = pd.concat(rows, ignore_index=True).sort_values(["bank", "date"]).reset_index(drop=True)

    mon["gdp"] = pd.to_numeric(mon["gdp"], errors="coerce")
    mon["gdp"] = mon.groupby("bank")["gdp"].transform(lambda s: s.ffill().bfill())
    mon["log_gdp"] = np.log(mon["gdp"].clip(lower=1e-8))

    cyc_list = []
    for bank, g in mon.groupby("bank", sort=False):
        gap = hamilton_output_gap(g.set_index("date")["log_gdp"], k=12)
        tmp = gap.rename("output_gap").reset_index()
        tmp["bank"] = bank
        cyc_list.append(tmp)

    cyc = pd.concat(cyc_list, ignore_index=True)
    mon = mon.merge(cyc, on=["date", "bank"], how="left", validate="one_to_one")

    mon["inflation_gap"] = pd.to_numeric(mon["infl_yoy"], errors="coerce") - cfg_panel.PI_STAR
    mon["year"] = mon["date"].dt.year
    mon["month"] = mon["date"].dt.month
    mon["ym"] = mon["date"].dt.to_period("M")

    mon["crisis10"] = mon["year"].between(2010, 2012).astype(int)
    mon["pandem"] = mon["year"].between(2020, 2021).astype(int)
    mon["QE_FG"] = mon.apply(lambda r: qe_flag(r["bank"], r["year"]), axis=1).astype(int)

    def elb_data_driven_series(s: pd.Series, eps: float) -> pd.Series:
        x = pd.to_numeric(s, errors="coerce")
        roll_min = x.rolling(24, min_periods=24).min()
        return (x <= (roll_min + eps)).astype(int)

    if elb_mode == "data_driven":
        mon["ELB"] = mon.groupby("bank", group_keys=False)["policy_rate"].apply(
            lambda s: elb_data_driven_series(s, cfg_panel.ELB_EPS)
        ).astype(int)
    else:
        mon["ELB"] = mon.apply(
            lambda r: int(r["policy_rate"] <= cfg_panel.ELB_THRESHOLDS.get(str(r["bank"]), 0.25)),
            axis=1,
        ).astype(int)

    mon["policy_rate_lead3"] = mon.groupby("bank")["policy_rate"].shift(-3)
    mon["di"] = mon.groupby("bank")["policy_rate"].diff()
    mon["abs_deltai_3m"] = (mon["policy_rate_lead3"] - mon["policy_rate"]).abs()
    mon["abs_deltai_3m_lag"] = mon.groupby("bank")["abs_deltai_3m"].shift(1)

    mon["abs_pi_gap"] = mon["inflation_gap"].abs()
    mon["abs_y_gap"] = mon["output_gap"].abs()
    den = mon["abs_pi_gap"] + mon["abs_y_gap"]
    mon["pi_share"] = np.where(den > 0, mon["abs_pi_gap"] / den, np.nan)

    return mon


def build_shadow_determinants_panel_legacy(
    raw: Dict[Tuple[str, str], pd.DataFrame],
    cred_eg_raw: pd.DataFrame,
    cfg: JournalConfig,
) -> pd.DataFrame:
    """
    Original shadow-determinants panel, but raw data come from the unified workbook.
    """
    cfg_panel = PanelCompatConfigLegacy(
        START=cfg.SHADOW_START,
        END=cfg.SHADOW_END,
        PI_STAR=cfg.PI_STAR,
        ELB_EPS=cfg.ELB_EPS,
        ELB_THRESHOLDS=cfg.ELB_THRESHOLDS,
    )

    mon = to_monthly_panel_legacy_from_raw(raw, cfg_panel=cfg_panel, elb_mode="data_driven").copy()

    cred_long = cred_eg_raw.copy()
    cred_long.index = pd.to_datetime(cred_long.index)
    cred_long.index = cred_long.index.to_period("M").to_timestamp("M")
    cred_long = cred_long.stack().rename("cred_eg_raw").reset_index()
    cred_long.columns = ["date", "econ", "cred_eg_raw"]
    cred_long["bank"] = cred_long["econ"].map(BANK_CODE_TO_NAME)

    z = mon.merge(
        cred_long[["date", "bank", "cred_eg_raw"]],
        on=["date", "bank"],
        how="left",
        validate="one_to_one",
    ).sort_values(["bank", "date"]).copy()

    z["neg_cred_eg_raw"] = -pd.to_numeric(z["cred_eg_raw"], errors="coerce")

    z["p_share_F"] = z["pi_share"]
    z["p_share_F_x_ELB"] = z["p_share_F"] * z["ELB"]

    z["abs_infl_gap"] = z["inflation_gap"].abs()
    z["miss_streak_24m"] = z.groupby("bank")["abs_infl_gap"].transform(
        lambda s: s.rolling(24, min_periods=6).mean()
    )
    z["abs_infl_gap_x_ELB"] = z["abs_infl_gap"] * z["ELB"]
    z["miss_streak_24m_x_ELB"] = z["miss_streak_24m"] * z["ELB"]

    z["abs_deltai_3_lag"] = z["abs_deltai_3m_lag"]

    z["year"] = z["date"].dt.year
    z["month"] = z["date"].dt.month
    z["ym"] = z["date"].dt.to_period("M")

    z = z[z["date"] >= month_end(cfg.SHADOW_START)].copy()

    return z


def run_shadow_rate_measure(
    shadow_wide: pd.DataFrame,
    cfg: JournalConfig,
) -> Dict[str, object]:
    """
    Legacy 1:1 WX shadow-rate measure:
        AR(0)-EGARCH(1,1)-t baseline by default, month-start indexing.
    """
    set_seeds(getattr(cfg, "SHADOW_SEED", 42))

    show_heading("WU & XIA SHADOW-RATE PIPELINE — LEGACY 1:1 SINGLE WORKBOOK")

    ar_lags: Dict[str, int] = {}
    sigma_eg: Dict[str, pd.Series] = {}
    eg_meta: Dict[str, Dict[str, object]] = {}

    for e in ["US", "EU", "UK"]:
        sr = ensure_me(shadow_wide[e]).dropna()
        p = select_ar(sr, cfg.AR_MAX)
        ar_lags[e] = int(p)

        res, sig = fit_egarch_t_level(
            sr,
            lags_ar=p,
            min_T=cfg.MIN_T,
            fallback_roll=cfg.FALLBACK_ROLL,
        )
        sigma_eg[e] = sig
        eg_meta[e] = {
            "ar_lags": int(p),
            "ar_source": "legacy_forced_AR0" if getattr(cfg, "LEGACY_SHADOW_FORCE_AR0", True) else "AIC_repaired",
            "egarch_ok": bool(res is not None),
        }

    sigma_eg_df = pd.DataFrame(sigma_eg).sort_index()
    cred_eg_raw = (-np.log(sigma_eg_df.clip(lower=1e-10))).rename_axis("date")
    cred_eg_sc, anchor_stats = scale_wide_to_0_100(
        cred_eg_raw,
        cfg.ANCHOR_END,
        cfg.SHADOW_SCALE_P_LO,
        cfg.SHADOW_SCALE_P_HI,
    )

    print("\n=== EGARCH meta (baseline SR-level, legacy 1:1) ===")
    print(pd.DataFrame(eg_meta).T)

    print("\n=== Anchor stats (pooled scaling, legacy WX) ===")
    print(anchor_stats)

    if getattr(cfg, "LEGACY_SHADOW_FORCE_AR0", True):
        print("\nLegacy note: AR lag is fixed at p=0 to reproduce the original code's effective behavior.")

    sigma_gjr: Dict[str, pd.Series] = {}
    gjr_meta: Dict[str, Dict[str, object]] = {}

    for e in ["US", "EU", "UK"]:
        sr = ensure_me(shadow_wide[e]).dropna()
        p = ar_lags.get(e, select_ar(sr, cfg.AR_MAX))

        res, sig = fit_gjr_garch_t_level(
            sr,
            lags_ar=p,
            min_T=cfg.MIN_T,
            fallback_roll=cfg.FALLBACK_ROLL,
        )
        sigma_gjr[e] = sig
        gjr_meta[e] = {"ar_lags": int(p), "gjr_ok": bool(res is not None)}

    sigma_gjr_df = pd.DataFrame(sigma_gjr).sort_index()
    cred_gjr_raw = (-np.log(sigma_gjr_df.clip(lower=1e-10))).rename_axis("date")
    cred_gjr_sc, _ = scale_wide_to_0_100(
        cred_gjr_raw,
        cfg.ANCHOR_END,
        cfg.SHADOW_SCALE_P_LO,
        cfg.SHADOW_SCALE_P_HI,
    )

    rows = []
    for e in ["US", "EU", "UK"]:
        tmp = pd.concat(
            [cred_eg_sc[e].rename("egarch"), cred_gjr_sc[e].rename("gjr")],
            axis=1,
        ).dropna()
        rows.append(
            [
                e,
                float(tmp["egarch"].corr(tmp["gjr"])) if len(tmp) > 5 else np.nan,
                int(len(tmp)),
            ]
        )

    pooled = pd.concat(
        [cred_eg_sc.stack().rename("egarch"), cred_gjr_sc.stack().rename("gjr")],
        axis=1,
    ).dropna()

    print("\n=== Robustness: baseline EGARCH credibility vs GJR-GARCH credibility ===")
    print(pd.DataFrame(rows, columns=["econ", "corr(egarch,gjr)", "T_common"]).to_string(index=False))
    print(f"Pooled corr(egarch,gjr) = {float(pooled['egarch'].corr(pooled['gjr'])):.3f} (N={len(pooled)})")
    print("\n=== GJR meta ===")
    print(pd.DataFrame(gjr_meta).T)

    plot_shadow_vol_and_cred(sigma_eg_df, cred_eg_sc, cfg)

    return {
        "sigma_eg": sigma_eg_df,
        "cred_eg_raw": cred_eg_raw,
        "cred_eg_sc": cred_eg_sc,
        "eg_meta": pd.DataFrame(eg_meta).T,
        "anchor_stats": anchor_stats,
        "sigma_gjr": sigma_gjr_df,
        "cred_gjr_raw": cred_gjr_raw,
        "cred_gjr_sc": cred_gjr_sc,
        "gjr_meta": pd.DataFrame(gjr_meta).T,
        "gjr_corr_by_econ": pd.DataFrame(rows, columns=["econ", "corr(egarch,gjr)", "T_common"]),
        "gjr_corr_pooled": float(pooled["egarch"].corr(pooled["gjr"])) if len(pooled) > 0 else np.nan,
    }


def run_all(cfg: JournalConfig = CFG) -> Dict[str, object]:
    """
    Legacy 1:1 master runner:
        - AP3 path: original AP3 month-end backbone from the unified workbook.
        - Shadow path: original WX month-start block from the unified workbook.
        - Shadow determinants: original shadow compatibility panel from the unified workbook.
    """
    global CFG
    CFG = cfg
    set_seeds(cfg.SEED)

    data_path = resolve_input_file(cfg.DATA_FILE, cfg.ROOT_LOCAL)

    show_heading("Single-workbook data audit")
    audit = freq_audit(data_path)
    print(audit.to_string(index=False))

    raw, t5y5y_daily = load_unified_raw(data_path)

    common_panel = build_common_macro_panel(raw, cfg=cfg, elb_mode="data_driven")
    show_table("AP3 macro backbone audit", macro_backbone_audit(common_panel))

    ap3_bundle = build_ap3_measure(common_panel, cfg)
    ap3_panel_for_det = prepare_lowcred_regression_panel(
        ap3_bundle["panel_reported"],
        y_col="AP3_raw_lowcred",
        reported_start=cfg.REPORTED_START,
    )

    det_ap3 = run_workhorse_determinants(
        ap3_panel_for_det,
        yname="AP3_raw_lowcred",
        label_prefix="AP3_RAW",
        heading="AP(3) DETERMINANTS — RAW LOW-CREDIBILITY",
        cfg=cfg,
    )

    us_val_ap3 = run_us_t5y5y_validation(
        ap3_bundle["panel_reported"].rename(columns={"AP3_raw_lowcred": "AP3_RAW"}),
        yvar="AP3_RAW",
        label="AP(3) raw low-credibility",
        t5y5y_daily=t5y5y_daily,
        cfg=cfg,
    )

    shadow_wide = build_shadow_rate_wide(raw, cfg=cfg)
    shadow_bundle = run_shadow_rate_measure(shadow_wide, cfg)

    shadow_wx_panel = prep_shadow_panel_legacy(raw, cfg)
    sr_validation = run_sacrifice_ratio_validation_legacy(
        shadow_wx_panel=shadow_wx_panel,
        cred_eg_raw=shadow_bundle["cred_eg_raw"],
        cfg=cfg,
    )

    shadow_panel_for_det = build_shadow_determinants_panel_legacy(
        raw=raw,
        cred_eg_raw=shadow_bundle["cred_eg_raw"],
        cfg=cfg,
    )

    det_shadow = run_workhorse_determinants(
        shadow_panel_for_det,
        yname="neg_cred_eg_raw",
        label_prefix="SHADOW_RAW",
        heading="SHADOW-RATE CREDIBILITY DETERMINANTS — NEGATIVE RAW EGARCH CREDIBILITY",
        cfg=cfg,
    )

    results = {
        "data_path": data_path,
        "workbook_audit": audit,
        "raw": raw,
        "t5y5y_daily": t5y5y_daily,
        "common_panel": common_panel,
        "macro_backbone_audit": macro_backbone_audit(common_panel),
        "shadow_wide": shadow_wide,
        "shadow_wx_panel": shadow_wx_panel,
        "ap3": ap3_bundle,
        "det_ap3": det_ap3,
        "us_val_ap3": us_val_ap3,
        "shadow": shadow_bundle,
        "sacrifice_ratio": sr_validation,
        "shadow_det_panel": shadow_panel_for_det,
        "det_shadow": det_shadow,
    }

    maybe_write_results(results, cfg)

    return results


if __name__ == "__main__":
    results = run_all(CFG)
    present_results(results)
# Out:
# ============================================
# Single-workbook data audit
# ============================================
#           sheet  n_rows  n_dates  n_values infer_freq      start        end         date_col value_col
# Shadow Rates EU     169      169       169         MS 2008-01-01 2022-01-01             Date        SR
# Policy Rates EU    8061     8061      8061          D 2000-01-07 2022-01-31             Date    POLICY
#    Inflation EU     259      259       259         MS 2000-07-01 2022-01-01             Date       INF
#         RGDP EU      87       87        87     QS-OCT 2000-07-01 2022-01-01             Date       GDP
# Shadow Rates UK     169      169       169         MS 2008-01-01 2022-01-01             Date        SR
# Policy Rates UK    5578     5578      5578          B 2000-01-07 2022-01-31             Date    POLICY
#    Inflation UK     259      259       259         MS 2000-07-01 2022-01-01             Date       INF
#         RGDP UK      87       87        87     QS-OCT 2000-07-01 2022-01-01             Date       GDP
#            5y5y    4522     4522      4337          B 2004-10-01 2022-01-31 observation_date    T5YIFR
# Shadow Rates US     169      169       169         MS 2008-01-01 2022-01-01             Date        SR
# Policy Rates US    5631     5631      5420          B 2000-07-03 2022-01-31             Date    POLICY
#    Inflation US     259      259       259         MS 2000-07-01 2022-01-01             Date       INF
#         RGDP US      87       87        87     QS-OCT 2000-07-01 2022-01-01             Date       GDP
#
# ============================================
# AP3 macro backbone audit
# ============================================
#    bank         series  nonmissing      start        end           min  \
# 0   BoE    policy_rate         265 2000-01-31 2022-01-31  1.000000e-01
# 1   BoE      inf_level         259 2000-07-31 2022-01-31  7.330000e+01
# 2   BoE       infl_yoy         247 2001-07-31 2022-01-31  1.998002e-01
# 3   BoE         PI_log         247 2001-07-31 2022-01-31  1.996009e-01
# 4   BoE            gdp         265 2000-01-31 2022-01-31  4.506880e+05
# 5   BoE     output_gap         236 2002-06-30 2022-01-31 -1.013130e+01
# 6   BoE  inflation_gap         247 2001-07-31 2022-01-31 -1.800200e+00
# 7   BoE            ELB         265 2000-01-31 2022-01-31  0.000000e+00
# 8   BoE       pi_share         236 2002-06-30 2022-01-31  2.053767e-13
# 9   ECB    policy_rate         265 2000-01-31 2022-01-31 -5.000000e-01
# 10  ECB      inf_level         259 2000-07-31 2022-01-31  7.587000e+01
# 11  ECB       infl_yoy         247 2001-07-31 2022-01-31 -6.199021e-01
# 12  ECB         PI_log         247 2001-07-31 2022-01-31 -6.218315e-01
# 13  ECB            gdp         265 2000-01-31 2022-01-31  2.142272e+06
# 14  ECB     output_gap         236 2002-06-30 2022-01-31 -2.919159e+00
# 15  ECB  inflation_gap         247 2001-07-31 2022-01-31 -2.619902e+00
# 16  ECB            ELB         265 2000-01-31 2022-01-31  0.000000e+00
# 17  ECB       pi_share         236 2002-06-30 2022-01-31  8.031849e-03
# 18  Fed    policy_rate         259 2000-07-31 2022-01-31  4.000000e-02
# 19  Fed      inf_level         259 2000-07-31 2022-01-31  1.727000e+02
# 20  Fed       infl_yoy         247 2001-07-31 2022-01-31 -1.958761e+00
# 21  Fed         PI_log         247 2001-07-31 2022-01-31 -1.978199e+00
# 22  Fed            gdp         265 2000-01-31 2022-01-31  1.414531e+04
# 23  Fed     output_gap         236 2002-06-30 2022-01-31 -2.560923e+00
# 24  Fed  inflation_gap         247 2001-07-31 2022-01-31 -3.958761e+00
# 25  Fed            ELB         265 2000-01-31 2022-01-31  0.000000e+00
# 26  Fed       pi_share         236 2002-06-30 2022-01-31  5.165517e-03
#
#              max
# 0   6.000000e+00
# 1   1.147000e+02
# 2   4.849039e+00
# 3   4.735141e+00
# 4   6.261110e+05
# 5   2.876940e+01
# 6   2.849039e+00
# 7   1.000000e+00
# 8   9.999714e-01
# 9   3.750000e+00
# 10  1.107000e+02
# 11  5.108242e+00
# 12  4.982051e+00
# 13  2.758369e+06
# 14  9.808348e+00
# 15  3.108242e+00
# 16  1.000000e+00
# 17  9.997851e-01
# 18  6.650000e+00
# 19  2.825420e+02
# 20  7.578082e+00
# 21  7.304675e+00
# 22  2.198874e+04
# 23  5.533168e+00
# 24  5.578082e+00
# 25  1.000000e+00
# 26  9.993496e-01
# ============================================
# Figure 1A. First Credibility Score
# ============================================
# ====================================================================================================
# AP(3) DETERMINANTS — RAW LOW-CREDIBILITY
# ====================================================================================================
# LHS: AP3_raw_lowcred
# Interpretation: larger LHS = lower credibility.
#
# ------------------------------------------------------------------------------
# Outcome-based p-share: pooled + ELB interaction
# ------------------------------------------------------------------------------
#
# [Outcome-based p-share: NO interaction]
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.3222      0.117      2.765      0.006       0.094       0.551
# p_share_F           -0.0360      0.055     -0.658      0.510      -0.143       0.071
# ELB                  0.1404      0.118      1.190      0.234      -0.091       0.372
# QE_FG               -0.2223      0.106     -2.099      0.036      -0.430      -0.015
# crisis10            -0.0914      0.050     -1.819      0.069      -0.190       0.007
# pandem               0.0783      0.039      1.999      0.046       0.002       0.155
# abs_deltai_3_lag     0.3581      0.076      4.714      0.000       0.209       0.507
# by_BoE_2009         -0.1365      0.075     -1.827      0.068      -0.283       0.010
# by_BoE_2010         -0.0335      0.027     -1.245      0.213      -0.086       0.019
# by_BoE_2011          0.0186      0.025      0.744      0.457      -0.030       0.067
# by_BoE_2012         -0.0260      0.033     -0.794      0.427      -0.090       0.038
# by_BoE_2013          0.0261      0.144      0.181      0.856      -0.257       0.309
# by_BoE_2014         -0.3226      0.139     -2.323      0.020      -0.595      -0.050
# by_BoE_2015         -0.2984      0.139     -2.146      0.032      -0.571      -0.026
# by_BoE_2016         -0.3861      0.139     -2.774      0.006      -0.659      -0.113
# by_BoE_2017         -0.3905      0.128     -3.039      0.002      -0.642      -0.139
# by_BoE_2018         -0.1195      0.112     -1.065      0.287      -0.339       0.100
# by_BoE_2019         -0.2239      0.105     -2.137      0.033      -0.429      -0.019
# by_BoE_2020          0.3134      0.119      2.643      0.008       0.081       0.546
# by_BoE_2021         -0.1751      0.044     -3.975      0.000      -0.261      -0.089
# by_ECB_2008         -0.0551      0.150     -0.367      0.713      -0.349       0.239
# by_ECB_2009         -0.0322      0.141     -0.229      0.819      -0.308       0.244
# by_ECB_2010         -0.2998      0.094     -3.184      0.001      -0.484      -0.115
# by_ECB_2011         -0.1523      0.088     -1.740      0.082      -0.324       0.019
# by_ECB_2012         -0.2480      0.094     -2.632      0.008      -0.433      -0.063
# by_ECB_2013         -0.2407      0.139     -1.738      0.082      -0.512       0.031
# by_ECB_2014         -0.3568      0.138     -2.594      0.009      -0.626      -0.087
# by_ECB_2015         -0.1896      0.035     -5.447      0.000      -0.258      -0.121
# by_ECB_2016         -0.1642      0.036     -4.623      0.000      -0.234      -0.095
# by_ECB_2017         -0.1686      0.034     -4.909      0.000      -0.236      -0.101
# by_ECB_2018         -0.1869      0.034     -5.559      0.000      -0.253      -0.121
# by_ECB_2019         -0.4078      0.138     -2.955      0.003      -0.678      -0.137
# by_ECB_2020         -0.2805      0.037     -7.684      0.000      -0.352      -0.209
# by_ECB_2021         -0.2793      0.040     -7.012      0.000      -0.357      -0.201
# by_Fed_2008          0.0290      0.201      0.144      0.885      -0.365       0.423
# by_Fed_2009         -0.0407      0.037     -1.104      0.270      -0.113       0.032
# by_Fed_2010          0.2718      0.087      3.108      0.002       0.100       0.443
# by_Fed_2011          0.1294      0.047      2.729      0.006       0.036       0.222
# by_Fed_2012          0.2483      0.062      3.999      0.000       0.127       0.370
# by_Fed_2013         -0.0175      0.063     -0.279      0.780      -0.140       0.105
# by_Fed_2014         -0.0053      0.047     -0.113      0.910      -0.097       0.087
# by_Fed_2015          0.1720      0.188      0.914      0.361      -0.197       0.541
# by_Fed_2016         -0.1599      0.102     -1.570      0.116      -0.359       0.040
# by_Fed_2017         -0.2169      0.096     -2.249      0.025      -0.406      -0.028
# by_Fed_2018         -0.2893      0.093     -3.095      0.002      -0.473      -0.106
# by_Fed_2019          0.0055      0.130      0.042      0.966      -0.250       0.261
# by_Fed_2020          0.6662      0.176      3.780      0.000       0.321       1.012
# by_Fed_2021         -0.1664      0.062     -2.682      0.007      -0.288      -0.045
# m_2                  0.0095      0.048      0.199      0.842      -0.084       0.103
# m_3                  0.0236      0.060      0.393      0.695      -0.094       0.141
# m_4                  0.0379      0.056      0.679      0.497      -0.071       0.147
# m_5                 -0.0119      0.053     -0.223      0.824      -0.116       0.093
# m_6                  0.0241      0.058      0.418      0.676      -0.089       0.137
# m_7                  0.0117      0.057      0.205      0.838      -0.100       0.123
# m_8                 -0.0006      0.059     -0.010      0.992      -0.116       0.115
# m_9                 -0.0410      0.057     -0.719      0.472      -0.153       0.071
# m_10                -0.0243      0.056     -0.432      0.666      -0.135       0.086
# m_11                 0.0086      0.072      0.119      0.905      -0.133       0.150
# m_12                -0.0157      0.054     -0.294      0.769      -0.121       0.089
# ====================================================================================
#
# [AP3_RAW Outcome-based p-share pooled] two-way cluster results
# p_share_F                 t_tw=  -0.585  p_tw=0.558
# ELB                       t_tw=   1.026  p_tw=0.305
# [wild-cluster by ym] p_share_F: p_boot=0.600
#
# [Outcome-based p-share with ELB interaction]
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.2306      0.157      1.471      0.141      -0.077       0.538
# p_share_F            0.0598      0.134      0.448      0.654      -0.202       0.322
# ELB                  0.2555      0.198      1.291      0.197      -0.132       0.643
# p_share_F_x_ELB     -0.1401      0.149     -0.942      0.346      -0.431       0.151
# QE_FG               -0.2106      0.099     -2.129      0.033      -0.404      -0.017
# crisis10            -0.0843      0.046     -1.814      0.070      -0.175       0.007
# pandem               0.0696      0.041      1.690      0.091      -0.011       0.150
# abs_deltai_3_lag     0.3654      0.072      5.072      0.000       0.224       0.507
# by_BoE_2009         -0.1388      0.075     -1.847      0.065      -0.286       0.008
# by_BoE_2010         -0.0366      0.026     -1.436      0.151      -0.087       0.013
# by_BoE_2011          0.0201      0.025      0.792      0.428      -0.030       0.070
# by_BoE_2012         -0.0315      0.031     -1.019      0.308      -0.092       0.029
# by_BoE_2013          0.0413      0.135      0.305      0.761      -0.224       0.307
# by_BoE_2014         -0.3051      0.128     -2.378      0.017      -0.557      -0.054
# by_BoE_2015         -0.2780      0.127     -2.184      0.029      -0.527      -0.028
# by_BoE_2016         -0.3661      0.128     -2.860      0.004      -0.617      -0.115
# by_BoE_2017         -0.3767      0.120     -3.145      0.002      -0.612      -0.142
# by_BoE_2018         -0.1066      0.110     -0.966      0.334      -0.323       0.110
# by_BoE_2019         -0.2068      0.102     -2.029      0.042      -0.407      -0.007
# by_BoE_2020          0.3123      0.121      2.583      0.010       0.075       0.549
# by_BoE_2021         -0.1874      0.046     -4.114      0.000      -0.277      -0.098
# by_ECB_2008         -0.0543      0.150     -0.363      0.717      -0.348       0.239
# by_ECB_2009         -0.0193      0.133     -0.145      0.885      -0.281       0.242
# by_ECB_2010         -0.2933      0.090     -3.276      0.001      -0.469      -0.118
# by_ECB_2011         -0.1541      0.086     -1.794      0.073      -0.322       0.014
# by_ECB_2012         -0.2368      0.088     -2.695      0.007      -0.409      -0.065
# by_ECB_2013         -0.2221      0.127     -1.742      0.082      -0.472       0.028
# by_ECB_2014         -0.3366      0.126     -2.668      0.008      -0.584      -0.089
# by_ECB_2015         -0.1811      0.031     -5.906      0.000      -0.241      -0.121
# by_ECB_2016         -0.1557      0.032     -4.942      0.000      -0.218      -0.094
# by_ECB_2017         -0.1634      0.031     -5.203      0.000      -0.225      -0.102
# by_ECB_2018         -0.1866      0.033     -5.643      0.000      -0.251      -0.122
# by_ECB_2019         -0.3886      0.127     -3.061      0.002      -0.637      -0.140
# by_ECB_2020         -0.2779      0.036     -7.654      0.000      -0.349      -0.207
# by_ECB_2021         -0.2859      0.044     -6.500      0.000      -0.372      -0.200
# by_Fed_2008          0.0370      0.200      0.185      0.853      -0.354       0.428
# by_Fed_2009         -0.0348      0.034     -1.035      0.301      -0.101       0.031
# by_Fed_2010          0.2722      0.089      3.057      0.002       0.098       0.447
# by_Fed_2011          0.1302      0.047      2.750      0.006       0.037       0.223
# by_Fed_2012          0.2455      0.060      4.083      0.000       0.128       0.363
# by_Fed_2013         -0.0121      0.062     -0.194      0.846      -0.134       0.110
# by_Fed_2014         -0.0077      0.048     -0.159      0.874      -0.102       0.087
# by_Fed_2015          0.1902      0.183      1.039      0.299      -0.168       0.549
# by_Fed_2016         -0.1601      0.101     -1.582      0.114      -0.359       0.038
# by_Fed_2017         -0.2077      0.096     -2.166      0.030      -0.396      -0.020
# by_Fed_2018         -0.2835      0.092     -3.073      0.002      -0.464      -0.103
# by_Fed_2019          0.0165      0.130      0.128      0.899      -0.238       0.271
# by_Fed_2020          0.6693      0.175      3.821      0.000       0.326       1.013
# by_Fed_2021         -0.1608      0.057     -2.800      0.005      -0.273      -0.048
# m_2                  0.0070      0.047      0.150      0.881      -0.085       0.099
# m_3                  0.0232      0.060      0.387      0.699      -0.094       0.141
# m_4                  0.0378      0.055      0.688      0.492      -0.070       0.145
# m_5                 -0.0117      0.054     -0.217      0.828      -0.117       0.094
# m_6                  0.0225      0.058      0.390      0.696      -0.090       0.135
# m_7                  0.0088      0.056      0.158      0.875      -0.100       0.118
# m_8                 -0.0014      0.059     -0.023      0.981      -0.116       0.114
# m_9                 -0.0424      0.056     -0.751      0.453      -0.153       0.068
# m_10                -0.0238      0.056     -0.426      0.670      -0.133       0.086
# m_11                 0.0066      0.071      0.093      0.926      -0.132       0.145
# m_12                -0.0136      0.054     -0.252      0.801      -0.120       0.093
# ====================================================================================
#
# [AP3_RAW Outcome-based p-share] two-way cluster results
# p_share_F                 t_tw=   0.557  p_tw=0.578
# p_share_F_x_ELB           t_tw=  -1.132  p_tw=0.257
# ELB                       t_tw=   1.193  p_tw=0.233
# [wild-cluster by ym] p_share_F: p_boot=0.823
# [wild-cluster by ym] p_share_F_x_ELB: p_boot=0.625
#
# ------------------------------------------------------------------------------
# Inflation performance: pooled + ELB interactions
# ------------------------------------------------------------------------------
#
# [Inflation performance pooled: levels-only]
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.9465      0.274      3.458      0.001       0.410       1.483
# abs_infl_gap       -0.0826      0.041     -2.019      0.044      -0.163      -0.002
# miss_streak_24m    -0.0100      0.087     -0.116      0.908      -0.180       0.160
# output_gap          0.0016      0.003      0.604      0.546      -0.004       0.007
# ELB                 0.2560      0.121      2.113      0.035       0.019       0.493
# QE_FG              -0.7326      0.197     -3.716      0.000      -1.119      -0.346
# crisis10           -0.3899      0.111     -3.502      0.000      -0.608      -0.172
# pandem              0.0008      0.069      0.012      0.991      -0.135       0.137
# by_BoE_2009        -0.2545      0.073     -3.504      0.000      -0.397      -0.112
# by_BoE_2010         0.0432      0.055      0.791      0.429      -0.064       0.150
# by_BoE_2011         0.2041      0.080      2.540      0.011       0.047       0.362
# by_BoE_2012         0.0639      0.057      1.119      0.263      -0.048       0.176
# by_BoE_2013        -0.7191      0.268     -2.683      0.007      -1.245      -0.194
# by_BoE_2014        -1.0561      0.266     -3.967      0.000      -1.578      -0.534
# by_BoE_2015        -0.9408      0.255     -3.691      0.000      -1.440      -0.441
# by_BoE_2016        -1.0537      0.260     -4.057      0.000      -1.563      -0.545
# by_BoE_2017        -1.0743      0.265     -4.054      0.000      -1.594      -0.555
# by_BoE_2018        -0.7308      0.255     -2.868      0.004      -1.230      -0.231
# by_BoE_2019        -0.8611      0.257     -3.354      0.001      -1.364      -0.358
# by_BoE_2020         0.2976      0.134      2.221      0.026       0.035       0.560
# by_BoE_2021        -0.2206      0.053     -4.189      0.000      -0.324      -0.117
# by_ECB_2008        -0.1636      0.314     -0.520      0.603      -0.780       0.453
# by_ECB_2009        -0.5627      0.269     -2.095      0.036      -1.089      -0.036
# by_ECB_2010        -0.7325      0.162     -4.533      0.000      -1.049      -0.416
# by_ECB_2011        -0.4021      0.170     -2.372      0.018      -0.734      -0.070
# by_ECB_2012        -0.6636      0.158     -4.191      0.000      -0.974      -0.353
# by_ECB_2013        -0.9650      0.262     -3.677      0.000      -1.479      -0.451
# by_ECB_2014        -0.9860      0.255     -3.870      0.000      -1.485      -0.487
# by_ECB_2015        -0.2909      0.063     -4.615      0.000      -0.414      -0.167
# by_ECB_2016        -0.2659      0.073     -3.638      0.000      -0.409      -0.123
# by_ECB_2017        -0.3885      0.075     -5.184      0.000      -0.535      -0.242
# by_ECB_2018        -0.4181      0.078     -5.336      0.000      -0.572      -0.265
# by_ECB_2019        -1.1116      0.264     -4.210      0.000      -1.629      -0.594
# by_ECB_2020        -0.3135      0.048     -6.532      0.000      -0.408      -0.219
# by_ECB_2021        -0.3498      0.069     -5.038      0.000      -0.486      -0.214
# by_Fed_2008        -0.1656      0.301     -0.551      0.582      -0.755       0.424
# by_Fed_2009        -0.0770      0.105     -0.731      0.465      -0.283       0.129
# by_Fed_2010         0.4357      0.109      3.987      0.000       0.222       0.650
# by_Fed_2011         0.2936      0.071      4.132      0.000       0.154       0.433
# by_Fed_2012         0.3678      0.074      4.976      0.000       0.223       0.513
# by_Fed_2013        -0.2204      0.097     -2.267      0.023      -0.411      -0.030
# by_Fed_2014        -0.2264      0.094     -2.396      0.017      -0.412      -0.041
# by_Fed_2015        -0.4201      0.277     -1.518      0.129      -0.963       0.122
# by_Fed_2016        -0.7268      0.242     -3.004      0.003      -1.201      -0.253
# by_Fed_2017        -0.7805      0.248     -3.150      0.002      -1.266      -0.295
# by_Fed_2018        -0.8199      0.256     -3.205      0.001      -1.321      -0.319
# by_Fed_2019        -0.5534      0.287     -1.929      0.054      -1.116       0.009
# by_Fed_2020         0.7104      0.173      4.111      0.000       0.372       1.049
# by_Fed_2021        -0.1232      0.055     -2.246      0.025      -0.231      -0.016
# m_2                 0.0440      0.038      1.162      0.245      -0.030       0.118
# m_3                 0.0535      0.051      1.040      0.299      -0.047       0.154
# m_4                 0.0511      0.045      1.144      0.253      -0.037       0.139
# m_5                -0.0022      0.041     -0.054      0.957      -0.083       0.079
# m_6                -0.0031      0.051     -0.060      0.952      -0.104       0.098
# m_7                -0.0004      0.049     -0.009      0.993      -0.096       0.095
# m_8                -0.0011      0.051     -0.021      0.983      -0.100       0.098
# m_9                -0.0311      0.057     -0.543      0.587      -0.143       0.081
# m_10                0.0120      0.054      0.220      0.826      -0.095       0.119
# m_11                0.0285      0.059      0.486      0.627      -0.086       0.143
# m_12               -0.0135      0.045     -0.300      0.764      -0.102       0.075
# ===================================================================================
#
# [AP3_RAW Inflation performance pooled] two-way cluster results
# abs_infl_gap              t_tw=  -3.120  p_tw=0.002
# miss_streak_24m           t_tw=  -0.094  p_tw=0.925
# [wild-cluster by ym] abs_infl_gap: p_boot=0.280
# [wild-cluster by ym] miss_streak_24m: p_boot=0.930
#
# [Inflation performance with ELB interactions]
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.1828      0.316      3.746      0.000       0.564       1.802
# abs_infl_gap             -0.3394      0.096     -3.547      0.000      -0.527      -0.152
# abs_infl_gap_x_ELB        0.3104      0.086      3.603      0.000       0.142       0.479
# miss_streak_24m           0.1798      0.179      1.002      0.317      -0.172       0.532
# miss_streak_24m_x_ELB    -0.3398      0.167     -2.031      0.042      -0.668      -0.012
# output_gap                0.0016      0.003      0.627      0.531      -0.003       0.007
# ELB                       0.3457      0.192      1.797      0.072      -0.031       0.723
# QE_FG                    -0.8902      0.180     -4.952      0.000      -1.243      -0.538
# crisis10                 -0.4967      0.105     -4.729      0.000      -0.703      -0.291
# pandem                   -0.0980      0.071     -1.377      0.169      -0.238       0.042
# by_BoE_2009              -0.2592      0.066     -3.944      0.000      -0.388      -0.130
# by_BoE_2010               0.0879      0.054      1.636      0.102      -0.017       0.193
# by_BoE_2011               0.1777      0.065      2.717      0.007       0.050       0.306
# by_BoE_2012               0.1689      0.058      2.918      0.004       0.055       0.282
# by_BoE_2013              -0.9265      0.252     -3.677      0.000      -1.420      -0.433
# by_BoE_2014              -1.3468      0.258     -5.213      0.000      -1.853      -0.840
# by_BoE_2015              -1.2291      0.241     -5.106      0.000      -1.701      -0.757
# by_BoE_2016              -1.2299      0.236     -5.209      0.000      -1.693      -0.767
# by_BoE_2017              -1.2609      0.243     -5.182      0.000      -1.738      -0.784
# by_BoE_2018              -0.9893      0.251     -3.942      0.000      -1.481      -0.497
# by_BoE_2019              -1.0890      0.267     -4.078      0.000      -1.612      -0.566
# by_BoE_2020               0.2566      0.131      1.956      0.050      -0.001       0.514
# by_BoE_2021              -0.1677      0.070     -2.397      0.017      -0.305      -0.031
# by_ECB_2008              -0.3010      0.258     -1.166      0.244      -0.807       0.205
# by_ECB_2009              -0.7535      0.242     -3.116      0.002      -1.228      -0.280
# by_ECB_2010              -0.7729      0.139     -5.580      0.000      -1.044      -0.501
# by_ECB_2011              -0.4739      0.169     -2.801      0.005      -0.806      -0.142
# by_ECB_2012              -0.8143      0.153     -5.328      0.000      -1.114      -0.515
# by_ECB_2013              -1.2320      0.251     -4.912      0.000      -1.724      -0.740
# by_ECB_2014              -1.2643      0.241     -5.246      0.000      -1.737      -0.792
# by_ECB_2015              -0.3214      0.059     -5.436      0.000      -0.437      -0.206
# by_ECB_2016              -0.2476      0.065     -3.823      0.000      -0.374      -0.121
# by_ECB_2017              -0.3658      0.059     -6.196      0.000      -0.481      -0.250
# by_ECB_2018              -0.4887      0.082     -5.945      0.000      -0.650      -0.328
# by_ECB_2019              -1.3976      0.254     -5.500      0.000      -1.896      -0.900
# by_ECB_2020              -0.3389      0.050     -6.725      0.000      -0.438      -0.240
# by_ECB_2021              -0.2765      0.059     -4.682      0.000      -0.392      -0.161
# by_Fed_2008              -0.2246      0.239     -0.941      0.347      -0.692       0.243
# by_Fed_2009              -0.0129      0.102     -0.126      0.900      -0.214       0.188
# by_Fed_2010               0.4648      0.110      4.240      0.000       0.250       0.680
# by_Fed_2011               0.2847      0.069      4.104      0.000       0.149       0.421
# by_Fed_2012               0.3805      0.066      5.752      0.000       0.251       0.510
# by_Fed_2013              -0.3170      0.101     -3.147      0.002      -0.514      -0.120
# by_Fed_2014              -0.3443      0.100     -3.443      0.001      -0.540      -0.148
# by_Fed_2015              -0.6932      0.247     -2.807      0.005      -1.177      -0.209
# by_Fed_2016              -1.0091      0.222     -4.548      0.000      -1.444      -0.574
# by_Fed_2017              -1.1021      0.238     -4.634      0.000      -1.568      -0.636
# by_Fed_2018              -1.0081      0.257     -3.922      0.000      -1.512      -0.504
# by_Fed_2019              -0.7778      0.297     -2.615      0.009      -1.361      -0.195
# by_Fed_2020               0.6852      0.170      4.042      0.000       0.353       1.017
# by_Fed_2021              -0.2568      0.070     -3.676      0.000      -0.394      -0.120
# m_2                       0.0466      0.034      1.362      0.173      -0.020       0.114
# m_3                       0.0550      0.045      1.224      0.221      -0.033       0.143
# m_4                       0.0276      0.036      0.776      0.438      -0.042       0.097
# m_5                      -0.0229      0.034     -0.671      0.503      -0.090       0.044
# m_6                       0.0059      0.046      0.128      0.898      -0.084       0.096
# m_7                       0.0016      0.042      0.038      0.969      -0.080       0.084
# m_8                      -0.0066      0.047     -0.142      0.887      -0.099       0.085
# m_9                      -0.0341      0.054     -0.635      0.525      -0.139       0.071
# m_10                     -0.0148      0.053     -0.281      0.778      -0.118       0.088
# m_11                     -0.0133      0.051     -0.262      0.793      -0.113       0.086
# m_12                     -0.0187      0.049     -0.384      0.701      -0.114       0.077
# =========================================================================================
#
# [AP3_RAW Inflation performance] two-way cluster results
# abs_infl_gap              t_tw=  -3.965  p_tw=0.000
# abs_infl_gap_x_ELB        t_tw=   4.149  p_tw=0.000
# miss_streak_24m           t_tw=   0.796  p_tw=0.426
# miss_streak_24m_x_ELB     t_tw=  -1.212  p_tw=0.226
# [wild-cluster by ym] abs_infl_gap: p_boot=0.045
# [wild-cluster by ym] abs_infl_gap_x_ELB: p_boot=0.040
# [wild-cluster by ym] miss_streak_24m: p_boot=0.623
# [wild-cluster by ym] miss_streak_24m_x_ELB: p_boot=0.212
#
# ====================================================================================================
# SUMMARY — AP3_RAW DETERMINANTS
# ====================================================================================================
# Outcome-based p-share pooled: β(p_share_F)=-0.0360 se=0.0546 p=0.510
# Outcome-based p-share: β(p_share_F | ELB=0)=0.0598 se=0.1336 p=0.654 | Δβ at ELB=-0.1401 se=0.1487 p=0.346
# Inflation performance pooled: β(|π-π*|)=-0.0826 se=0.0409 p=0.044 | β(streak)=-0.0100 se=0.0866 p=0.908
# Inflation performance: β(|π-π*| | ELB=0)=-0.3394 se=0.0957 p=0.000 | Δβ at ELB=0.3104 se=0.0862 p=0.000
# Inflation performance: β(streak | ELB=0)=0.1798 se=0.1795 p=0.317 | Δβ at ELB=-0.3398 se=0.1673 p=0.042
#
# ==========================================================
# WU & XIA SHADOW-RATE PIPELINE — LEGACY 1:1 SINGLE WORKBOOK
# ==========================================================
#
# === EGARCH meta (baseline SR-level, legacy 1:1) ===
#    ar_lags          ar_source egarch_ok
# US       0  legacy_forced_AR0      True
# EU       0  legacy_forced_AR0      True
# UK       0  legacy_forced_AR0      True
#
# === Anchor stats (pooled scaling, legacy WX) ===
# {'q_lo': -1.9768540176810874, 'q_hi': 1.0508624963717477, 'anchor_end': '2010-12-01'}
#
# Legacy note: AR lag is fixed at p=0 to reproduce the original code's effective behavior.
#
# === Robustness: baseline EGARCH credibility vs GJR-GARCH credibility ===
# econ  corr(egarch,gjr)  T_common
#   US          0.989707       169
#   EU          0.973072       169
#   UK          0.991215       169
# Pooled corr(egarch,gjr) = 0.984 (N=507)
#
# === GJR meta ===
#    ar_lags gjr_ok
# US       0   True
# EU       0   True
# UK       0   True
# === Legacy WX data coverage (non-missing counts) ===
# SR {'EU': np.int64(169), 'UK': np.int64(169), 'US': np.int64(169)}
# INF {'EU': np.int64(169), 'UK': np.int64(169), 'US': np.int64(169)}
# GDP {'EU': np.int64(169), 'UK': np.int64(169), 'US': np.int64(169)}
#
# ==================== SACRIFICE RATIO REGRESSION (WX only, LEGACY 1:1) ====================
# Model: SR_H12 ~ const + cred(t-12) + country dummies (pooled)
# Notes: SR uses overlapping windows; HAC(maxlags=H) is conservative under persistence.
# Legacy timing: SR non-missing windows are selected before cred_lag is computed.
#
# [Baseline cred = EGARCH] HAC: b=-0.2292, se=0.0757, p=0.0024 | N=170 | maxlags=12
#
# --- EGARCH credibility regression table (HAC) ---
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2911      0.108      2.693      0.007       0.079       0.503
# cred_lag12    -0.2292      0.076     -3.030      0.002      -0.377      -0.081
# ent_UK         0.2465      0.361      0.683      0.495      -0.461       0.954
# ent_US         0.2085      0.194      1.072      0.284      -0.173       0.590
# ==============================================================================
#
# ====================================================================================================
# SHADOW-RATE CREDIBILITY DETERMINANTS — NEGATIVE RAW EGARCH CREDIBILITY
# ====================================================================================================
# LHS: neg_cred_eg_raw
# Interpretation: larger LHS = lower credibility.
#
# ------------------------------------------------------------------------------
# Outcome-based p-share: pooled + ELB interaction
# ------------------------------------------------------------------------------
#
# [Outcome-based p-share: NO interaction]
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.5248      0.131      3.995      0.000       0.267       0.782
# p_share_F           -0.1756      0.097     -1.807      0.071      -0.366       0.015
# ELB                 -0.0787      0.128     -0.617      0.537      -0.329       0.171
# QE_FG               -0.1110      0.073     -1.523      0.128      -0.254       0.032
# crisis10            -1.2581      0.090    -13.999      0.000      -1.434      -1.082
# pandem               0.6093      0.064      9.569      0.000       0.485       0.734
# abs_deltai_3_lag     0.0260      0.202      0.129      0.897      -0.369       0.421
# by_BoE_2011          0.5391      0.209      2.579      0.010       0.129       0.949
# by_BoE_2012          1.8239      0.195      9.334      0.000       1.441       2.207
# by_BoE_2013          0.8109      0.077     10.543      0.000       0.660       0.962
# by_BoE_2014         -0.0840      0.204     -0.412      0.680      -0.483       0.315
# by_BoE_2015         -1.5106      0.404     -3.737      0.000      -2.303      -0.718
# by_BoE_2016         -0.6818      0.264     -2.583      0.010      -1.199      -0.165
# by_BoE_2017          0.3406      0.081      4.181      0.000       0.181       0.500
# by_BoE_2018         -0.3353      0.239     -1.401      0.161      -0.804       0.134
# by_BoE_2019         -0.1613      0.177     -0.910      0.363      -0.509       0.186
# by_BoE_2020          0.2985      0.166      1.793      0.073      -0.028       0.625
# by_BoE_2021          0.2266      0.146      1.557      0.120      -0.059       0.512
# by_ECB_2010          1.2690      0.108     11.711      0.000       1.057       1.481
# by_ECB_2011          1.3399      0.122     10.989      0.000       1.101       1.579
# by_ECB_2012         -0.1360      0.198     -0.687      0.492      -0.524       0.252
# by_ECB_2013         -1.0015      0.247     -4.047      0.000      -1.487      -0.516
# by_ECB_2014         -1.3444      0.316     -4.248      0.000      -1.965      -0.724
# by_ECB_2015          0.3642      0.058      6.333      0.000       0.251       0.477
# by_ECB_2016          0.8995      0.087     10.285      0.000       0.728       1.071
# by_ECB_2017          1.2167      0.055     22.056      0.000       1.109       1.325
# by_ECB_2018          1.3192      0.069     19.058      0.000       1.184       1.455
# by_ECB_2019          1.4149      0.083     17.060      0.000       1.252       1.578
# by_ECB_2020          0.9145      0.053     17.386      0.000       0.811       1.018
# by_ECB_2021          0.7240      0.053     13.740      0.000       0.621       0.827
# by_Fed_2010          0.0752      0.264      0.284      0.776      -0.443       0.593
# by_Fed_2011         -0.7468      0.330     -2.265      0.024      -1.393      -0.101
# by_Fed_2012         -0.3167      0.224     -1.416      0.157      -0.755       0.122
# by_Fed_2013         -0.9919      0.176     -5.638      0.000      -1.337      -0.647
# by_Fed_2014          0.2032      0.088      2.320      0.020       0.032       0.375
# by_Fed_2015         -0.8059      0.217     -3.707      0.000      -1.232      -0.380
# by_Fed_2016          0.0221      0.093      0.238      0.812      -0.160       0.204
# by_Fed_2017          0.2153      0.115      1.874      0.061      -0.010       0.441
# by_Fed_2018          0.5914      0.106      5.575      0.000       0.384       0.799
# by_Fed_2019          0.6922      0.106      6.533      0.000       0.485       0.900
# by_Fed_2020         -0.4220      0.125     -3.378      0.001      -0.667      -0.177
# by_Fed_2021         -1.1322      0.063    -17.932      0.000      -1.256      -1.008
# m_2                  0.1302      0.074      1.760      0.078      -0.015       0.275
# m_3                  0.0969      0.108      0.899      0.369      -0.114       0.308
# m_4                  0.0841      0.108      0.782      0.434      -0.127       0.295
# m_5                  0.0345      0.121      0.285      0.776      -0.203       0.272
# m_6                  0.0615      0.135      0.456      0.648      -0.203       0.326
# m_7                 -0.0427      0.132     -0.324      0.746      -0.301       0.216
# m_8                  0.0461      0.116      0.396      0.692      -0.182       0.274
# m_9                  0.0985      0.115      0.856      0.392      -0.127       0.324
# m_10                 0.0288      0.107      0.268      0.789      -0.182       0.239
# m_11                 0.0006      0.114      0.005      0.996      -0.223       0.224
# m_12                 0.1796      0.122      1.467      0.142      -0.060       0.420
# ====================================================================================
#
# [SHADOW_RAW Outcome-based p-share pooled] two-way cluster results
# p_share_F                 t_tw=  -0.798  p_tw=0.425
# ELB                       t_tw=  -0.660  p_tw=0.510
# [wild-cluster by ym] p_share_F: p_boot=0.020
#
# [Outcome-based p-share with ELB interaction]
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.4396      0.156      2.826      0.005       0.135       0.745
# p_share_F           -0.0615      0.113     -0.545      0.585      -0.282       0.159
# ELB                  0.0535      0.209      0.256      0.798      -0.356       0.463
# p_share_F_x_ELB     -0.1688      0.177     -0.954      0.340      -0.515       0.178
# QE_FG               -0.1097      0.072     -1.533      0.125      -0.250       0.031
# crisis10            -1.2610      0.089    -14.166      0.000      -1.435      -1.086
# pandem               0.5919      0.069      8.568      0.000       0.456       0.727
# abs_deltai_3_lag     0.0434      0.194      0.224      0.823      -0.336       0.423
# by_BoE_2011          0.5450      0.208      2.616      0.009       0.137       0.953
# by_BoE_2012          1.8213      0.193      9.447      0.000       1.443       2.199
# by_BoE_2013          0.8096      0.076     10.627      0.000       0.660       0.959
# by_BoE_2014         -0.0800      0.203     -0.394      0.693      -0.478       0.318
# by_BoE_2015         -1.5040      0.404     -3.721      0.000      -2.296      -0.712
# by_BoE_2016         -0.6763      0.263     -2.572      0.010      -1.192      -0.161
# by_BoE_2017          0.3374      0.081      4.171      0.000       0.179       0.496
# by_BoE_2018         -0.3434      0.235     -1.460      0.144      -0.804       0.117
# by_BoE_2019         -0.1641      0.183     -0.894      0.371      -0.524       0.196
# by_BoE_2020          0.2947      0.161      1.835      0.066      -0.020       0.609
# by_BoE_2021          0.2121      0.143      1.487      0.137      -0.067       0.492
# by_ECB_2010          1.2497      0.113     11.084      0.000       1.029       1.471
# by_ECB_2011          1.3266      0.119     11.133      0.000       1.093       1.560
# by_ECB_2012         -0.1321      0.197     -0.669      0.503      -0.519       0.255
# by_ECB_2013         -1.0006      0.249     -4.020      0.000      -1.488      -0.513
# by_ECB_2014         -1.3401      0.316     -4.240      0.000      -1.960      -0.721
# by_ECB_2015          0.3676      0.057      6.436      0.000       0.256       0.480
# by_ECB_2016          0.9036      0.087     10.344      0.000       0.732       1.075
# by_ECB_2017          1.2185      0.056     21.896      0.000       1.109       1.328
# by_ECB_2018          1.3172      0.068     19.323      0.000       1.184       1.451
# by_ECB_2019          1.4196      0.082     17.361      0.000       1.259       1.580
# by_ECB_2020          0.9190      0.052     17.697      0.000       0.817       1.021
# by_ECB_2021          0.7161      0.054     13.336      0.000       0.611       0.821
# by_Fed_2010          0.0643      0.262      0.245      0.806      -0.449       0.578
# by_Fed_2011         -0.7420      0.329     -2.254      0.024      -1.387      -0.097
# by_Fed_2012         -0.3143      0.223     -1.409      0.159      -0.752       0.123
# by_Fed_2013         -0.9938      0.177     -5.625      0.000      -1.340      -0.647
# by_Fed_2014          0.1903      0.091      2.097      0.036       0.012       0.368
# by_Fed_2015         -0.8033      0.218     -3.689      0.000      -1.230      -0.376
# by_Fed_2016         -0.0028      0.086     -0.032      0.974      -0.171       0.166
# by_Fed_2017          0.1989      0.113      1.763      0.078      -0.022       0.420
# by_Fed_2018          0.5740      0.100      5.759      0.000       0.379       0.769
# by_Fed_2019          0.6802      0.102      6.662      0.000       0.480       0.880
# by_Fed_2020         -0.4240      0.124     -3.414      0.001      -0.667      -0.181
# by_Fed_2021         -1.1261      0.068    -16.665      0.000      -1.259      -0.994
# m_2                  0.1272      0.074      1.730      0.084      -0.017       0.271
# m_3                  0.0958      0.107      0.892      0.372      -0.115       0.306
# m_4                  0.0842      0.107      0.784      0.433      -0.126       0.295
# m_5                  0.0343      0.121      0.283      0.777      -0.203       0.272
# m_6                  0.0608      0.135      0.451      0.652      -0.203       0.325
# m_7                 -0.0445      0.132     -0.337      0.736      -0.303       0.214
# m_8                  0.0467      0.116      0.403      0.687      -0.181       0.274
# m_9                  0.0987      0.115      0.859      0.390      -0.126       0.324
# m_10                 0.0311      0.108      0.289      0.773      -0.180       0.242
# m_11                 0.0005      0.114      0.004      0.996      -0.223       0.224
# m_12                 0.1847      0.123      1.501      0.133      -0.057       0.426
# ====================================================================================
#
# [SHADOW_RAW Outcome-based p-share] two-way cluster results
# p_share_F                 t_tw=     nan  p_tw=nan
# p_share_F_x_ELB           t_tw=  -0.507  p_tw=0.612
# ELB                       t_tw=   0.148  p_tw=0.882
# [wild-cluster by ym] p_share_F: p_boot=0.435
# [wild-cluster by ym] p_share_F_x_ELB: p_boot=0.200
#
# ------------------------------------------------------------------------------
# Inflation performance: pooled + ELB interactions
# ------------------------------------------------------------------------------
#
# [Inflation performance pooled: levels-only]
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.6596      0.217      3.037      0.002       0.234       1.085
# abs_infl_gap       -0.0115      0.070     -0.165      0.869      -0.148       0.125
# miss_streak_24m    -0.2939      0.205     -1.435      0.151      -0.695       0.107
# output_gap          0.0085      0.004      2.111      0.035       0.001       0.016
# ELB                -0.0004      0.149     -0.003      0.998      -0.293       0.292
# QE_FG              -0.1683      0.076     -2.205      0.027      -0.318      -0.019
# crisis10           -1.3746      0.110    -12.508      0.000      -1.590      -1.159
# pandem              0.6202      0.071      8.721      0.000       0.481       0.760
# by_BoE_2011         0.6264      0.213      2.939      0.003       0.209       1.044
# by_BoE_2012         2.0471      0.237      8.643      0.000       1.583       2.511
# by_BoE_2013         0.7281      0.111      6.563      0.000       0.511       0.946
# by_BoE_2014        -0.3204      0.241     -1.329      0.184      -0.793       0.152
# by_BoE_2015        -1.6245      0.376     -4.319      0.000      -2.362      -0.887
# by_BoE_2016        -0.6492      0.293     -2.218      0.027      -1.223      -0.075
# by_BoE_2017         0.3053      0.094      3.258      0.001       0.122       0.489
# by_BoE_2018        -0.4142      0.256     -1.619      0.105      -0.915       0.087
# by_BoE_2019        -0.2972      0.197     -1.508      0.131      -0.683       0.089
# by_BoE_2020         0.2230      0.192      1.159      0.246      -0.154       0.600
# by_BoE_2021         0.1515      0.199      0.762      0.446      -0.238       0.541
# by_BoE_2022         0.9414      0.194      4.858      0.000       0.562       1.321
# by_ECB_2010         1.4722      0.184      8.005      0.000       1.112       1.833
# by_ECB_2011         1.4355      0.142     10.143      0.000       1.158       1.713
# by_ECB_2012        -0.1894      0.194     -0.974      0.330      -0.570       0.192
# by_ECB_2013        -1.1706      0.251     -4.657      0.000      -1.663      -0.678
# by_ECB_2014        -1.4406      0.336     -4.282      0.000      -2.100      -0.781
# by_ECB_2015         0.5288      0.144      3.662      0.000       0.246       0.812
# by_ECB_2016         1.1526      0.207      5.573      0.000       0.747       1.558
# by_ECB_2017         1.3352      0.124     10.733      0.000       1.091       1.579
# by_ECB_2018         1.2551      0.075     16.733      0.000       1.108       1.402
# by_ECB_2019         1.2145      0.119     10.207      0.000       0.981       1.448
# by_ECB_2020         0.9282      0.086     10.820      0.000       0.760       1.096
# by_ECB_2021         0.8771      0.115      7.603      0.000       0.651       1.103
# by_ECB_2022         1.2695      0.188      6.761      0.000       0.901       1.637
# by_Fed_2010         0.4365      0.357      1.222      0.222      -0.263       1.136
# by_Fed_2011        -0.5731      0.329     -1.744      0.081      -1.217       0.071
# by_Fed_2012        -0.1881      0.242     -0.778      0.436      -0.662       0.286
# by_Fed_2013        -1.0561      0.158     -6.666      0.000      -1.367      -0.746
# by_Fed_2014         0.0889      0.129      0.689      0.491      -0.164       0.342
# by_Fed_2015        -0.8722      0.198     -4.400      0.000      -1.261      -0.484
# by_Fed_2016         0.1374      0.150      0.913      0.361      -0.157       0.432
# by_Fed_2017         0.2193      0.119      1.840      0.066      -0.014       0.453
# by_Fed_2018         0.4593      0.136      3.375      0.001       0.193       0.726
# by_Fed_2019         0.5471      0.143      3.820      0.000       0.266       0.828
# by_Fed_2020        -0.4994      0.136     -3.660      0.000      -0.767      -0.232
# by_Fed_2021        -1.0603      0.136     -7.773      0.000      -1.328      -0.793
# by_Fed_2022        -0.9234      0.266     -3.474      0.001      -1.444      -0.402
# m_2                 0.1068      0.070      1.530      0.126      -0.030       0.244
# m_3                 0.0641      0.104      0.615      0.538      -0.140       0.268
# m_4                 0.0773      0.108      0.713      0.476      -0.135       0.290
# m_5                 0.0076      0.117      0.064      0.949      -0.223       0.238
# m_6                 0.0306      0.131      0.234      0.815      -0.226       0.287
# m_7                -0.0603      0.131     -0.460      0.645      -0.317       0.196
# m_8                 0.0111      0.112      0.099      0.921      -0.209       0.231
# m_9                 0.0631      0.111      0.566      0.571      -0.155       0.282
# m_10                0.0104      0.110      0.095      0.925      -0.204       0.225
# m_11               -0.0244      0.117     -0.209      0.834      -0.253       0.204
# m_12                0.1201      0.126      0.955      0.340      -0.126       0.367
# ...
# by_ECB_2016               1.3211      0.227      5.813      0.000       0.876       1.767
# by_ECB_2017               1.4627      0.146     10.048      0.000       1.177       1.748
# by_ECB_2018               1.2445      0.069     18.143      0.000       1.110       1.379
# by_ECB_2019               1.1034      0.131      8.454      0.000       0.848       1.359
# by_ECB_2020               0.9130      0.090     10.173      0.000       0.737       1.089
# by_ECB_2021               0.9822      0.138      7.103      0.000       0.711       1.253
# by_ECB_2022               1.2937      0.180      7.200      0.000       0.942       1.646
# by_Fed_2010               0.4111      0.349      1.178      0.239      -0.273       1.095
# by_Fed_2011              -0.5551      0.326     -1.702      0.089      -1.194       0.084
# by_Fed_2012              -0.1406      0.245     -0.575      0.566      -0.620       0.339
# by_Fed_2013              -1.0912      0.145     -7.523      0.000      -1.376      -0.807
# by_Fed_2014               0.0127      0.134      0.094      0.925      -0.250       0.276
# by_Fed_2015              -0.9374      0.194     -4.824      0.000      -1.318      -0.557
# by_Fed_2016              -0.0477      0.167     -0.286      0.775      -0.375       0.279
# by_Fed_2017               0.1064      0.126      0.846      0.398      -0.140       0.353
# by_Fed_2018               0.6048      0.176      3.434      0.001       0.260       0.950
# by_Fed_2019               0.6714      0.197      3.412      0.001       0.286       1.057
# by_Fed_2020              -0.5358      0.149     -3.607      0.000      -0.827      -0.245
# by_Fed_2021              -1.1476      0.112    -10.229      0.000      -1.367      -0.928
# by_Fed_2022              -1.3848      0.287     -4.823      0.000      -1.948      -0.822
# m_2                       0.1048      0.071      1.480      0.139      -0.034       0.243
# m_3                       0.0615      0.103      0.598      0.550      -0.140       0.263
# m_4                       0.0647      0.108      0.597      0.551      -0.148       0.277
# m_5                       0.0021      0.117      0.018      0.986      -0.227       0.231
# m_6                       0.0468      0.131      0.357      0.721      -0.210       0.303
# m_7                      -0.0572      0.131     -0.438      0.662      -0.313       0.199
# m_8                       0.0131      0.113      0.117      0.907      -0.208       0.234
# m_9                       0.0763      0.113      0.677      0.499      -0.145       0.297
# m_10                      0.0055      0.111      0.049      0.961      -0.213       0.224
# m_11                     -0.0293      0.122     -0.240      0.810      -0.268       0.210
# m_12                      0.1367      0.128      1.070      0.284      -0.114       0.387
# =========================================================================================
#
# [SHADOW_RAW Inflation performance] two-way cluster results
# abs_infl_gap              t_tw=  -1.093  p_tw=0.274
# abs_infl_gap_x_ELB        t_tw=   2.266  p_tw=0.023
# miss_streak_24m           t_tw=   0.220  p_tw=0.826
# miss_streak_24m_x_ELB     t_tw=  -1.278  p_tw=0.201
# [wild-cluster by ym] abs_infl_gap: p_boot=0.140
# [wild-cluster by ym] abs_infl_gap_x_ELB: p_boot=0.312
# [wild-cluster by ym] miss_streak_24m: p_boot=0.605
# [wild-cluster by ym] miss_streak_24m_x_ELB: p_boot=0.018
#
# ====================================================================================================
# SUMMARY — SHADOW_RAW DETERMINANTS
# ====================================================================================================
# Outcome-based p-share pooled: β(p_share_F)=-0.1756 se=0.0971 p=0.071
# Outcome-based p-share: β(p_share_F | ELB=0)=-0.0615 se=0.1127 p=0.585 | Δβ at ELB=-0.1688 se=0.1769 p=0.340
# Inflation performance pooled: β(|π-π*|)=-0.0115 se=0.0698 p=0.869 | β(streak)=-0.2939 se=0.2047 p=0.151
# Inflation performance: β(|π-π*| | ELB=0)=-0.2677 se=0.1412 p=0.058 | Δβ at ELB=0.2968 se=0.1343 p=0.027
# Inflation performance: β(streak | ELB=0)=0.1574 se=0.2981 p=0.597 | Δβ at ELB=-0.6671 se=0.3166 p=0.035
#
# Data workbook: Dataset for Credibility.xlsx
# Best AP(3) rolling RF window: 84
#
# ============================================
# AP(3) rolling-window CV
# ============================================
#    window       mse  n_surprise
# 0      84  0.041809         636
# 1      72  0.046119         636
# 2      60  0.047798         636
# 3      48  0.050689         636
# 4      36  0.063083         636
# ============================================
# AP(3) scale stats
# ============================================
#       q_lo      q_hi
# 0  0.00122  1.943602
# ============================================
# US 5y5y validation: correlations
# ============================================
#                        label sample_start sample_end    N  \
# 0  AP(3) raw low-credibility   2012-01-31 2021-12-31  120
#
#    corr_y_t5y5y_pearson  corr_y_t5y5y_spearman  corr_y_absdev_pearson  \
# 0             -0.343918               -0.21458               0.095352
#
#    corr_y_absdev_spearman  corr_y_downside_gap_pearson  \
# 0                0.063671                     0.465522
#
#    corr_y_downside_gap_spearman
# 0                      0.249331
# ============================================
# US 5y5y validation: downside-gap regressions
# ============================================
#             spec           variable      coef    se_hac     t_hac     p_hac  \
# 0          no_FE  downside_anch_gap  1.375025  0.634287  2.167828  0.030172
# 1       month_FE  downside_anch_gap  1.372294  0.624447  2.197614  0.027977
# 2  year_month_FE  downside_anch_gap  0.625820  0.402050  1.556572  0.119572
#
#      ci_low   ci_high    N sample_start sample_end  year_FE  month_FE
# 0  0.131845  2.618205  120   2012-01-31 2021-12-31    False     False
# 1  0.148400  2.596188  120   2012-01-31 2021-12-31    False      True
# 2 -0.162184  1.413823  120   2012-01-31 2021-12-31     True      True
# ============================================
# US 5y5y validation: baseline summary
# ============================================
#                        label                     validation_object  \
# 0  AP(3) raw low-credibility  downside_anch_gap = max(2 - 5y5y, 0)
#
#    baseline_spec  higher_is_worse  beta_downside_anch_gap   se_hac     p_hac  \
# 0  year_month_FE             True                 0.62582  0.40205  0.119572
#
#    n_joint sample_start sample_end
# 0      120   2012-01-31 2021-12-31
# ============================================
# Shadow EGARCH meta
# ============================================
#    ar_lags          ar_source egarch_ok
# US       0  legacy_forced_AR0      True
# EU       0  legacy_forced_AR0      True
# UK       0  legacy_forced_AR0      True
# ============================================
# Shadow anchor stats
# ============================================
#        q_lo      q_hi  anchor_end
# 0 -1.976854  1.050862  2010-12-01
# ============================================
# Shadow EGARCH vs GJR robustness
# ============================================
#   econ  corr(egarch,gjr)  T_common
# 0   US          0.989707       169
# 1   EU          0.973072       169
# 2   UK          0.991215       169
# ============================================
# Sacrifice-ratio validation summary
# ============================================
#                                    model      coef    se_hac     p_hac    N  \
# 0  SR_H12 ~ cred_lag12 + country dummies -0.229203  0.075652  0.002448  170
#
#    HAC_lags
# 0        12
# ============================================
# AP3 determinant coefficients
# ============================================
#                                     spec               variable      coef  \
# 0   AP3_RAW_Outcome_based_p-share_pooled              p_share_F -0.035979
# 1   AP3_RAW_Outcome_based_p-share_pooled                    ELB  0.140364
# 2   AP3_RAW_Outcome_based_p-share_pooled                  QE_FG -0.222310
# 3   AP3_RAW_Outcome_based_p-share_pooled               crisis10 -0.091409
# 4   AP3_RAW_Outcome_based_p-share_pooled                 pandem  0.078308
# 5   AP3_RAW_Outcome_based_p-share_pooled       abs_deltai_3_lag  0.358111
# 6   AP3_RAW_Outcome-based_p-share_regime              p_share_F  0.059838
# 7   AP3_RAW_Outcome-based_p-share_regime                    ELB  0.255495
# 8   AP3_RAW_Outcome-based_p-share_regime        p_share_F_x_ELB -0.140051
# 9   AP3_RAW_Outcome-based_p-share_regime                  QE_FG -0.210604
# 10  AP3_RAW_Outcome-based_p-share_regime               crisis10 -0.084320
# 11  AP3_RAW_Outcome-based_p-share_regime                 pandem  0.069596
# 12  AP3_RAW_Outcome-based_p-share_regime       abs_deltai_3_lag  0.365429
# 13  AP3_RAW_Inflation_performance_pooled           abs_infl_gap -0.082566
# 14  AP3_RAW_Inflation_performance_pooled        miss_streak_24m -0.010018
# 15  AP3_RAW_Inflation_performance_pooled             output_gap  0.001574
# 16  AP3_RAW_Inflation_performance_pooled                    ELB  0.256023
# 17  AP3_RAW_Inflation_performance_pooled                  QE_FG -0.732589
# 18  AP3_RAW_Inflation_performance_pooled               crisis10 -0.389876
# 19  AP3_RAW_Inflation_performance_pooled                 pandem  0.000826
# 20  AP3_RAW_Inflation_performance_regime           abs_infl_gap -0.339428
# 21  AP3_RAW_Inflation_performance_regime     abs_infl_gap_x_ELB  0.310422
# 22  AP3_RAW_Inflation_performance_regime        miss_streak_24m  0.179765
# 23  AP3_RAW_Inflation_performance_regime  miss_streak_24m_x_ELB -0.339846
# 24  AP3_RAW_Inflation_performance_regime             output_gap  0.001576
# 25  AP3_RAW_Inflation_performance_regime                    ELB  0.345750
# 26  AP3_RAW_Inflation_performance_regime                  QE_FG -0.890212
# 27  AP3_RAW_Inflation_performance_regime               crisis10 -0.496694
# 28  AP3_RAW_Inflation_performance_regime                 pandem -0.098022
#
#       se_hac     t_hac         p_hac    ci_low   ci_high
# 0   0.054649 -0.658375  5.102972e-01 -0.143089  0.071130
# 1   0.117993  1.189593  2.342063e-01 -0.090899  0.371627
# 2   0.105926 -2.098724  3.584121e-02 -0.429921 -0.014698
# 3   0.050238 -1.819500  6.883520e-02 -0.189874  0.007057
# 4   0.039174  1.998960  4.561267e-02  0.001528  0.155089
# 5   0.075975  4.713563  2.434221e-06  0.209203  0.507018
# 6   0.133617  0.447833  6.542740e-01 -0.202046  0.321721
# 7   0.197858  1.291306  1.965977e-01 -0.132299  0.643290
# 8   0.148665 -0.942058  3.461628e-01 -0.431429  0.151327
# 9   0.098903 -2.129402  3.322098e-02 -0.404450 -0.016758
# 10  0.046475 -1.814334  6.962633e-02 -0.175409  0.006768
# 11  0.041180  1.690047  9.101894e-02 -0.011115  0.150308
# 12  0.072042  5.072450  3.927267e-07  0.224230  0.506629
# 13  0.040897 -2.018875  4.350019e-02 -0.162723 -0.002409
# 14  0.086599 -0.115684  9.079031e-01 -0.179750  0.159714
# 15  0.002606  0.604121  5.457634e-01 -0.003533  0.006681
# 16  0.121137  2.113497  3.455829e-02  0.018599  0.493448
# 17  0.197162 -3.715679  2.026591e-04 -1.119019 -0.346160
# 18  0.111334 -3.501864  4.620152e-04 -0.608086 -0.171666
# 19  0.069500  0.011887  9.905157e-01 -0.135391  0.137044
# 20  0.095689 -3.547206  3.893393e-04 -0.526974 -0.151881
# 21  0.086165  3.602645  3.149961e-04  0.141542  0.479303
# 22  0.179485  1.001565  3.165539e-01 -0.172018  0.531549
# 23  0.167315 -2.031174  4.223738e-02 -0.667777 -0.011914
# 24  0.002515  0.626763  5.308146e-01 -0.003353  0.006505
# 25  0.192405  1.796985  7.233793e-02 -0.031358  0.722858
# 26  0.179767 -4.952027  7.344428e-07 -1.242550 -0.537875
# 27  0.105042 -4.728538  2.261424e-06 -0.702572 -0.290816
# 28  0.071195 -1.376802  1.685733e-01 -0.237562  0.041518
# ============================================
# Shadow determinant coefficients
# ============================================
#                                        spec               variable      coef  \
# 0   SHADOW_RAW_Outcome_based_p-share_pooled              p_share_F -0.175550
# 1   SHADOW_RAW_Outcome_based_p-share_pooled                    ELB -0.078709
# 2   SHADOW_RAW_Outcome_based_p-share_pooled                  QE_FG -0.110954
# 3   SHADOW_RAW_Outcome_based_p-share_pooled               crisis10 -1.258089
# 4   SHADOW_RAW_Outcome_based_p-share_pooled                 pandem  0.609323
# 5   SHADOW_RAW_Outcome_based_p-share_pooled       abs_deltai_3_lag  0.026027
# 6   SHADOW_RAW_Outcome-based_p-share_regime              p_share_F -0.061460
# 7   SHADOW_RAW_Outcome-based_p-share_regime                    ELB  0.053456
# 8   SHADOW_RAW_Outcome-based_p-share_regime        p_share_F_x_ELB -0.168756
# 9   SHADOW_RAW_Outcome-based_p-share_regime                  QE_FG -0.109690
# 10  SHADOW_RAW_Outcome-based_p-share_regime               crisis10 -1.260958
# 11  SHADOW_RAW_Outcome-based_p-share_regime                 pandem  0.591878
# 12  SHADOW_RAW_Outcome-based_p-share_regime       abs_deltai_3_lag  0.043450
# 13  SHADOW_RAW_Inflation_performance_pooled           abs_infl_gap -0.011512
# 14  SHADOW_RAW_Inflation_performance_pooled        miss_streak_24m -0.293851
# 15  SHADOW_RAW_Inflation_performance_pooled             output_gap  0.008468
# 16  SHADOW_RAW_Inflation_performance_pooled                    ELB -0.000448
# 17  SHADOW_RAW_Inflation_performance_pooled                  QE_FG -0.168257
# 18  SHADOW_RAW_Inflation_performance_pooled               crisis10 -1.374622
# 19  SHADOW_RAW_Inflation_performance_pooled                 pandem  0.620221
# 20  SHADOW_RAW_Inflation_performance_regime           abs_infl_gap -0.267681
# 21  SHADOW_RAW_Inflation_performance_regime     abs_infl_gap_x_ELB  0.296826
# 22  SHADOW_RAW_Inflation_performance_regime        miss_streak_24m  0.157424
# 23  SHADOW_RAW_Inflation_performance_regime  miss_streak_24m_x_ELB -0.667122
# 24  SHADOW_RAW_Inflation_performance_regime             output_gap  0.008060
# 25  SHADOW_RAW_Inflation_performance_regime                    ELB  0.393388
# 26  SHADOW_RAW_Inflation_performance_regime                  QE_FG -0.201772
# 27  SHADOW_RAW_Inflation_performance_regime               crisis10 -1.440353
# 28  SHADOW_RAW_Inflation_performance_regime                 pandem  0.598295
#
#       se_hac      t_hac         p_hac    ci_low   ci_high
# 0   0.097124  -1.807481  7.068731e-02 -0.365911  0.014810
# 1   0.127593  -0.616877  5.373158e-01 -0.328787  0.171368
# 2   0.072867  -1.522698  1.278343e-01 -0.253771  0.031862
# 3   0.089868 -13.999336  1.573343e-44 -1.434227 -1.081952
# 4   0.063680   9.568559  1.084065e-21  0.484513  0.734133
# 5   0.201504   0.129162  8.972296e-01 -0.368913  0.420966
# 6   0.112673  -0.545475  5.854271e-01 -0.282295  0.159375
# 7   0.208736   0.256092  7.978794e-01 -0.355659  0.462571
# 8   0.176909  -0.953910  3.401291e-01 -0.515491  0.177980
# 9   0.071552  -1.533013  1.252726e-01 -0.249928  0.030549
# 10  0.089016 -14.165554  1.496809e-45 -1.435426 -1.086490
# 11  0.069078   8.568246  1.050735e-17  0.456487  0.727269
# 12  0.193754   0.224252  8.225613e-01 -0.336302  0.423201
# 13  0.069756  -0.165035  8.689166e-01 -0.148232  0.125208
# 14  0.204706  -1.435475  1.511518e-01 -0.695068  0.107366
# 15  0.004011   2.111178  3.475701e-02  0.000607  0.016329
# 16  0.149384  -0.002998  9.976079e-01 -0.293236  0.292340
# 17  0.076311  -2.204883  2.746229e-02 -0.317823 -0.018690
# 18  0.109900 -12.507961  6.753580e-36 -1.590022 -1.159222
# 19  0.071120   8.720799  2.762461e-18  0.480829  0.759613
# 20  0.141207  -1.895668  5.800400e-02 -0.544441  0.009079
# 21  0.134345   2.209419  2.714550e-02  0.033513  0.560138
# 22  0.298127   0.528044  5.974689e-01 -0.426894  0.741743
# 23  0.316587  -2.107231  3.509758e-02 -1.287622 -0.046623
# 24  0.003628   2.221913  2.628919e-02  0.000950  0.015170
# 25  0.322415   1.220127  2.224167e-01 -0.238535  1.025310
# 26  0.077249  -2.611974  9.002115e-03 -0.353177 -0.050367
# 27  0.114177 -12.615114  1.743063e-36 -1.664135 -1.216571
# 28  0.070593   8.475239  2.345980e-17  0.459934  0.736655
