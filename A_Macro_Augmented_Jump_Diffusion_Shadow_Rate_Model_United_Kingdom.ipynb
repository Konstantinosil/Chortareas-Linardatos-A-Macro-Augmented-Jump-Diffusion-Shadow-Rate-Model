# %% [markdown]
# <a href="https://colab.research.google.com/github/Konstantinosil/Chortareas-Linardatos-A-Macro-Augmented-Jump-Diffusion-Shadow-Rate-Model/blob/main/A_Macro_Augmented_Jump_Diffusion_Shadow_Rate_Model_United_Kingdom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import subprocess
import importlib.util

needed = []
for pkg, pip_name in [
    ("filterpy", "filterpy==1.4.5"),
    ("openpyxl", "openpyxl"),
]:
    if importlib.util.find_spec(pkg) is None:
        needed.append(pip_name)

if needed:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *needed])

import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import minimize
from filterpy.kalman import KalmanFilter

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox, het_arch
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.api import VAR

try:
    from IPython.display import display
except Exception:
    def display(x):
        print(x)

warnings.filterwarnings("ignore")

SEED = 42
rng  = np.random.default_rng(SEED)
np.random.seed(SEED)

OUTPUT_DIR = Path("replication_outputs_uk")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


def find_input_file(filename):
    """
    Locate required input files for journal replication.
    This is path-portability polish only; it does not change any calculation.
    """
    candidates = [
        Path(filename),
        Path("data") / filename,
        Path("data") / "raw" / filename,
        Path("/content") / filename,
        Path("/content") / "data" / filename,
        Path("/content") / "data" / "raw" / filename,
        Path("/mnt/data") / filename,
    ]

    for p in candidates:
        if p.exists():
            return p

    raise FileNotFoundError(
        f"Could not find {filename}. Put it in the notebook folder, data/raw/, or /content."
    )


DATA = find_input_file("Dataset United Kingdom.xlsx")
xls = pd.ExcelFile(DATA)

print(f"Using input dataset: {DATA.resolve()}")
print(f"Writing outputs to: {OUTPUT_DIR.resolve()}")


def _prep(sheet, cols):
    df = pd.read_excel(xls, sheet, header=1)
    df = df.iloc[:, :len(cols)].copy()
    df.columns = cols
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
    for c in cols[1:]:
        df[c] = pd.to_numeric(df[c], errors="coerce")
    return df.dropna(subset=["Date"]).set_index("Date")

ser = {
    "SR" : _prep("Shadow Rates UK", ["Date","SR UK"]),
    "INF": _prep("Inflation Data UK", ["Date","INF UK"]),
    "UN" : _prep("Unemployment Data UK", ["Date","UNEM UK"]),
    "CDS": _prep("Sovereign CDS Spreads UK", ["Date","CDS UK"]),
    "GDP": _prep("Real GDP UK", ["Date","GDP UK"]),
    "EX" : _prep("Exchange Rates UK", ["Date","EX UK"]),
    "3M" : _prep("3M",  ["Date","3M UK"]),
    "6M" : _prep("6M",  ["Date","6M UK"]),
    "1Y" : _prep("1Y",  ["Date","1Y UK"]),
    "2Y" : _prep("2Y",  ["Date","2Y UK"]),
    "5Y" : _prep("5Y",  ["Date","5Y UK"]),
    "7Y" : _prep("7Y",  ["Date","7Y UK"]),
    "10Y": _prep("10Y", ["Date","10Y UK"]),
    "30Y": _prep("30Y", ["Date","30Y UK"]),
}

df = pd.concat(ser.values(), axis=1).interpolate("linear")
macro = ["INF UK","UNEM UK","EX UK","CDS UK","GDP UK"]
ylds  = ["3M UK","6M UK","1Y UK","2Y UK","5Y UK","7Y UK","10Y UK","30Y UK"]

df[ylds] = df[ylds] * 100
df    = df.dropna(subset=["SR UK"] + macro + ylds)

y_df, m_df = df[ylds].copy(), df[macro].copy()

var_list = ylds + macro
tbl_station, tbl_ac, tbl_arch = [], [], []

for v in var_list:
    s0 = df[v].dropna()
    adf0 = adfuller(s0, autolag='AIC'); stat0, p0 = adf0[0], adf0[1]

    if p0 < .05:
        tbl_station.append([v, stat0, p0, 'Stat']);  s_final = s0
    else:
        s1 = s0.diff().dropna()
        adf1 = adfuller(s1, autolag='AIC')
        tbl_station += [[f'{v}(orig)',stat0,p0,'NOT stat'],
                        [f'{v}(Δ1)',adf1[0],adf1[1],
                         'Stat' if adf1[1]<.05 else 'NOT']]
        s_final = s1

    lb_p   = acorr_ljungbox(s_final, lags=[10], return_df=True)['lb_pvalue'].iloc[0]
    arch_p = het_arch(s_final, maxlag=10)[1]
    tbl_ac.append([v, lb_p,   'Sig' if lb_p<.05  else 'OK'])
    tbl_arch.append([v, arch_p,'Sig' if arch_p<.05 else 'OK'])

print("\n=== ADF ===");   display(pd.DataFrame(tbl_station, columns=['Var','ADF','p','Res']))
print("\n=== LB  ===");  display(pd.DataFrame(tbl_ac,      columns=['Var','p','AC?']))
print("\n=== ARCH ==="); display(pd.DataFrame(tbl_arch,    columns=['Var','p','ARCH?']))

if y_df.abs().max().max() > 20:
    y_df /= 100

low, upp = y_df.mean()-3*y_df.std(), y_df.mean()+3*y_df.std()
y_df = y_df.clip(lower=low, upper=upp, axis=1)

m_z  = pd.DataFrame(StandardScaler().fit_transform(m_df),
                    index=m_df.index, columns=m_df.columns)

def _beta(y,z):
    X = add_constant(z)
    return {c: OLS(y[c],X).fit().params.values for c in y}

def _pca(y):
    return PCA(1,random_state=SEED).fit_transform(y).ravel()

def _sim(n,r0,z,β,ψ,lb=-2):
    κ,σ,λ,μ,s,θ0,θ1,θ2 = ψ; z0,z1 = 240,1992
    S=np.empty(n); S[0]=r0
    for t in range(1,n):
        θ = θ0 if t<z0 else (θ1 if t<=z1 else θ2)
        S[t]=S[t-1]+κ*(θ-S[t-1])+σ*rng.normal()
        if rng.random()<λ:
            S[t]+=rng.normal(μ,s)
        if S[t]<lb:
            S[t]=lb+0.3*(S[t]-lb)
        Xt=z.iloc[t].values
        S[t]+=0.5*np.mean([Xt@β[m][1:] for m in β])
    return S

def _kalman(x):
    kf=KalmanFilter(dim_x=1,dim_z=1)
    kf.x=[[x[0]]]; kf.F=kf.H=np.eye(1); kf.P*=100; kf.R[:]=1; kf.Q[:]=0.01
    out=[]
    for v in x:
        kf.predict()
        kf.update([[v]])
        out.append(kf.x[0,0])
    return np.array(out)

β   = _beta(y_df,m_z)
pca = _pca(y_df)

print("\n=== β̂m (macro loading per maturity) ===")
for m, coef in β.items():
    print(f"{m:>5}: {coef[1]:+.4f}")

pca = _pca(y_df)
θ0, θ1, θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()

θ0,θ1,θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()
x0  = [0.15,0.015,0.005,0.10,0.05, θ0,θ1,θ2]
bnd = [(1e-4,1),(1e-4,0.05),(0,0.1),(-.5,.5),(1e-4,0.2),(-5,5),(-5,5),(-5,5)]
obj = lambda p: ((_sim(len(pca),pca[0],m_z,β,p)-pca)**2).sum()
ψhat= minimize(obj,x0,bounds=bnd,method='L-BFGS-B',
               options={'maxiter':500}).x

S     = _sim(len(pca),pca[0],m_z,β,ψhat)
S_sm  = _kalman(S)
final = pd.Series(0.7*pca+0.3*S_sm,index=df.index,name='Final SR')

print("\nψ̂:",np.round(ψhat,4))
display(final.head())

ws   = np.arange(0.50, 0.95, 0.05)
rmse = []

for w in ws:
    shadow = w*pca + (1-w)*S_sm
    errs = []
    for m in ylds:
        y_hat = OLS(y_df[m], add_constant(shadow)).fit().fittedvalues
        errs.append(((y_df[m]-y_hat)**2).mean())
    rmse.append(np.sqrt(np.mean(errs))*1e4)

grid = pd.DataFrame({"w": ws, "RMSE_bp": rmse})
print(grid.round(2))

grid.plot(x="w", y="RMSE_bp", marker="o", figsize=(4,3.5))
plt.ylabel("mean cross-section RMSE (bp) (U.K.)")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5,3.5))
plt.bar(range(1,9), PCA().fit(y_df).explained_variance_ratio_)
plt.xlabel('PC')
plt.ylabel('Explained var share')
plt.title('Scree Plot – United Kingdom Yield Curve')
plt.tight_layout()
plt.show()

plt.figure(figsize=(11,5))
plt.plot(df.index,final,label='Final SR')
plt.plot(df.index,pca,'--',label='PCA')
plt.grid()
plt.legend()
plt.title('UK shadow-rate')
plt.show()

start,end='2009-01-01','2022-08-01'
alpha=0.05

ewma = final.ewm(alpha=alpha,adjust=False).mean().loc[start:end]
wu   = df['SR UK'].loc[start:end]

plt.figure(figsize=(11,5))
plt.plot(final.resample('M').mean().loc[start:end],lw=2,label='MAJD')
plt.plot(wu.resample('M').last(),'--',label='WX')
plt.grid()
plt.legend()
plt.ylabel('%')
plt.title('MAJD vs WX (United Kingdom)')
plt.show()

plt.figure(figsize=(11,5))
plt.plot(ewma,lw=2,label=f'Final EWMA (α={alpha})')
plt.plot(wu,'--',label='Wu-Xia')
plt.grid()
plt.legend()
plt.ylabel('%')
plt.title('Final EWMA vs Wu-Xia (daily)')
plt.show()

fit_tbl=[]
for m in ylds:
    rmse_f = np.sqrt(((OLS(y_df[m], add_constant(final)).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    rmse_w = np.sqrt(((OLS(y_df[m], add_constant(df['SR UK'])).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    fit_tbl.append([m, rmse_f, rmse_w])

fit_df = pd.DataFrame(fit_tbl, columns=['Maturity','RMSE_final','RMSE_WX'])
print("\n=== In-sample cross-section RMSE (bp) ===")
display(fit_df)

TEST_START = '2023-01-01'
train      = final.loc[:TEST_START]
test_idx   = final.loc[TEST_START:].index
n_train    = len(train)

oos_len   = len(test_idx)

ar1 = AutoReg(train, lags=1, old_names=False).fit()

pred_path = ar1.forecast(steps=oos_len)
pred_path.index = test_idx

fc_df = pd.DataFrame({f'h{h}': pred_path.shift(h-1)
                      for h in range(1, 13)},
                     index=test_idx)

oos_tbl=[]
for m in ylds:
    a,b = OLS(y_df[m].loc[:TEST_START], add_constant(train)).fit().params
    act = y_df[m].loc[TEST_START:]
    for h in range(1,13):
        rmse = np.sqrt(((a + b*fc_df[f'h{h}'] - act)**2).mean())*1e4
        oos_tbl.append([m, h, rmse])

oos_df = (pd.DataFrame(oos_tbl, columns=['Maturity','h','RMSE_bp'])
            .pivot(index='Maturity', columns='h', values='RMSE_bp')
            .reindex(ylds))

print("\n=== OOS RMSE (bp) – forecast horizon h = 1…12 months ===")
display(oos_df.round(2))

OUT_CSV = OUTPUT_DIR / "shadow_rate_uk.csv"
OUT_XLSX = OUTPUT_DIR / "shadow_rate_uk.xlsx"

final.to_csv(OUT_CSV, index_label="Date")
final.to_excel(OUT_XLSX, sheet_name="UK SR")

print(f"\n✓ Shadow-rate series written to:  {OUT_CSV.resolve()}")
print(f"  Rows written: {len(final):,}")



def _master_aux(sheet, colname_out, source_col=None):
    raw = pd.read_excel(xls, sheet_name=sheet, header=1)
    raw = raw.iloc[:, :2].copy()
    raw.columns = ["Date", colname_out]
    raw["Date"] = pd.to_datetime(raw["Date"], errors="coerce")
    raw[colname_out] = pd.to_numeric(raw[colname_out], errors="coerce")
    return raw.dropna(subset=["Date"]).set_index("Date")

wu_xia_uk = _master_aux("Shadow Rates UK", "WX (United Kingdom)")

shadow_rates_uk = final.to_frame(name="MAJD (United Kingdom)")
industrial_prod_uk = _master_aux("Industrial Production UK", "Ind Prod UK")
cpi_uk = _master_aux("Inflation Data UK", "CPI UK")
unemployment_uk = _master_aux("Unemployment Data UK", "Unemployment UK")
bond_yields_uk_3m = _master_aux("3M", "Bond Yield UK 3M")
bond_yields_uk_10y = _master_aux("10Y", "Bond Yields UK 10Y")

uk_data_with_wu_xia = pd.concat([
    wu_xia_uk,
    shadow_rates_uk,
    industrial_prod_uk,
    cpi_uk,
    unemployment_uk,
    bond_yields_uk_3m,
    bond_yields_uk_10y
], axis=1).dropna()

print(uk_data_with_wu_xia.columns)

SHADOW_COLS_UK = ['WX (United Kingdom)', 'MAJD (United Kingdom)']
FACTOR_COLS_UK = [c for c in uk_data_with_wu_xia.columns if c not in SHADOW_COLS_UK]

diff_uk = uk_data_with_wu_xia.diff().dropna()
diff_uk.index = pd.date_range(start=diff_uk.index[0], periods=len(diff_uk), freq='ME')

standardized_factor_data_uk = (
    diff_uk[FACTOR_COLS_UK] - diff_uk[FACTOR_COLS_UK].mean()
) / diff_uk[FACTOR_COLS_UK].std()

pca_uk = PCA(n_components=3)
pca_factors_uk = pca_uk.fit_transform(standardized_factor_data_uk)

common_factors_uk = pd.DataFrame(
    pca_factors_uk,
    index=diff_uk.index,
    columns=['Factor1', 'Factor2', 'Factor3']
)
common_factors_uk[['Factor1', 'Factor2']] *= -1

def process_data_for_VAR(diff_data, common_factors, shadow_rate_col):
    var_data = pd.concat([common_factors, diff_data[[shadow_rate_col]]], axis=1).dropna()
    return var_data

uk_favar_data_your_shadow = process_data_for_VAR(
    diff_uk,
    common_factors_uk,
    shadow_rate_col='MAJD (United Kingdom)'
)

uk_favar_data_wu_xia_shadow = process_data_for_VAR(
    diff_uk,
    common_factors_uk,
    shadow_rate_col='WX (United Kingdom)'
)

def fit_VAR_and_analyze(data, lags=2, n_periods=10):
    """
    • Fits a VAR(lags) to the input DataFrame.
    • Prints the full coefficient tables, information criteria,
      and residual-correlation matrix.
    • Returns both the fitted VAR object and its orthogonalised IRF object.
    """
    model     = VAR(data)
    var_model = model.fit(lags)

    print("\n=== VAR({}) estimation results ===".format(lags))
    print(var_model.summary())
    print("\nCorrelation matrix of residuals")
    print(var_model.resid.corr())

    irf = var_model.irf(n_periods)
    return var_model, irf

var_your_shadow, irf_your_shadow = fit_VAR_and_analyze(
    uk_favar_data_your_shadow, lags=2, n_periods=10)

var_wu_xia, irf_wu_xia_shadow = fit_VAR_and_analyze(
    uk_favar_data_wu_xia_shadow, lags=2, n_periods=10)

print("Impulse Response for the MAJD (United Kingdom):")
fig = irf_your_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(ax.get_title().replace("MAJD (United Kingdom)", "MAJD (U.K.)"))
plt.show()

print("Impulse Response for WX (United Kingdom):")
fig = irf_wu_xia_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(ax.get_title().replace("WX (United Kingdom)", "WX (U.K.)"))
plt.show()

def calculate_cumulative_irf(irf_object, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_object.orth_irfs[:n_periods]
    response_names = irf_object.model.names

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            response_values = irf_matrix[:, j, i]
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(response_values))

    return cumulative_irf

cumulative_irf_your_shadow = calculate_cumulative_irf(irf_your_shadow, n_periods=10)
cumulative_irf_wu_xia_shadow = calculate_cumulative_irf(irf_wu_xia_shadow, n_periods=10)

comparison_df = pd.DataFrame({
    "MAJD (United Kingdom)": cumulative_irf_your_shadow,
    "WX (United Kingdom)": cumulative_irf_wu_xia_shadow
}).T

comparison_df.loc['Difference'] = (
    comparison_df.loc['MAJD (United Kingdom)'] - comparison_df.loc['WX (United Kingdom)']
)

print("Cumulative Impulse Responses Comparison for UK:")
print(comparison_df)

output_file = OUTPUT_DIR / 'cumulative_irf_comparison_uk.csv'
comparison_df.to_csv(output_file)
print(f"Comparison data saved as '{output_file}'.")

comparison_df.loc["MAJD (United Kingdom)"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="MAJD")
comparison_df.loc["WX (United Kingdom)"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="WX", color="orange")
plt.title("Cumulative Impulse Responses Comparison (United Kingdom)")
plt.xlabel("Response → Impulse")
plt.ylabel("Cumulative IRF")
plt.legend()
plt.tight_layout()
plt.show()


shadow_uk = final.to_frame(name='MAJD (United Kingdom)')
inflation_uk = _master_aux("Inflation Data UK", "INF UK")
gdp_uk = _master_aux("Real GDP UK", "GDP UK")

data_uk = pd.concat([shadow_uk, inflation_uk, gdp_uk], axis=1).dropna()

print("\nMerged Data Columns (UK):")
print(data_uk.columns)

data_uk['INF UK'] = data_uk['INF UK'].pct_change() * 100
data_uk['GDP UK'] = data_uk['GDP UK'].pct_change() * 100

data_uk = data_uk.dropna()

print("\nAfter transformations (first few rows):")
print(data_uk.head())

def prepare_var_data(df):
    standardized_data = (df - df.mean()) / df.std()
    return standardized_data

var_data_uk = prepare_var_data(data_uk)

model_uk = VAR(var_data_uk)
lag_order = 2
results_uk = model_uk.fit(lag_order)

print("\nVAR Model Summary (UK):")
print(results_uk.summary())

n_periods = 20
irf_uk = results_uk.irf(n_periods)

print("\nImpulse Response Functions (UK system):")
fig = irf_uk.plot(orth=True)
for ax in fig.axes:
    ax.set_title(
        ax.get_title()
        .replace("INF UK", "CPI U.K.")
        .replace("GDP UK", "Real GDP U.K.")
        .replace("MAJD (United Kingdom)", "MAJD (U.K.)")
    )
plt.suptitle('Impulse Response Functions - MAJD (United Kingdom)')
plt.show()

def calculate_cumulative_irf(irf_obj, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_obj.orth_irfs[:n_periods]
    response_names = irf_obj.model.names

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(irf_matrix[:, j, i]))

    return cumulative_irf

cumulative_irf_uk = calculate_cumulative_irf(irf_uk)
cumulative_irf_uk_df = pd.DataFrame(cumulative_irf_uk, index=['Cumulative IRF'])

print("\nCumulative IRF Results (UK):")
print(cumulative_irf_uk_df.T)

simple_var_out = OUTPUT_DIR / 'cumulative_irf_final_shadow_uk.xlsx'
cumulative_irf_uk_df.T.to_excel(simple_var_out)
print(f"\nCumulative IRF saved to '{simple_var_out}'.")


def process_data_for_VAR_alt(diff_data, common_factors, shadow_rate_col):
    var_data = pd.concat([diff_data[[shadow_rate_col]], common_factors], axis=1).dropna()
    return var_data

uk_favar_data_alt_your_shadow = process_data_for_VAR_alt(
    diff_uk,
    common_factors_uk,
    shadow_rate_col='MAJD (United Kingdom)'
)

uk_favar_data_alt_wu_xia_shadow = process_data_for_VAR_alt(
    diff_uk,
    common_factors_uk,
    shadow_rate_col='WX (United Kingdom)'
)

print("Alternative-order VAR data columns (MAJD):")
print(uk_favar_data_alt_your_shadow.columns.tolist())

print("\nAlternative-order VAR data columns (WX):")
print(uk_favar_data_alt_wu_xia_shadow.columns.tolist())

var_alt_your_shadow, irf_alt_your_shadow = fit_VAR_and_analyze(
    uk_favar_data_alt_your_shadow, lags=2, n_periods=10
)

var_alt_wu_xia, irf_alt_wu_xia_shadow = fit_VAR_and_analyze(
    uk_favar_data_alt_wu_xia_shadow, lags=2, n_periods=10
)

print("Impulse Response for the MAJD (United Kingdom) - Alternative Ordering:")
fig = irf_alt_your_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(
        ax.get_title()
        .replace("MAJD (United Kingdom)", "MAJD (U.K.)")
    )
plt.suptitle("Orthogonalised IRFs - MAJD (U.K.) | Alternative Ordering", y=1.02)
plt.tight_layout()
plt.show()

print("Impulse Response for WX (United Kingdom) - Alternative Ordering:")
fig = irf_alt_wu_xia_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(
        ax.get_title()
        .replace("WX (United Kingdom)", "WX (U.K.)")
    )
plt.suptitle("Orthogonalised IRFs - WX (U.K.) | Alternative Ordering", y=1.02)
plt.tight_layout()
plt.show()

cumulative_irf_alt_your_shadow = calculate_cumulative_irf(irf_alt_your_shadow, n_periods=10)
cumulative_irf_alt_wu_xia_shadow = calculate_cumulative_irf(irf_alt_wu_xia_shadow, n_periods=10)

comparison_alt_df = pd.DataFrame({
    "MAJD (United Kingdom) - AltOrder": cumulative_irf_alt_your_shadow,
    "WX (United Kingdom) - AltOrder": cumulative_irf_alt_wu_xia_shadow
}).T

comparison_alt_df.loc["Difference"] = (
    comparison_alt_df.loc["MAJD (United Kingdom) - AltOrder"]
    - comparison_alt_df.loc["WX (United Kingdom) - AltOrder"]
)

print("\nCumulative IRF Comparison for United Kingdom (Alternative Ordering):")
print(comparison_alt_df)

comparison_alt_out = OUTPUT_DIR / "cumulative_irf_comparison_uk_alt_order.csv"
comparison_alt_df.to_csv(comparison_alt_out)
print(f"\nSaved: {comparison_alt_out}")

def shadow_shock_only(irf_object, shadow_name, n_periods=10):
    irf_matrix = irf_object.orth_irfs[:n_periods]
    names = irf_object.model.names
    shock_idx = names.index(shadow_name)

    out = {}
    for j, response in enumerate(names):
        out[f"{response} ← shock in {shadow_name}"] = np.sum(np.abs(irf_matrix[:, j, shock_idx]))
    return pd.Series(out)

shadow_only_alt_majd = shadow_shock_only(
    irf_alt_your_shadow,
    shadow_name="MAJD (United Kingdom)",
    n_periods=10
)

shadow_only_alt_wx = shadow_shock_only(
    irf_alt_wu_xia_shadow,
    shadow_name="WX (United Kingdom)",
    n_periods=10
)

shadow_only_alt_df = pd.concat(
    [shadow_only_alt_majd, shadow_only_alt_wx],
    axis=1
)
shadow_only_alt_df.columns = ["MAJD AltOrder", "WX AltOrder"]
shadow_only_alt_df["Difference"] = shadow_only_alt_df["MAJD AltOrder"] - shadow_only_alt_df["WX AltOrder"]

print("\nCumulative responses to SHADOW-RATE shock only (Alternative Ordering):")
print(shadow_only_alt_df)

shadow_only_alt_out = OUTPUT_DIR / "shadow_shock_only_uk_alt_order.csv"
shadow_only_alt_df.to_csv(shadow_only_alt_out)
print(f"\nSaved: {shadow_only_alt_out}")
# Out:
# Using input dataset: /content/Dataset United Kingdom.xlsx
# Writing outputs to: /content/replication_outputs_uk
#
# === ADF ===
#               Var        ADF             p       Res
# 0     3M UK(orig)  -1.557293  5.050035e-01  NOT stat
# 1       3M UK(Δ1)  -7.329764  1.135944e-10      Stat
# 2     6M UK(orig)  -1.539067  5.141046e-01  NOT stat
# 3       6M UK(Δ1)  -7.453321  5.595950e-11      Stat
# 4     1Y UK(orig)  -1.651850  4.560760e-01  NOT stat
# 5       1Y UK(Δ1) -10.648476  4.728016e-19      Stat
# 6     2Y UK(orig)  -1.606587  4.802841e-01  NOT stat
# 7       2Y UK(Δ1) -10.694724  3.649474e-19      Stat
# 8     5Y UK(orig)  -1.926093  3.198875e-01  NOT stat
# 9       5Y UK(Δ1) -32.719194  0.000000e+00      Stat
# 10          7Y UK -20.036017  0.000000e+00      Stat
# 11   10Y UK(orig)  -1.681793  4.405171e-01  NOT stat
# 12     10Y UK(Δ1) -14.831548  1.895896e-27      Stat
# 13   30Y UK(orig)  -1.123014  7.058076e-01  NOT stat
# ...
