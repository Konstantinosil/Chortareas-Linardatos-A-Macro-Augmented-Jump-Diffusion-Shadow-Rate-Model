# %% [markdown]
# <a href="https://colab.research.google.com/github/Konstantinosil/Chortareas-Linardatos-A-Macro-Augmented-Jump-Diffusion-Shadow-Rate-Model/blob/main/A_Macro_Augmented_Jump_Diffusion_Shadow_Rate_Model_Euro_Area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import subprocess
import importlib.util

needed = []
for pkg, pip_name in [
    ("filterpy", "filterpy==1.4.5"),
    ("openpyxl", "openpyxl"),
]:
    if importlib.util.find_spec(pkg) is None:
        needed.append(pip_name)

if needed:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *needed])

import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import minimize
from filterpy.kalman import KalmanFilter

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox, het_arch
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.api import VAR

try:
    from IPython.display import display
except Exception:
    def display(x):
        print(x)

warnings.filterwarnings("ignore")

SEED = 42
rng  = np.random.default_rng(SEED)
np.random.seed(SEED)

OUTPUT_DIR = Path("replication_outputs_ea")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


def find_input_file(filename):
    """
    Finds input files in the current directory, /content, or /mnt/data.
    This is only path-polish; it does not change any calculations.
    """
    candidates = [
        Path(filename),
        Path("/content") / filename,
        Path("/mnt/data") / filename,
    ]
    for p in candidates:
        if p.exists():
            return p
    raise FileNotFoundError(
        f"Could not find {filename}. Put it in the notebook working directory or /content."
    )


def _irf_names(irf_object):
    """
    Version-safe way to retrieve VAR variable names from statsmodels IRF objects.
    This does not change the IRF calculation; it only avoids attribute-name
    differences across statsmodels versions.
    """
    candidates = [
        getattr(irf_object, "model", None),
        getattr(getattr(irf_object, "model", None), "model", None),
        irf_object,
    ]
    for obj in candidates:
        if obj is None:
            continue
        for attr in ("names", "endog_names"):
            if hasattr(obj, attr):
                names = getattr(obj, attr)
                if names is not None:
                    return list(names)
    raise AttributeError("Could not recover endogenous variable names from IRF object.")


DATA = find_input_file("Dataset Euro Area.xlsx")
xls  = pd.ExcelFile(DATA)

def _prep(sheet, cols):
    df = pd.read_excel(xls, sheet, header=1)
    df.columns = cols
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True, errors="coerce")
    return df.dropna(subset=["Date"]).set_index("Date")

def _prep_aux(sheet, cols):
    """
    Reads auxiliary monthly/daily sheets from the master workbook with the
    date parsing used by the original FAVAR/simple-VAR auxiliary workbooks
    (i.e., no dayfirst=True). This preserves the old FAVAR/new-entry
    date alignment exactly.
    """
    df = pd.read_excel(xls, sheet, header=1)
    df.columns = cols
    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
    return df.dropna(subset=["Date"]).set_index("Date")

ser = {
    "SR" : _prep("Shadow Rates EU", ["Date","SR EU"]),
    "INF": _prep("Inflation Data EU", ["Date","INF EU"]),
    "UN" : _prep("Unemployment Data EU", ["Date","UNEM EU"]),
    "CDS": _prep("Sovereign CDS Spreads EU", ["Date","CDS EU"]),
    "GDP": _prep("Real GDP EU", ["Date","GDP EU"]),
    "EX" : _prep("Exchange Rates EU", ["Date","EX EU"]),
    "3M" : _prep("3M",  ["Date","3M EU"]),
    "6M" : _prep("6M",  ["Date","6M EU"]),
    "1Y" : _prep("1Y",  ["Date","1Y EU"]),
    "2Y" : _prep("2Y",  ["Date","2Y EU"]),
    "5Y" : _prep("5Y",  ["Date","5Y EU"]),
    "7Y" : _prep("7Y",  ["Date","7Y EU"]),
    "10Y": _prep("10Y", ["Date","10Y EU"]),
    "30Y": _prep("30Y", ["Date","30Y EU"]),
}

df = pd.concat(ser.values(), axis=1).interpolate("linear")
macro = ["INF EU","UNEM EU","EX EU","CDS EU","GDP EU"]
ylds  = ["3M EU","6M EU","1Y EU","2Y EU","5Y EU","7Y EU","10Y EU","30Y EU"]
df    = df.dropna(subset=["SR EU"] + macro + ylds)

y_df, m_df = df[ylds].copy(), df[macro].copy()

var_list = ylds + macro
tbl_station, tbl_ac, tbl_arch = [], [], []

for v in var_list:
    s0 = df[v].dropna()
    adf0 = adfuller(s0, autolag='AIC'); stat0, p0 = adf0[0], adf0[1]

    if p0 < .05:
        tbl_station.append([v, stat0, p0, 'Stat']);  s_final = s0
    else:
        s1 = s0.diff().dropna()
        adf1 = adfuller(s1, autolag='AIC')
        tbl_station += [[f'{v}(orig)',stat0,p0,'NOT stat'],
                        [f'{v}(Δ1)',adf1[0],adf1[1],
                         'Stat' if adf1[1]<.05 else 'NOT']]
        s_final = s1

    lb_p   = acorr_ljungbox(s_final, lags=[10], return_df=True)['lb_pvalue'].iloc[0]
    arch_p = het_arch(s_final, maxlag=10)[1]
    tbl_ac.append([v, lb_p,   'Sig' if lb_p<.05  else 'OK'])
    tbl_arch.append([v, arch_p,'Sig' if arch_p<.05 else 'OK'])

print("\n=== ADF ===");   display(pd.DataFrame(tbl_station, columns=['Var','ADF','p','Res']))
print("\n=== LB  ===");  display(pd.DataFrame(tbl_ac,      columns=['Var','p','AC?']))
print("\n=== ARCH ==="); display(pd.DataFrame(tbl_arch,    columns=['Var','p','ARCH?']))

if y_df.abs().max().max() > 20: y_df /= 100
low, upp = y_df.mean()-3*y_df.std(), y_df.mean()+3*y_df.std()
y_df = y_df.clip(lower=low, upper=upp, axis=1)
m_z  = pd.DataFrame(StandardScaler().fit_transform(m_df),
                    index=m_df.index, columns=m_df.columns)

def _beta(y,z):
    X = add_constant(z); return {c: OLS(y[c],X).fit().params.values for c in y}

def _pca(y): return PCA(1,random_state=SEED).fit_transform(y).ravel()

def _sim(n,r0,z,β,ψ,lb=-2):
    κ,σ,λ,μ,s,θ0,θ1,θ2 = ψ; z0,z1 = 102,805
    S=np.empty(n); S[0]=r0
    for t in range(1,n):
        θ = θ0 if t<z0 else (θ1 if t<=z1 else θ2)
        S[t]=S[t-1]+κ*(θ-S[t-1])+σ*rng.normal()
        if rng.random()<λ: S[t]+=rng.normal(μ,s)
        if S[t]<lb: S[t]=lb+0.3*(S[t]-lb)
        Xt=z.iloc[t].values
        S[t]+=0.5*np.mean([Xt@β[m][1:] for m in β])
    return S

def _kalman(x):
    kf=KalmanFilter(dim_x=1,dim_z=1)
    kf.x=[[x[0]]]; kf.F=kf.H=np.eye(1); kf.P*=100; kf.R[:]=1; kf.Q[:]=0.01
    out=[]
    for v in x: kf.predict(); kf.update([[v]]); out.append(kf.x[0,0])
    return np.array(out)

β   = _beta(y_df,m_z); pca = _pca(y_df)
print("\n=== β̂m (macro loading per maturity) ===")
for m, coef in β.items():
    print(f"{m:>5}: {coef[1]:+.4f}")
pca = _pca(y_df)
θ0, θ1, θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()

θ0,θ1,θ2 = pca[:50].mean(), pca[50:150].mean(), pca[150:].mean()
x0  = [0.15,0.015,0.005,0.10,0.05, θ0,θ1,θ2]
bnd = [(1e-4,1),(1e-4,0.05),(0,0.1),(-.5,.5),(1e-4,0.2),(-5,5),(-5,5),(-5,5)]
obj = lambda p: ((_sim(len(pca),pca[0],m_z,β,p)-pca)**2).sum()
ψhat= minimize(obj,x0,bounds=bnd,method='L-BFGS-B',
               options={'maxiter':500}).x

S     = _sim(len(pca),pca[0],m_z,β,ψhat)
S_sm  = _kalman(S)
final = pd.Series(0.7*pca+0.3*S_sm,index=df.index,name='Final SR')

print("\nψ̂:",np.round(ψhat,4))
display(final.head())

ws   = np.arange(0.50, 0.95, 0.05)
rmse = []

for w in ws:
    shadow = w*pca + (1-w)*S_sm
    errs = []
    for m in ylds:
        y_hat = OLS(y_df[m], add_constant(shadow)).fit().fittedvalues
        errs.append(((y_df[m]-y_hat)**2).mean())
    rmse.append(np.sqrt(np.mean(errs))*1e4)

grid = pd.DataFrame({"w": ws, "RMSE_bp": rmse})
print(grid.round(2))

grid.plot(x="w", y="RMSE_bp", marker="o", figsize=(4,3.5))
plt.ylabel("mean cross-section RMSE (bp) (E.A.)"); plt.tight_layout(); plt.show()

plt.figure(figsize=(5,3.5))
plt.bar(range(1,9), PCA().fit(y_df).explained_variance_ratio_)
plt.xlabel('PC'); plt.ylabel('Explained var share')
plt.title('Scree Plot – Euro Area Yield Curve'); plt.tight_layout(); plt.show()

plt.figure(figsize=(11,5))
plt.plot(df.index,final,label='Final SR')
plt.plot(df.index,pca,'--',label='PCA'); plt.grid(); plt.legend()
plt.title('EU shadow-rate'); plt.show()

start,end='2009-01-01','2022-08-01'; alpha=0.05
ewma = final.ewm(alpha=alpha,adjust=False).mean().loc[start:end]
wu   = df['SR EU'].loc[start:end]

plt.figure(figsize=(11,5))
plt.plot(final.resample('M').mean().loc[start:end],lw=2,label='MAJD')
plt.plot(wu.resample('M').last(),'--',label='WX'); plt.grid(); plt.legend()
plt.ylabel('%'); plt.title('MAJD vs WX (Euro Area)'); plt.show()

plt.figure(figsize=(11,5))
plt.plot(ewma,lw=2,label=f'Final EWMA (α={alpha})')
plt.plot(wu,'--',label='Wu-Xia'); plt.grid(); plt.legend()
plt.ylabel('%'); plt.title('Final EWMA vs Wu-Xia (daily)'); plt.show()

fit_tbl=[]
for m in ylds:
    rmse_f = np.sqrt(((OLS(y_df[m], add_constant(final)).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    rmse_w = np.sqrt(((OLS(y_df[m], add_constant(df['SR EU'])).fit()
                       .fittedvalues - y_df[m])**2).mean())*1e4
    fit_tbl.append([m, rmse_f, rmse_w])

fit_df = pd.DataFrame(fit_tbl, columns=['Maturity','RMSE_final','RMSE_WX'])
print("\n=== In-sample cross-section RMSE (bp) ==="); display(fit_df)

TEST_START = '2023-01-01'
train      = final.loc[:TEST_START]
test_idx   = final.loc[TEST_START:].index
n_train    = len(train)

oos_len   = len(test_idx)

ar1 = AutoReg(train, lags=1, old_names=False).fit()

pred_path = ar1.forecast(steps=oos_len)
pred_path.index = test_idx

fc_df = pd.DataFrame({f'h{h}': pred_path.shift(h-1)
                      for h in range(1, 13)},
                     index=test_idx)

oos_tbl=[]
for m in ylds:
    a,b = OLS(y_df[m].loc[:TEST_START], add_constant(train)).fit().params
    act = y_df[m].loc[TEST_START:]
    for h in range(1,13):
        rmse = np.sqrt(((a + b*fc_df[f'h{h}'] - act)**2).mean())*1e4
        oos_tbl.append([m, h, rmse])

oos_df = (pd.DataFrame(oos_tbl, columns=['Maturity','h','RMSE_bp'])
            .pivot(index='Maturity', columns='h', values='RMSE_bp')
            .reindex(ylds))

print("\n=== OOS RMSE (bp) – forecast horizon h = 1…12 months ===")
display(oos_df.round(2))

OUT = OUTPUT_DIR / "shadow_rate_eu.csv"
final.to_csv(OUT, index_label="Date")
final.to_excel(OUTPUT_DIR / "shadow_rate_eu.xlsx", sheet_name="EU SR")

print(f"\n✓ Shadow-rate series written to:  {OUT.resolve()}")
print(f"  Rows written: {len(final):,}")


wu_xia_eu = _prep_aux("Shadow Rates EU", ["Date", "WX (Euro Area)"])

shadow_rates_eu = final.rename("MAJD (Euro Area)").to_frame()

indeutrial_prod_eu = _prep_aux(
    "Industrial Production EU",
    ["Date", "Ind Prod EU"]
)

cpi_eu = _prep_aux(
    "Inflation Data EU",
    ["Date", "CPI EU"]
)

unemployment_eu = _prep_aux(
    "Unemployment Data EU",
    ["Date", "Unemployment EU"]
)

bond_yields_eu_3m = _prep_aux(
    "3M",
    ["Date", "Bond Yield EU 3M"]
)

bond_yields_eu_10y = _prep_aux(
    "10Y",
    ["Date", "Bond Yield EU 10Y"]
)

eu_data_with_wu_xia = pd.concat([
    wu_xia_eu,
    shadow_rates_eu,
    indeutrial_prod_eu,
    cpi_eu,
    unemployment_eu,
    bond_yields_eu_3m,
    bond_yields_eu_10y
], axis=1).dropna()

print(eu_data_with_wu_xia.columns)

SHADOW_COLS_EU = ['WX (Euro Area)', 'MAJD (Euro Area)']
FACTOR_COLS_EU = [c for c in eu_data_with_wu_xia.columns if c not in SHADOW_COLS_EU]

diff_eu = eu_data_with_wu_xia.diff().dropna()
diff_eu.index = pd.date_range(start=diff_eu.index[0], periods=len(diff_eu), freq='ME')

standardized_factor_data_eu = (
    diff_eu[FACTOR_COLS_EU] - diff_eu[FACTOR_COLS_EU].mean()
) / diff_eu[FACTOR_COLS_EU].std()

pca_eu = PCA(n_components=3)
pca_factors_eu = pca_eu.fit_transform(standardized_factor_data_eu)

common_factors_eu = pd.DataFrame(
    pca_factors_eu,
    index=diff_eu.index,
    columns=['Factor1', 'Factor2', 'Factor3']
)

def process_data_for_VAR(diff_data, common_factors, shadow_rate_col):
    var_data = pd.concat([common_factors, diff_data[[shadow_rate_col]]], axis=1).dropna()
    return var_data

eu_favar_data_your_shadow = process_data_for_VAR(
    diff_eu,
    common_factors_eu,
    shadow_rate_col='MAJD (Euro Area)'
)

eu_favar_data_wu_xia_shadow = process_data_for_VAR(
    diff_eu,
    common_factors_eu,
    shadow_rate_col='WX (Euro Area)'
)

def fit_VAR_and_analyze(data, lags=2, n_periods=10):
    """
    • Fits a VAR(lags) to the input DataFrame.
    • Prints the full coefficient tables, information criteria,
      and residual-correlation matrix.
    • Returns both the fitted VAR object and its orthogonalised IRF object.
    """
    model     = VAR(data)
    var_model = model.fit(lags)

    print("\n=== VAR({}) estimation results ===".format(lags))
    print(var_model.summary())
    print("\nCorrelation matrix of residuals")
    print(var_model.resid.corr())

    irf = var_model.irf(n_periods)
    return var_model, irf

var_your_shadow, irf_your_shadow = fit_VAR_and_analyze(
    eu_favar_data_your_shadow, lags=2, n_periods=10)

var_wu_xia, irf_wu_xia_shadow = fit_VAR_and_analyze(
    eu_favar_data_wu_xia_shadow, lags=2, n_periods=10)

print("Impulse Response for the MAJD (Euro Area):")
fig = irf_your_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(ax.get_title().replace("MAJD (Euro Area)", "MAJD (E.A.)"))
plt.show()

print("Impulse Response for WX (Euro Area):")
fig = irf_wu_xia_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(ax.get_title().replace("WX (Euro Area)", "WX (E.A.)"))
plt.show()

def calculate_cumulative_irf(irf_object, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_object.orth_irfs[:n_periods]
    response_names = _irf_names(irf_object)

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            response_values = irf_matrix[:, j, i]
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(response_values))

    return cumulative_irf

cumulative_irf_your_shadow = calculate_cumulative_irf(irf_your_shadow, n_periods=10)
cumulative_irf_wu_xia_shadow = calculate_cumulative_irf(irf_wu_xia_shadow, n_periods=10)

comparison_df = pd.DataFrame({
    "MAJD (Euro Area)": cumulative_irf_your_shadow,
    "WX (Euro Area)": cumulative_irf_wu_xia_shadow
}).T

comparison_df.loc['Difference'] = (
    comparison_df.loc['MAJD (Euro Area)'] - comparison_df.loc['WX (Euro Area)']
)

print("Cumulative Impulse Responses Comparison for EU:")
print(comparison_df)

output_file = OUTPUT_DIR / 'cumulative_irf_comparison_eu.csv'
comparison_df.to_csv(output_file)
print(f"Comparison data saved as '{output_file}'.")

comparison_df.loc["MAJD (Euro Area)"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="MAJD")
comparison_df.loc["WX (Euro Area)"].plot(kind="bar", figsize=(10, 6), alpha=0.7, label="WX", color="orange")
plt.title("Cumulative Impulse Responses Comparison (Euro Area)")
plt.xlabel("Response → Impulse")
plt.ylabel("Cumulative IRF")
plt.legend()
plt.tight_layout()
plt.show()


shadow_eu = final.rename("MAJD (Euro Area)").to_frame()
inflation_eu = _prep_aux("Inflation Data EU", ["Date", "INF EU"])
gdp_eu = _prep_aux("Real GDP EU", ["Date", "GDP EU"])

data_eu = pd.concat([shadow_eu, inflation_eu, gdp_eu], axis=1).dropna()

print("\nMerged Data Columns (EU):")
print(data_eu.columns)

data_eu['INF EU'] = data_eu['INF EU'].pct_change() * 100
data_eu['GDP EU'] = data_eu['GDP EU'].pct_change() * 100

data_eu = data_eu.dropna()

print("\nAfter transformations (first few rows):")
print(data_eu.head())

def prepare_var_data(df):
    standardized_data = (df - df.mean()) / df.std()
    return standardized_data

var_data_eu = prepare_var_data(data_eu)

model_eu = VAR(var_data_eu)
lag_order = 2
results_eu = model_eu.fit(lag_order)

print("\nVAR Model Summary (EU):")
print(results_eu.summary())

n_periods = 20
irf_eu = results_eu.irf(n_periods)

print("\nImpulse Response Functions (EU system):")
fig = irf_eu.plot(orth=True)
for ax in fig.axes:
    ax.set_title(
        ax.get_title()
        .replace("INF EU", "CPI E.A.")
        .replace("GDP EU", "Real GDP E.A.")
        .replace("MAJD (Euro Area)", "MAJD (E.A.)")
    )
plt.suptitle('Impulse Response Functions - MAJD (Euro Area)')
plt.show()

def calculate_cumulative_irf_simple(irf_obj, n_periods=10):
    cumulative_irf = {}
    irf_matrix = irf_obj.orth_irfs[:n_periods]
    response_names = _irf_names(irf_obj)

    for i, impulse in enumerate(response_names):
        for j, response in enumerate(response_names):
            cumulative_irf[f"{response} → {impulse}"] = np.sum(np.abs(irf_matrix[:, j, i]))

    return cumulative_irf

cumulative_irf_eu = calculate_cumulative_irf_simple(irf_eu)
cumulative_irf_eu_df = pd.DataFrame(cumulative_irf_eu, index=['Cumulative IRF'])

print("\nCumulative IRF Results (EU):")
print(cumulative_irf_eu_df.T)

cumulative_irf_eu_df.T.to_excel(OUTPUT_DIR / 'cumulative_irf_final_shadow_eu.xlsx')
print("\nCumulative IRF saved to replication_outputs_ea/cumulative_irf_final_shadow_eu.xlsx.")


def process_data_for_VAR_alt(diff_data, common_factors, shadow_rate_col):
    var_data = pd.concat([diff_data[[shadow_rate_col]], common_factors], axis=1).dropna()
    return var_data

eu_favar_data_alt_your_shadow = process_data_for_VAR_alt(
    diff_eu,
    common_factors_eu,
    shadow_rate_col='MAJD (Euro Area)'
)

eu_favar_data_alt_wu_xia_shadow = process_data_for_VAR_alt(
    diff_eu,
    common_factors_eu,
    shadow_rate_col='WX (Euro Area)'
)

print("Alternative-order VAR data columns (MAJD):")
print(eu_favar_data_alt_your_shadow.columns.tolist())

print("\nAlternative-order VAR data columns (WX):")
print(eu_favar_data_alt_wu_xia_shadow.columns.tolist())

var_alt_your_shadow, irf_alt_your_shadow = fit_VAR_and_analyze(
    eu_favar_data_alt_your_shadow, lags=2, n_periods=10
)

var_alt_wu_xia, irf_alt_wu_xia_shadow = fit_VAR_and_analyze(
    eu_favar_data_alt_wu_xia_shadow, lags=2, n_periods=10
)

print("Impulse Response for the MAJD (Euro Area) - Alternative Ordering:")
fig = irf_alt_your_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(
        ax.get_title()
        .replace("MAJD (Euro Area)", "MAJD (E.A.)")
    )
plt.suptitle("Orthogonalised IRFs - MAJD (E.A.) | Alternative Ordering", y=1.02)
plt.tight_layout()
plt.show()

print("Impulse Response for WX (Euro Area) - Alternative Ordering:")
fig = irf_alt_wu_xia_shadow.plot(orth=True)
for ax in fig.axes:
    ax.set_title(
        ax.get_title()
        .replace("WX (Euro Area)", "WX (E.A.)")
    )
plt.suptitle("Orthogonalised IRFs - WX (E.A.) | Alternative Ordering", y=1.02)
plt.tight_layout()
plt.show()

cumulative_irf_alt_your_shadow = calculate_cumulative_irf(irf_alt_your_shadow, n_periods=10)
cumulative_irf_alt_wu_xia_shadow = calculate_cumulative_irf(irf_alt_wu_xia_shadow, n_periods=10)

comparison_alt_df = pd.DataFrame({
    "MAJD (Euro Area) - AltOrder": cumulative_irf_alt_your_shadow,
    "WX (Euro Area) - AltOrder": cumulative_irf_alt_wu_xia_shadow
}).T

comparison_alt_df.loc["Difference"] = (
    comparison_alt_df.loc["MAJD (Euro Area) - AltOrder"]
    - comparison_alt_df.loc["WX (Euro Area) - AltOrder"]
)

print("\nCumulative IRF Comparison for Euro Area (Alternative Ordering):")
print(comparison_alt_df)

comparison_alt_df.to_csv(OUTPUT_DIR / "cumulative_irf_comparison_eu_alt_order.csv")
print("\nSaved: replication_outputs_ea/cumulative_irf_comparison_eu_alt_order.csv")

def shadow_shock_only(irf_object, shadow_name, n_periods=10):
    irf_matrix = irf_object.orth_irfs[:n_periods]
    names = _irf_names(irf_object)
    shock_idx = names.index(shadow_name)

    out = {}
    for j, response in enumerate(names):
        out[f"{response} ← shock in {shadow_name}"] = np.sum(np.abs(irf_matrix[:, j, shock_idx]))
    return pd.Series(out)

shadow_only_alt_majd = shadow_shock_only(
    irf_alt_your_shadow,
    shadow_name="MAJD (Euro Area)",
    n_periods=10
)

shadow_only_alt_wx = shadow_shock_only(
    irf_alt_wu_xia_shadow,
    shadow_name="WX (Euro Area)",
    n_periods=10
)

shadow_only_alt_df = pd.concat(
    [shadow_only_alt_majd, shadow_only_alt_wx],
    axis=1
)
shadow_only_alt_df.columns = ["MAJD AltOrder", "WX AltOrder"]
shadow_only_alt_df["Difference"] = shadow_only_alt_df["MAJD AltOrder"] - shadow_only_alt_df["WX AltOrder"]

print("\nCumulative responses to SHADOW-RATE shock only (Alternative Ordering):")
print(shadow_only_alt_df)

shadow_only_alt_df.to_csv(OUTPUT_DIR / "shadow_shock_only_eu_alt_order.csv")
print("\nSaved: replication_outputs_ea/shadow_shock_only_eu_alt_order.csv")
# Out:
# === ADF ===
#               Var        ADF             p       Res
# 0     3M EU(orig)  -1.966270  3.015553e-01  NOT stat
# 1       3M EU(Δ1) -12.881831  4.641304e-24      Stat
# 2     6M EU(orig)  -2.106384  2.419551e-01  NOT stat
# 3       6M EU(Δ1) -13.115691  1.600921e-24      Stat
# 4     1Y EU(orig)  -2.141170  2.282852e-01  NOT stat
# 5       1Y EU(Δ1) -13.223977  9.887211e-25      Stat
# 6     2Y EU(orig)  -2.174103  2.157783e-01  NOT stat
# 7       2Y EU(Δ1) -13.079758  1.881449e-24      Stat
# 8     5Y EU(orig)  -2.002812  2.853415e-01  NOT stat
# 9       5Y EU(Δ1) -13.271080  8.035126e-25      Stat
# 10    7Y EU(orig)  -1.868190  3.471703e-01  NOT stat
# 11      7Y EU(Δ1) -13.698446  1.303409e-25      Stat
# 12   10Y EU(orig)  -1.701928  4.301193e-01  NOT stat
# 13     10Y EU(Δ1) -15.335681  3.891829e-28      Stat
# 14   30Y EU(orig)  -1.687119  4.377613e-01  NOT stat
# 15     30Y EU(Δ1) -16.549403  1.951270e-29      Stat
# 16   INF EU(orig)   0.414048  9.820128e-01  NOT stat
# 17     INF EU(Δ1)  -8.505836  1.203638e-13      Stat
# 18  UNEM EU(orig)  -0.855918  8.021426e-01  NOT stat
# 19    UNEM EU(Δ1)  -4.507256  1.907878e-04      Stat
# 20          EX EU  -4.841728  4.522386e-05      Stat
# 21   CDS EU(orig)  -2.698867  7.423460e-02  NOT stat
# 22     CDS EU(Δ1) -11.002975  6.610820e-20      Stat
# 23   GDP EU(orig)  -1.614040  4.758551e-01  NOT stat
# 24     GDP EU(Δ1)  -6.351300  2.606917e-08      Stat
# === LB  ===
#         Var              p  AC?
# 0     3M EU   0.000000e+00  Sig
# 1     6M EU   0.000000e+00  Sig
# 2     1Y EU   0.000000e+00  Sig
# 3     2Y EU  5.310339e-128  Sig
# 4     5Y EU   1.687226e-73  Sig
# 5     7Y EU   1.540112e-81  Sig
# 6    10Y EU   7.307992e-89  Sig
# 7    30Y EU   2.281397e-63  Sig
# 8    INF EU   0.000000e+00  Sig
# 9   UNEM EU   0.000000e+00  Sig
# 10    EX EU   0.000000e+00  Sig
# 11   CDS EU   7.158456e-55  Sig
# 12   GDP EU   0.000000e+00  Sig
# === ARCH ===
#         Var              p ARCH?
# 0     3M EU  1.696081e-122   Sig
# 1     6M EU  1.323065e-144   Sig
# 2     1Y EU   1.745783e-94   Sig
# 3     2Y EU  6.138335e-103   Sig
# 4     5Y EU  1.312643e-117   Sig
# 5     7Y EU  1.113906e-107   Sig
# 6    10Y EU   8.681232e-97   Sig
# 7    30Y EU   3.594336e-57   Sig
# 8    INF EU   0.000000e+00   Sig
# 9   UNEM EU   0.000000e+00   Sig
# 10    EX EU   0.000000e+00   Sig
# 11   CDS EU  5.423597e-139   Sig
# 12   GDP EU   0.000000e+00   Sig
# === β̂m (macro loading per maturity) ===
# 3M EU: +1.5684
# 6M EU: +1.5506
# 1Y EU: +1.4670
# 2Y EU: +1.2873
# 5Y EU: +0.9974
# 7Y EU: +0.9113
# 10Y EU: +0.8499
# 30Y EU: +0.5738
#
# ψ̂: [ 0.15    0.015   0.005   0.1     0.05    5.      5.     -0.2341]
# Date
# 2008-07-22    7.925374
# 2008-07-23    8.005088
# 2008-07-24    8.083726
# 2008-07-25    8.164605
# 2008-07-28    8.244170
# Name: Final SR, dtype: float64
#       w  RMSE_bp
# 0  0.50  6385.76
# 1  0.55  6120.17
# 2  0.60  5870.62
# 3  0.65  5641.02
# 4  0.70  5435.19
# 5  0.75  5256.62
# 6  0.80  5108.25
# 7  0.85  4992.26
# 8  0.90  4909.88
# === In-sample cross-section RMSE (bp) ===
#   Maturity   RMSE_final       RMSE_WX
# 0    3M EU  7311.345487  10126.587826
# 1    6M EU  7030.856655   9903.318701
# 2    1Y EU  6115.446874   9227.966477
# 3    2Y EU  4203.429672   7976.358549
# 4    5Y EU  2235.850303   6457.523437
# 5    7Y EU  3245.632877   6191.862239
# 6   10Y EU  4733.824774   6158.890868
# 7   30Y EU  6358.630391   6105.028155
# === OOS RMSE (bp) – forecast horizon h = 1…12 months ===
# h               1         2         3         4         5         6   \
# Maturity
# 3M EU     28665.25  28672.34  28679.09  28681.64  28682.53  28681.64
# 6M EU     27497.22  27499.93  27502.21  27499.03  27495.21  27490.74
# 1Y EU     24603.07  24600.60  24597.69  24587.22  24577.87  24569.61
# 2Y EU     19114.59  19107.78  19100.60  19084.87  19071.81  19061.18
# 5Y EU      9617.14   9605.63   9594.04   9579.00   9565.75   9553.66
# 7Y EU      6499.81   6486.85   6474.07   6462.89   6451.83   6440.15
# 10Y EU     4483.69   4469.42   4455.87   4453.13   4447.94   4439.51
# 30Y EU     4745.40   4729.82   4715.77   4722.53   4726.83   4728.49
#
# h               7         8         9         10        11        12
# Maturity
# 3M EU     28678.84  28669.80  28662.42  28651.35  28636.26  28622.40
# 6M EU     27485.60  27473.55  27462.22  27449.35  27434.89  27422.81
# 1Y EU     24562.40  24547.81  24534.42  24520.85  24507.08  24496.88
# 2Y EU     19052.73  19038.08  19025.38  19012.17  18998.44  18988.84
# 5Y EU      9542.10   9529.40   9516.68   9503.45   9489.62   9477.85
# 7Y EU      6427.06   6415.68   6404.49   6393.45   6382.38   6370.18
# 10Y EU     4427.07   4420.27   4415.48   4412.68   4411.51   4403.23
# 30Y EU     4727.33   4734.64   4741.27   4756.67   4778.37   4790.43
# ✓ Shadow-rate series written to:  /content/replication_outputs_ea/shadow_rate_eu.csv
#   Rows written: 4,725
# Index(['WX (Euro Area)', 'MAJD (Euro Area)', 'Ind Prod EU', 'CPI EU',
#        'Unemployment EU', 'Bond Yield EU 3M', 'Bond Yield EU 10Y'],
#       dtype='object')
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 02, May, 2026
# Time:                     01:02:32
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                  -0.311705
# Nobs:                     99.0000    HQIC:                 -0.873571
# Log likelihood:          -463.758    FPE:                   0.285540
# AIC:                     -1.25539    Det(Omega_mle):        0.201611
# --------------------------------------------------------------------
# Results for equation Factor1
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.033956         0.124937           -0.272           0.786
# L1.Factor1                  0.533199         0.108622            4.909           0.000
# L1.Factor2                 -0.136481         0.132678           -1.029           0.304
# L1.Factor3                  0.031004         0.128768            0.241           0.810
# L1.MAJD (Euro Area)        -0.549000         0.299206           -1.835           0.067
# L2.Factor1                  0.059210         0.116724            0.507           0.612
# L2.Factor2                 -0.041281         0.136155           -0.303           0.762
# L2.Factor3                 -0.008920         0.118715           -0.075           0.940
# L2.MAJD (Euro Area)         0.020750         0.301946            0.069           0.945
# ======================================================================================
#
# Results for equation Factor2
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.049183         0.112856            0.436           0.663
# L1.Factor1                  0.029543         0.098118            0.301           0.763
# L1.Factor2                 -0.101249         0.119848           -0.845           0.398
# L1.Factor3                 -0.142214         0.116317           -1.223           0.221
# L1.MAJD (Euro Area)         0.357860         0.270273            1.324           0.185
# L2.Factor1                 -0.206116         0.105437           -1.955           0.051
# L2.Factor2                 -0.051277         0.122989           -0.417           0.677
# L2.Factor3                  0.028544         0.107236            0.266           0.790
# L2.MAJD (Euro Area)         0.100805         0.272748            0.370           0.712
# ======================================================================================
#
# Results for equation Factor3
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.022391         0.100979            0.222           0.825
# L1.Factor1                 -0.156776         0.087792           -1.786           0.074
# L1.Factor2                 -0.341706         0.107236           -3.186           0.001
# L1.Factor3                  0.018969         0.104076            0.182           0.855
# L1.MAJD (Euro Area)        -0.160394         0.241831           -0.663           0.507
# L2.Factor1                 -0.036808         0.094341           -0.390           0.696
# L2.Factor2                 -0.056531         0.110046           -0.514           0.607
# L2.Factor3                  0.026769         0.095951            0.279           0.780
# L2.MAJD (Euro Area)         0.429807         0.244045            1.761           0.078
# ======================================================================================
#
# Results for equation MAJD (Euro Area)
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.130423         0.051398           -2.538           0.011
# L1.Factor1                  0.102041         0.044686            2.284           0.022
# L1.Factor2                 -0.022377         0.054582           -0.410           0.682
# L1.Factor3                  0.017246         0.052974            0.326           0.745
# L1.MAJD (Euro Area)        -0.164248         0.123090           -1.334           0.182
# L2.Factor1                  0.051552         0.048019            1.074           0.283
# L2.Factor2                  0.013120         0.056013            0.234           0.815
# L2.Factor3                 -0.065309         0.048838           -1.337           0.181
# L2.MAJD (Euro Area)        -0.135349         0.124217           -1.090           0.276
# ======================================================================================
#
# Correlation matrix of residuals
#                      Factor1   Factor2   Factor3  MAJD (Euro Area)
# Factor1             1.000000  0.047482  0.134986          0.200083
# Factor2             0.047482  1.000000 -0.058374         -0.428833
# Factor3             0.134986 -0.058374  1.000000         -0.011443
# MAJD (Euro Area)    0.200083 -0.428833 -0.011443          1.000000
#
#
#
#
# Correlation matrix of residuals
#                    Factor1   Factor2   Factor3  MAJD (Euro Area)
# Factor1           1.000000  0.047482  0.134986          0.200083
# Factor2           0.047482  1.000000 -0.058374         -0.428833
# Factor3           0.134986 -0.058374  1.000000         -0.011443
# MAJD (Euro Area)  0.200083 -0.428833 -0.011443          1.000000
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 02, May, 2026
# Time:                     01:02:32
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                  -0.111504
# Nobs:                     99.0000    HQIC:                 -0.673370
# Log likelihood:          -473.668    FPE:                   0.348830
# AIC:                     -1.05518    Det(Omega_mle):        0.246297
# --------------------------------------------------------------------
# Results for equation Factor1
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.001062         0.117309           -0.009           0.993
# L1.Factor1                0.498951         0.117357            4.252           0.000
# L1.Factor2               -0.023691         0.115055           -0.206           0.837
# L1.Factor3                0.066706         0.136529            0.489           0.625
# L1.WX (Euro Area)        -0.046006         0.260939           -0.176           0.860
# L2.Factor1                0.145592         0.125436            1.161           0.246
# L2.Factor2               -0.041987         0.120005           -0.350           0.726
# L2.Factor3                0.068296         0.124301            0.549           0.583
# L2.WX (Euro Area)        -0.454583         0.259810           -1.750           0.080
# ====================================================================================
#
# Results for equation Factor2
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.012919         0.105699            0.122           0.903
# L1.Factor1                0.057934         0.105742            0.548           0.584
# L1.Factor2               -0.171137         0.103668           -1.651           0.099
# L1.Factor3               -0.154937         0.123016           -1.259           0.208
# L1.WX (Euro Area)        -0.035415         0.235113           -0.151           0.880
# L2.Factor1               -0.247403         0.113021           -2.189           0.029
# L2.Factor2               -0.071996         0.108127           -0.666           0.506
# L2.Factor3               -0.029980         0.111998           -0.268           0.789
# L2.WX (Euro Area)         0.319187         0.234096            1.363           0.173
# ====================================================================================
#
# Results for equation Factor3
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.005277         0.096139            0.055           0.956
# L1.Factor1               -0.212739         0.096178           -2.212           0.027
# L1.Factor2               -0.281244         0.094292           -2.983           0.003
# L1.Factor3                0.010810         0.111890            0.097           0.923
# L1.WX (Euro Area)         0.060985         0.213849            0.285           0.776
# L2.Factor1               -0.029457         0.102800           -0.287           0.774
# L2.Factor2               -0.135690         0.098348           -1.380           0.168
# L2.Factor3               -0.017861         0.101869           -0.175           0.861
# L2.WX (Euro Area)         0.186183         0.212924            0.874           0.382
# ====================================================================================
#
# Results for equation WX (Euro Area)
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.058831         0.057183           -1.029           0.304
# L1.Factor1                0.146593         0.057206            2.563           0.010
# L1.Factor2               -0.016008         0.056084           -0.285           0.775
# L1.Factor3                0.066434         0.066551            0.998           0.318
# L1.WX (Euro Area)        -0.162949         0.127195           -1.281           0.200
# L2.Factor1                0.055408         0.061144            0.906           0.365
# L2.Factor2               -0.002359         0.058497           -0.040           0.968
# L2.Factor3                0.076084         0.060591            1.256           0.209
# L2.WX (Euro Area)        -0.023796         0.126645           -0.188           0.851
# ====================================================================================
#
# Correlation matrix of residuals
#                    Factor1   Factor2   Factor3  WX (Euro Area)
# Factor1           1.000000  0.047892  0.165935        0.511465
# Factor2           0.047892  1.000000 -0.073775       -0.029047
# Factor3           0.165935 -0.073775  1.000000        0.380373
# WX (Euro Area)    0.511465 -0.029047  0.380373        1.000000
#
#
#
#
# Correlation matrix of residuals
#                  Factor1   Factor2   Factor3  WX (Euro Area)
# Factor1         1.000000  0.047892  0.165935        0.511465
# Factor2         0.047892  1.000000 -0.073775       -0.029047
# Factor3         0.165935 -0.073775  1.000000        0.380373
# WX (Euro Area)  0.511465 -0.029047  0.380373        1.000000
# Impulse Response for the MAJD (Euro Area):
# Impulse Response for WX (Euro Area):
# Cumulative Impulse Responses Comparison for EU:
#                   Factor1 → Factor1  Factor2 → Factor1  Factor3 → Factor1  \
# MAJD (Euro Area)           2.392433           0.347284           0.481512
# WX (Euro Area)             2.318689           0.290882           0.539197
# Difference                 0.073745           0.056403          -0.057685
#
#                   MAJD (Euro Area) → Factor1  Factor1 → Factor2  \
# MAJD (Euro Area)                    0.362668           0.192605
# WX (Euro Area)                           NaN           0.165049
# Difference                               NaN           0.027555
#
#                   Factor2 → Factor2  Factor3 → Factor2  \
# MAJD (Euro Area)           1.264029           0.504194
# WX (Euro Area)             1.255438           0.515712
# Difference                 0.008591          -0.011518
#
#                   MAJD (Euro Area) → Factor2  Factor1 → Factor3  \
# MAJD (Euro Area)                    0.274915           0.162621
# WX (Euro Area)                           NaN           0.131307
# Difference                               NaN           0.031314
#
#                   Factor2 → Factor3  ...  Factor2 → MAJD (Euro Area)  \
# MAJD (Euro Area)           0.224340  ...                    0.204576
# WX (Euro Area)             0.238884  ...                         NaN
# Difference                -0.014543  ...                         NaN
#
#                   Factor3 → MAJD (Euro Area)  \
# MAJD (Euro Area)                    0.261105
# WX (Euro Area)                           NaN
# Difference                               NaN
#
#                   MAJD (Euro Area) → MAJD (Euro Area)  \
# MAJD (Euro Area)                             0.577849
# WX (Euro Area)                                    NaN
# Difference                                        NaN
#
#                   WX (Euro Area) → Factor1  WX (Euro Area) → Factor2  \
# MAJD (Euro Area)                       NaN                       NaN
# WX (Euro Area)                    0.614791                  0.119574
# Difference                             NaN                       NaN
#
#                   WX (Euro Area) → Factor3  Factor1 → WX (Euro Area)  \
# MAJD (Euro Area)                       NaN                       NaN
# WX (Euro Area)                    0.287798                  0.422674
# Difference                             NaN                       NaN
#
#                   Factor2 → WX (Euro Area)  Factor3 → WX (Euro Area)  \
# MAJD (Euro Area)                       NaN                       NaN
# WX (Euro Area)                    0.286762                   0.14882
# Difference                             NaN                       NaN
#
#                   WX (Euro Area) → WX (Euro Area)
# MAJD (Euro Area)                              NaN
# WX (Euro Area)                           0.579862
# Difference                                    NaN
#
# [3 rows x 23 columns]
# Comparison data saved as 'replication_outputs_ea/cumulative_irf_comparison_eu.csv'.
# Merged Data Columns (EU):
# Index(['MAJD (Euro Area)', 'INF EU', 'GDP EU'], dtype='object')
#
# After transformations (first few rows):
#             MAJD (Euro Area)    INF EU    GDP EU
# Date
# 2009-01-01          5.420489 -1.401869 -3.081868
# 2009-04-01          6.036941  1.135236 -0.035236
# 2009-07-01          5.819896 -0.403226  0.392424
# 2009-10-01          5.125132  0.579932  0.492971
# 2010-01-01          4.225509 -0.380766  0.367195
#
# VAR Model Summary (EU):
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 02, May, 2026
# Time:                     01:02:37
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -1.47546
# Nobs:                     55.0000    HQIC:                  -1.94551
# Log likelihood:          -151.473    FPE:                   0.106700
# AIC:                     -2.24189    Det(Omega_mle):       0.0744867
# --------------------------------------------------------------------
# Results for equation MAJD (Euro Area)
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.064991         0.050050           -1.299           0.194
# L1.MAJD (Euro Area)         0.085989         0.284267            0.302           0.762
# L1.INF EU                   0.138163         0.053942            2.561           0.010
# L1.GDP EU                  -0.109992         0.060185           -1.828           0.068
# L2.MAJD (Euro Area)         0.798282         0.274785            2.905           0.004
# L2.INF EU                   0.082439         0.053968            1.528           0.127
# L2.GDP EU                  -0.018877         0.050511           -0.374           0.709
# ======================================================================================
#
# Results for equation INF EU
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.053970         0.118751            0.454           0.649
# L1.MAJD (Euro Area)         0.264532         0.674464            0.392           0.695
# L1.INF EU                  -0.196649         0.127984           -1.537           0.124
# L1.GDP EU                  -0.024801         0.142796           -0.174           0.862
# L2.MAJD (Euro Area)        -0.309390         0.651967           -0.475           0.635
# L2.INF EU                   0.535025         0.128048            4.178           0.000
# L2.GDP EU                   0.069218         0.119845            0.578           0.564
# ======================================================================================
#
# Results for equation GDP EU
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.086947         0.137288            0.633           0.527
# L1.MAJD (Euro Area)         1.014296         0.779748            1.301           0.193
# L1.INF EU                   0.068934         0.147963            0.466           0.641
# L1.GDP EU                  -0.205298         0.165087           -1.244           0.214
# L2.MAJD (Euro Area)        -0.998081         0.753740           -1.324           0.185
# L2.INF EU                  -0.019860         0.148036           -0.134           0.893
# L2.GDP EU                  -0.159057         0.138553           -1.148           0.251
# ======================================================================================
#
# Correlation matrix of residuals
#                     MAJD (Euro Area)    INF EU    GDP EU
# MAJD (Euro Area)            1.000000  0.002252 -0.304711
# INF EU                      0.002252  1.000000  0.061539
# GDP EU                     -0.304711  0.061539  1.000000
#
#
#
#
# Impulse Response Functions (EU system):
# Cumulative IRF Results (EU):
#                                      Cumulative IRF
# MAJD (Euro Area) → MAJD (Euro Area)        1.549315
# INF EU → MAJD (Euro Area)                  1.449286
# GDP EU → MAJD (Euro Area)                  1.792274
# MAJD (Euro Area) → INF EU                  0.893226
# INF EU → INF EU                            3.071532
# GDP EU → INF EU                            0.529283
# MAJD (Euro Area) → GDP EU                  0.319020
# INF EU → GDP EU                            0.177207
# GDP EU → GDP EU                            1.610145
#
# Cumulative IRF saved to replication_outputs_ea/cumulative_irf_final_shadow_eu.xlsx.
# Alternative-order VAR data columns (MAJD):
# ['MAJD (Euro Area)', 'Factor1', 'Factor2', 'Factor3']
#
# Alternative-order VAR data columns (WX):
# ['WX (Euro Area)', 'Factor1', 'Factor2', 'Factor3']
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 02, May, 2026
# Time:                     01:02:38
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                  -0.311705
# Nobs:                     99.0000    HQIC:                 -0.873571
# Log likelihood:          -463.758    FPE:                   0.285540
# AIC:                     -1.25539    Det(Omega_mle):        0.201611
# --------------------------------------------------------------------
# Results for equation MAJD (Euro Area)
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.130423         0.051398           -2.538           0.011
# L1.MAJD (Euro Area)        -0.164248         0.123090           -1.334           0.182
# L1.Factor1                  0.102041         0.044686            2.284           0.022
# L1.Factor2                 -0.022377         0.054582           -0.410           0.682
# L1.Factor3                  0.017246         0.052974            0.326           0.745
# L2.MAJD (Euro Area)        -0.135349         0.124217           -1.090           0.276
# L2.Factor1                  0.051552         0.048019            1.074           0.283
# L2.Factor2                  0.013120         0.056013            0.234           0.815
# L2.Factor3                 -0.065309         0.048838           -1.337           0.181
# ======================================================================================
#
# Results for equation Factor1
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                      -0.033956         0.124937           -0.272           0.786
# L1.MAJD (Euro Area)        -0.549000         0.299206           -1.835           0.067
# L1.Factor1                  0.533199         0.108622            4.909           0.000
# L1.Factor2                 -0.136481         0.132678           -1.029           0.304
# L1.Factor3                  0.031004         0.128768            0.241           0.810
# L2.MAJD (Euro Area)         0.020750         0.301946            0.069           0.945
# L2.Factor1                  0.059210         0.116724            0.507           0.612
# L2.Factor2                 -0.041281         0.136155           -0.303           0.762
# L2.Factor3                 -0.008920         0.118715           -0.075           0.940
# ======================================================================================
#
# Results for equation Factor2
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.049183         0.112856            0.436           0.663
# L1.MAJD (Euro Area)         0.357860         0.270273            1.324           0.185
# L1.Factor1                  0.029543         0.098118            0.301           0.763
# L1.Factor2                 -0.101249         0.119848           -0.845           0.398
# L1.Factor3                 -0.142214         0.116317           -1.223           0.221
# L2.MAJD (Euro Area)         0.100805         0.272748            0.370           0.712
# L2.Factor1                 -0.206116         0.105437           -1.955           0.051
# L2.Factor2                 -0.051277         0.122989           -0.417           0.677
# L2.Factor3                  0.028544         0.107236            0.266           0.790
# ======================================================================================
#
# Results for equation Factor3
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.022391         0.100979            0.222           0.825
# L1.MAJD (Euro Area)        -0.160394         0.241831           -0.663           0.507
# L1.Factor1                 -0.156776         0.087792           -1.786           0.074
# L1.Factor2                 -0.341706         0.107236           -3.186           0.001
# L1.Factor3                  0.018969         0.104076            0.182           0.855
# L2.MAJD (Euro Area)         0.429807         0.244045            1.761           0.078
# L2.Factor1                 -0.036808         0.094341           -0.390           0.696
# L2.Factor2                 -0.056531         0.110046           -0.514           0.607
# L2.Factor3                  0.026769         0.095951            0.279           0.780
# ======================================================================================
#
# Correlation matrix of residuals
#                     MAJD (Euro Area)   Factor1   Factor2   Factor3
# MAJD (Euro Area)            1.000000  0.200083 -0.428833 -0.011443
# Factor1                     0.200083  1.000000  0.047482  0.134986
# Factor2                    -0.428833  0.047482  1.000000 -0.058374
# Factor3                    -0.011443  0.134986 -0.058374  1.000000
#
#
#
#
# Correlation matrix of residuals
#                   MAJD (Euro Area)   Factor1   Factor2   Factor3
# MAJD (Euro Area)          1.000000  0.200083 -0.428833 -0.011443
# Factor1                   0.200083  1.000000  0.047482  0.134986
# Factor2                  -0.428833  0.047482  1.000000 -0.058374
# Factor3                  -0.011443  0.134986 -0.058374  1.000000
#
# === VAR(2) estimation results ===
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 02, May, 2026
# Time:                     01:02:38
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                  -0.111504
# Nobs:                     99.0000    HQIC:                 -0.673370
# Log likelihood:          -473.668    FPE:                   0.348830
# AIC:                     -1.05518    Det(Omega_mle):        0.246297
# --------------------------------------------------------------------
# Results for equation WX (Euro Area)
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.058831         0.057183           -1.029           0.304
# L1.WX (Euro Area)        -0.162949         0.127195           -1.281           0.200
# L1.Factor1                0.146593         0.057206            2.563           0.010
# L1.Factor2               -0.016008         0.056084           -0.285           0.775
# L1.Factor3                0.066434         0.066551            0.998           0.318
# L2.WX (Euro Area)        -0.023796         0.126645           -0.188           0.851
# L2.Factor1                0.055408         0.061144            0.906           0.365
# L2.Factor2               -0.002359         0.058497           -0.040           0.968
# L2.Factor3                0.076084         0.060591            1.256           0.209
# ====================================================================================
#
# Results for equation Factor1
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                    -0.001062         0.117309           -0.009           0.993
# L1.WX (Euro Area)        -0.046006         0.260939           -0.176           0.860
# L1.Factor1                0.498951         0.117357            4.252           0.000
# L1.Factor2               -0.023691         0.115055           -0.206           0.837
# L1.Factor3                0.066706         0.136529            0.489           0.625
# L2.WX (Euro Area)        -0.454583         0.259810           -1.750           0.080
# L2.Factor1                0.145592         0.125436            1.161           0.246
# L2.Factor2               -0.041987         0.120005           -0.350           0.726
# L2.Factor3                0.068296         0.124301            0.549           0.583
# ====================================================================================
#
# Results for equation Factor2
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.012919         0.105699            0.122           0.903
# L1.WX (Euro Area)        -0.035415         0.235113           -0.151           0.880
# L1.Factor1                0.057934         0.105742            0.548           0.584
# L1.Factor2               -0.171137         0.103668           -1.651           0.099
# L1.Factor3               -0.154937         0.123016           -1.259           0.208
# L2.WX (Euro Area)         0.319187         0.234096            1.363           0.173
# L2.Factor1               -0.247403         0.113021           -2.189           0.029
# L2.Factor2               -0.071996         0.108127           -0.666           0.506
# L2.Factor3               -0.029980         0.111998           -0.268           0.789
# ====================================================================================
#
# Results for equation Factor3
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.005277         0.096139            0.055           0.956
# L1.WX (Euro Area)         0.060985         0.213849            0.285           0.776
# L1.Factor1               -0.212739         0.096178           -2.212           0.027
# L1.Factor2               -0.281244         0.094292           -2.983           0.003
# L1.Factor3                0.010810         0.111890            0.097           0.923
# L2.WX (Euro Area)         0.186183         0.212924            0.874           0.382
# L2.Factor1               -0.029457         0.102800           -0.287           0.774
# L2.Factor2               -0.135690         0.098348           -1.380           0.168
# L2.Factor3               -0.017861         0.101869           -0.175           0.861
# ====================================================================================
#
# Correlation matrix of residuals
#                   WX (Euro Area)   Factor1   Factor2   Factor3
# WX (Euro Area)          1.000000  0.511465 -0.029047  0.380373
# Factor1                 0.511465  1.000000  0.047892  0.165935
# Factor2                -0.029047  0.047892  1.000000 -0.073775
# Factor3                 0.380373  0.165935 -0.073775  1.000000
#
#
#
#
# Correlation matrix of residuals
#                 WX (Euro Area)   Factor1   Factor2   Factor3
# WX (Euro Area)        1.000000  0.511465 -0.029047  0.380373
# Factor1               0.511465  1.000000  0.047892  0.165935
# Factor2              -0.029047  0.047892  1.000000 -0.073775
# Factor3               0.380373  0.165935 -0.073775  1.000000
# Impulse Response for the MAJD (Euro Area) - Alternative Ordering:
# Impulse Response for WX (Euro Area) - Alternative Ordering:
# Cumulative IRF Comparison for Euro Area (Alternative Ordering):
#                              MAJD (Euro Area) → MAJD (Euro Area)  \
# MAJD (Euro Area) - AltOrder                             0.599149
# WX (Euro Area) - AltOrder                                    NaN
# Difference                                                   NaN
#
#                              Factor1 → MAJD (Euro Area)  \
# MAJD (Euro Area) - AltOrder                    0.358775
# WX (Euro Area) - AltOrder                           NaN
# Difference                                          NaN
#
#                              Factor2 → MAJD (Euro Area)  \
# MAJD (Euro Area) - AltOrder                    0.749695
# WX (Euro Area) - AltOrder                           NaN
# Difference                                          NaN
#
#                              Factor3 → MAJD (Euro Area)  \
# MAJD (Euro Area) - AltOrder                    0.239131
# WX (Euro Area) - AltOrder                           NaN
# Difference                                          NaN
#
#                              MAJD (Euro Area) → Factor1  Factor1 → Factor1  \
# MAJD (Euro Area) - AltOrder                    0.292099           2.401239
# WX (Euro Area) - AltOrder                           NaN           2.184771
# Difference                                          NaN           0.216468
#
#                              Factor2 → Factor1  Factor3 → Factor1  \
# MAJD (Euro Area) - AltOrder           0.387852           0.538926
# WX (Euro Area) - AltOrder             0.389923           0.431940
# Difference                           -0.002071           0.106986
#
#                              MAJD (Euro Area) → Factor2  Factor1 → Factor2  \
# MAJD (Euro Area) - AltOrder                    0.054643           0.358585
# WX (Euro Area) - AltOrder                           NaN           0.187847
# Difference                                          NaN           0.170738
#
#                              ...  Factor1 → Factor3  Factor2 → Factor3  \
# MAJD (Euro Area) - AltOrder  ...           0.130864           0.212689
# WX (Euro Area) - AltOrder    ...           0.186827           0.169179
# Difference                   ...          -0.055963           0.043511
#
#                              Factor3 → Factor3  \
# MAJD (Euro Area) - AltOrder           1.025208
# WX (Euro Area) - AltOrder             0.910032
# Difference                            0.115176
#
#                              WX (Euro Area) → WX (Euro Area)  \
# MAJD (Euro Area) - AltOrder                              NaN
# WX (Euro Area) - AltOrder                           0.673507
# Difference                                               NaN
#
#                              Factor1 → WX (Euro Area)  \
# MAJD (Euro Area) - AltOrder                       NaN
# WX (Euro Area) - AltOrder                    0.948374
# Difference                                        NaN
#
#                              Factor2 → WX (Euro Area)  \
# MAJD (Euro Area) - AltOrder                       NaN
# WX (Euro Area) - AltOrder                    0.263458
# Difference                                        NaN
#
#                              Factor3 → WX (Euro Area)  \
# MAJD (Euro Area) - AltOrder                       NaN
# WX (Euro Area) - AltOrder                    0.509103
# Difference                                        NaN
#
#                              WX (Euro Area) → Factor1  \
# MAJD (Euro Area) - AltOrder                       NaN
# WX (Euro Area) - AltOrder                    0.322602
# Difference                                        NaN
#
#                              WX (Euro Area) → Factor2  \
# MAJD (Euro Area) - AltOrder                       NaN
# WX (Euro Area) - AltOrder                    0.094596
# Difference                                        NaN
#
#                              WX (Euro Area) → Factor3
# MAJD (Euro Area) - AltOrder                       NaN
# WX (Euro Area) - AltOrder                     0.14175
# Difference                                        NaN
#
# [3 rows x 23 columns]
#
# Saved: replication_outputs_ea/cumulative_irf_comparison_eu_alt_order.csv
#
# Cumulative responses to SHADOW-RATE shock only (Alternative Ordering):
#                                               MAJD AltOrder  WX AltOrder  \
# MAJD (Euro Area) ← shock in MAJD (Euro Area)       0.599149          NaN
# Factor1 ← shock in MAJD (Euro Area)                0.358775          NaN
# Factor2 ← shock in MAJD (Euro Area)                0.749695          NaN
# Factor3 ← shock in MAJD (Euro Area)                0.239131          NaN
# WX (Euro Area) ← shock in WX (Euro Area)                NaN     0.673507
# Factor1 ← shock in WX (Euro Area)                       NaN     0.948374
# Factor2 ← shock in WX (Euro Area)                       NaN     0.263458
# Factor3 ← shock in WX (Euro Area)                       NaN     0.509103
#
#                                               Difference
# MAJD (Euro Area) ← shock in MAJD (Euro Area)         NaN
# Factor1 ← shock in MAJD (Euro Area)                  NaN
# Factor2 ← shock in MAJD (Euro Area)                  NaN
# Factor3 ← shock in MAJD (Euro Area)                  NaN
# WX (Euro Area) ← shock in WX (Euro Area)             NaN
# Factor1 ← shock in WX (Euro Area)                    NaN
# Factor2 ← shock in WX (Euro Area)                    NaN
# Factor3 ← shock in WX (Euro Area)                    NaN
#
# Saved: replication_outputs_ea/shadow_shock_only_eu_alt_order.csv
